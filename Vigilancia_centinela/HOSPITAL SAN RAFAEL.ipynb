# %% [markdown]
# </center>
#
# ---
# # **HOSPITAL UNIVERSITARIO CLINICA SAN RAFAEL**
# ---

# %% [markdown]
# ## **NOTAS:**
# - Actualizar el número de las semana

# %% [markdown]
# ## Identificación, Filtrado y Exportación de Registros Duplicados en un DataFrame

# %% [markdown]
#  estas dos líneas de código preparan tu entorno para trabajar con datos cargando las herramientas necesarias (pandas y numpy) y proporcionando nombres abreviados convenientes para ellos (pd y np).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Las siguientes dos líneas de código hacen lo siguiente:
#
# - Leen un archivo de Excel ubicado en una ruta específica.
# - Ignoran las primeras 5 filas del archivo.
# - Crean un DataFrame llamado df con los datos del archivo.
# - Muestran el DataFrame df

# %% [markdown]
# Reemplazar la ruta del archivo

# %%
df=pd.read_excel("/content/HUCSR_SE20.xlsx", skiprows=5)
df
# Out:
#                                             Aseguradora         Tipo Plan  \
# 0               CAJA DE COMPENSACIÓN FAMILIAR COMPENSAR  POS Contributivo
# 1                                 Salud Total EPS S S A  POS Contributivo
# 2             Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 3     Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 4                             COMPENSAR MICRORED CAPITA  Capitado-Alianza
# ...                                                 ...               ...
# 3639                          COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
# 3643          Hospital Universitario Clinica San Rafael        Particular
#
#      Tip Doc   Documento                Nombre Paciente       Sexo  \
# 0         CC   017011231             MOISES  NIÑO REYES  MASCULINO
# 1         CC  1000000290  DANNA LISBETH CARDOZO ANDRADE   FEMENINO
# 2         CC  1000007712   MARIA XIMENA ARAQUE SANDOVAL   FEMENINO
# 3         CC  1000019214          TANIA  GUERRA SANCHEZ   FEMENINO
# 4         CC  1000020532      MICHELL VANESA LUQUE MORA   FEMENINO
# ...      ...         ...                            ...        ...
# 3639      CC    98481037      RAFAEL ANGEL OSORIO ORTIZ  MASCULINO
# 3640      CC      996506   JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506   JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506   JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3643      PA   A25557795       AYLA LUCIA GUZMAN FLOREZ   FEMENINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo          Direccion De Residencia  \
# 0          02/02/1938  87 A      60 y mas                 CRA 13 F 40 I 26
# 1          25/12/1999  25 A  15 a 44 años              KRA 5 BIS 12 09 SUR
# 2          13/07/2002  22 A  15 a 44 años  KR  3 B BIS  48  SUR  11  ESTE
# 3          30/03/2002  23 A  15 a 44 años   CL 68 SUR  11 A 20 ESTE INTE 5
# 4          04/01/2002  23 A  15 a 44 años         CARE 11 ESTE 55 67 SUR
# ...               ...   ...           ...                              ...
# 3639       23/02/1963  62 A      60 y mas             CR  3  D 48 L 34 SUR
# 3640       15/06/1934  90 A      60 y mas            CALLE 11 SUR   12A 08
# 3641       15/06/1934  90 A      60 y mas            CALLE 11 SUR   12A 08
# 3642       15/06/1934  90 A      60 y mas            CALLE 11 SUR   12A 08
# 3643       28/04/2023   2 A    1 a 4 años               CR 8 B SUR 1 C 35
#
#       ...       Localidad Tipo Urgencia Fecha Ingreso Hora Ingreso  \
# 0     ...    RAFAEL URIBE       ADULTOS    2025/05/03   12:54:14
# 1     ...   SAN CRISTOBAL       ADULTOS    2025/05/15   07:14:49
# 2     ...   SAN CRISTOBAL     Ortopedia    2025/05/16   08:39:17
# 3     ...   SAN CRISTOBAL       ADULTOS    2025/05/10   12:37:27
# 4     ...   SAN CRISTOBAL       ADULTOS    2025/05/15   20:21:13
# ...   ...             ...           ...           ...          ...
# 3639  ...    RAFAEL URIBE       ADULTOS    2025/05/03   14:27:09
# 3640  ...  ANTONIO NARIÑO       ADULTOS    2025/05/14   14:53:20
# 3641  ...  ANTONIO NARIÑO       ADULTOS    2025/05/15   17:50:12
# 3642  ...  ANTONIO NARIÑO       ADULTOS    2025/05/17   10:16:15
# 3643  ...   SAN CRISTOBAL    PEDIATRICA    2025/05/14   22:31:36
#
#      Fecha Atencion Hora Atencion  \
# 0        2025/05/03    13:03:00
# 1        2025/05/15    08:54:00
# 2        2025/05/16    08:57:00
# 3        2025/05/10    16:04:00
# 4        2025/05/15    22:20:00
# ...             ...           ...
# 3639     2025/05/03    20:35:00
# 3640     2025/05/14    15:17:00
# 3641     2025/05/15    20:43:00
# 3642     2025/05/17    13:19:00
# 3643     2025/05/14    23:39:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 0                       Bronconeumonia, no especificada         J180
# 1      Contusion de la region lumbosacra y de la pelvis         S300
# 2                                 Contusion del tobillo         S900
# 3     Procedimiento no realizado por decision del pa...         Z532
# 4                                             Dispepsia         K30X
# ...                                                 ...          ...
# 3639                     Sindrome de manguito rotatorio         M751
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
# 3643  Otitis  media no supurativa, sin otra especifi...         H659
#
#                                      Diagnostico Egreso CIE10 Egreso
# 0     Infeccion de vias urinarias, sitio no especifi...         N390
# 1                                   Fractura del coccix         S322
# 2                    Esguinces y torceduras del tobillo         S934
# 3                                                   NaN          NaN
# 4                                             Dispepsia         K30X
# ...                                                 ...          ...
# 3639                                                NaN          NaN
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN          NaN
# 3643             Otra otitis media aguda, no supurativa         H651
#
# [3644 rows x 21 columns]

# %% [markdown]
# Esta línea es la encargada de mostrar las dimensiones (número de filas y columnas) del DataFrame llamado df

# %%
print(f"La base tiene {df.shape[0]} filas y {df.shape[1]} columnas  ")
# Out:
# La base tiene 3644 filas y 21 columnas

# %% [markdown]
# **Actualizar las fechas de las semana epidemiólogica**

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
# Función para filtrar datos con solo ingresar el número de la semana
import pandas as pd

def filtrar_por_semana(df, semana):
    if semana not in semanas_2025:
        raise ValueError("Número de semana no válido. Debe estar entre 1 y 53.")

    Fecha_Inicio_Semana, Fecha_Final_Semana = semanas_2025[semana]

    # Convertir la columna de fechas a formato datetime si no lo está
    df["Fecha Ingreso"] = pd.to_datetime(df["Fecha Ingreso"])

    # Filtrar el DataFrame por la semana seleccionada
    df = df[
        (df["Fecha Ingreso"] >= Fecha_Inicio_Semana) &
        (df["Fecha Ingreso"] <= Fecha_Final_Semana)
    ]

    return df

# %% [markdown]
# # Ingrese el número de semana epidemiologica

# %%
df=filtrar_por_semana(df,20)
df
# Out:
#                                     Aseguradora         Tipo Plan Tip Doc  \
# 1                         Salud Total EPS S S A  POS Contributivo      CC
# 2     Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      CC
# 4                     COMPENSAR MICRORED CAPITA  Capitado-Alianza      CC
# 8                                  Nueva Eps Sa  POS Contributivo      CC
# 9                                  Nueva Eps Sa  POS Contributivo      CC
# ...                                         ...               ...     ...
# 3637                       Eps Famisanar S A S   POS Contributivo      CC
# 3640                               Nueva Eps Sa  POS Contributivo      CC
# 3641                               Nueva Eps Sa  POS Contributivo      CC
# 3642                               Nueva Eps Sa  POS Contributivo      CC
# 3643  Hospital Universitario Clinica San Rafael        Particular      PA
#
#        Documento                   Nombre Paciente       Sexo  \
# 1     1000000290     DANNA LISBETH CARDOZO ANDRADE   FEMENINO
# 2     1000007712      MARIA XIMENA ARAQUE SANDOVAL   FEMENINO
# 4     1000020532         MICHELL VANESA LUQUE MORA   FEMENINO
# 8     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# 9     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# ...          ...                               ...        ...
# 3637    96354747          JOSE SANTOS CABRERA DIAZ  MASCULINO
# 3640      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3643   A25557795          AYLA LUCIA GUZMAN FLOREZ   FEMENINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo  \
# 1          25/12/1999  25 A  15 a 44 años
# 2          13/07/2002  22 A  15 a 44 años
# 4          04/01/2002  23 A  15 a 44 años
# 8          22/10/2001  23 A  15 a 44 años
# 9          22/10/2001  23 A  15 a 44 años
# ...               ...   ...           ...
# 3637       22/12/1976  48 A  45 a 59 años
# 3640       15/06/1934  90 A      60 y mas
# 3641       15/06/1934  90 A      60 y mas
# 3642       15/06/1934  90 A      60 y mas
# 3643       28/04/2023   2 A    1 a 4 años
#
#                     Direccion De Residencia  ...       Localidad  \
# 1                       KRA 5 BIS 12 09 SUR  ...   SAN CRISTOBAL
# 2           KR  3 B BIS  48  SUR  11  ESTE   ...   SAN CRISTOBAL
# 4                  CARE 11 ESTE 55 67 SUR    ...   SAN CRISTOBAL
# 8     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# 9     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# ...                                     ...  ...             ...
# 3637                            CL 75 10 30  ...            USME
# 3640                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3641                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3642                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3643                     CR 8 B SUR 1 C 35   ...   SAN CRISTOBAL
#
#      Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion Hora Atencion  \
# 1          ADULTOS    2025-05-15   07:14:49       2025/05/15    08:54:00
# 2        Ortopedia    2025-05-16   08:39:17       2025/05/16    08:57:00
# 4          ADULTOS    2025-05-15   20:21:13       2025/05/15    22:20:00
# 8          ADULTOS    2025-05-12   08:05:41       2025/05/12    08:59:00
# 9          ADULTOS    2025-05-12   08:05:41       2025/05/12    09:12:00
# ...            ...           ...          ...            ...           ...
# 3637       ADULTOS    2025-05-15   10:39:58       2025/05/15    13:17:00
# 3640       ADULTOS    2025-05-14   14:53:20       2025/05/14    15:17:00
# 3641       ADULTOS    2025-05-15   17:50:12       2025/05/15    20:43:00
# 3642       ADULTOS    2025-05-17   10:16:15       2025/05/17    13:19:00
# 3643    PEDIATRICA    2025-05-14   22:31:36       2025/05/14    23:39:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 1      Contusion de la region lumbosacra y de la pelvis         S300
# 2                                 Contusion del tobillo         S900
# 4                                             Dispepsia         K30X
# 8     Trastornos inflamatorios pelvicos femeninos en...         N748
# 9     Trastornos inflamatorios pelvicos femeninos en...         N748
# ...                                                 ...          ...
# 3637                       Cuerpo extraño en la faringe         T172
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
# 3643  Otitis  media no supurativa, sin otra especifi...         H659
#
#                           Diagnostico Egreso CIE10 Egreso
# 1                        Fractura del coccix         S322
# 2         Esguinces y torceduras del tobillo         S934
# 4                                  Dispepsia         K30X
# 8                       Contractura muscular         M624
# 9                       Contractura muscular         M624
# ...                                      ...          ...
# 3637            Cuerpo extraño en el esofago         T181
# 3640        Hipertension esencial (primaria)         I10X
# 3641        Hipertension esencial (primaria)         I10X
# 3642                                     NaN          NaN
# 3643  Otra otitis media aguda, no supurativa         H651
#
# [1569 rows x 21 columns]

# %%
df["Municipio"].unique()
# Out:
# array(['Bogotá D.C.', 'Gutierrez', 'Mosquera', 'El Colegio', 'Madrid',
#        'Soacha', 'Funza', 'Ubate', 'Sibate', 'La Vega', 'Guatavita',
#        'Fosca', 'Saravena', 'Viota', 'Junin', 'Caqueza',
#        'San Jose del Guaviare', 'San Antonio del Tequendam', 'Ubaque',
#        'Choachi', 'Choconta', 'La Mesa', 'San Francisco', 'Yopal',
#        'Guasca', 'Bojaca', 'Une', 'Tena', 'Villavicencio', 'Tame'],
#       dtype=object)

# %%
df=df[df["Municipio"]=='Bogotá D.C.']
df
# Out:
#                                     Aseguradora         Tipo Plan Tip Doc  \
# 1                         Salud Total EPS S S A  POS Contributivo      CC
# 2     Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      CC
# 4                     COMPENSAR MICRORED CAPITA  Capitado-Alianza      CC
# 8                                  Nueva Eps Sa  POS Contributivo      CC
# 9                                  Nueva Eps Sa  POS Contributivo      CC
# ...                                         ...               ...     ...
# 3637                       Eps Famisanar S A S   POS Contributivo      CC
# 3640                               Nueva Eps Sa  POS Contributivo      CC
# 3641                               Nueva Eps Sa  POS Contributivo      CC
# 3642                               Nueva Eps Sa  POS Contributivo      CC
# 3643  Hospital Universitario Clinica San Rafael        Particular      PA
#
#        Documento                   Nombre Paciente       Sexo  \
# 1     1000000290     DANNA LISBETH CARDOZO ANDRADE   FEMENINO
# 2     1000007712      MARIA XIMENA ARAQUE SANDOVAL   FEMENINO
# 4     1000020532         MICHELL VANESA LUQUE MORA   FEMENINO
# 8     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# 9     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# ...          ...                               ...        ...
# 3637    96354747          JOSE SANTOS CABRERA DIAZ  MASCULINO
# 3640      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3643   A25557795          AYLA LUCIA GUZMAN FLOREZ   FEMENINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo  \
# 1          25/12/1999  25 A  15 a 44 años
# 2          13/07/2002  22 A  15 a 44 años
# 4          04/01/2002  23 A  15 a 44 años
# 8          22/10/2001  23 A  15 a 44 años
# 9          22/10/2001  23 A  15 a 44 años
# ...               ...   ...           ...
# 3637       22/12/1976  48 A  45 a 59 años
# 3640       15/06/1934  90 A      60 y mas
# 3641       15/06/1934  90 A      60 y mas
# 3642       15/06/1934  90 A      60 y mas
# 3643       28/04/2023   2 A    1 a 4 años
#
#                     Direccion De Residencia  ...       Localidad  \
# 1                       KRA 5 BIS 12 09 SUR  ...   SAN CRISTOBAL
# 2           KR  3 B BIS  48  SUR  11  ESTE   ...   SAN CRISTOBAL
# 4                  CARE 11 ESTE 55 67 SUR    ...   SAN CRISTOBAL
# 8     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# 9     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# ...                                     ...  ...             ...
# 3637                            CL 75 10 30  ...            USME
# 3640                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3641                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3642                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3643                     CR 8 B SUR 1 C 35   ...   SAN CRISTOBAL
#
#      Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion Hora Atencion  \
# 1          ADULTOS    2025-05-15   07:14:49       2025/05/15    08:54:00
# 2        Ortopedia    2025-05-16   08:39:17       2025/05/16    08:57:00
# 4          ADULTOS    2025-05-15   20:21:13       2025/05/15    22:20:00
# 8          ADULTOS    2025-05-12   08:05:41       2025/05/12    08:59:00
# 9          ADULTOS    2025-05-12   08:05:41       2025/05/12    09:12:00
# ...            ...           ...          ...            ...           ...
# 3637       ADULTOS    2025-05-15   10:39:58       2025/05/15    13:17:00
# 3640       ADULTOS    2025-05-14   14:53:20       2025/05/14    15:17:00
# 3641       ADULTOS    2025-05-15   17:50:12       2025/05/15    20:43:00
# 3642       ADULTOS    2025-05-17   10:16:15       2025/05/17    13:19:00
# 3643    PEDIATRICA    2025-05-14   22:31:36       2025/05/14    23:39:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 1      Contusion de la region lumbosacra y de la pelvis         S300
# 2                                 Contusion del tobillo         S900
# 4                                             Dispepsia         K30X
# 8     Trastornos inflamatorios pelvicos femeninos en...         N748
# 9     Trastornos inflamatorios pelvicos femeninos en...         N748
# ...                                                 ...          ...
# 3637                       Cuerpo extraño en la faringe         T172
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
# 3643  Otitis  media no supurativa, sin otra especifi...         H659
#
#                           Diagnostico Egreso CIE10 Egreso
# 1                        Fractura del coccix         S322
# 2         Esguinces y torceduras del tobillo         S934
# 4                                  Dispepsia         K30X
# 8                       Contractura muscular         M624
# 9                       Contractura muscular         M624
# ...                                      ...          ...
# 3637            Cuerpo extraño en el esofago         T181
# 3640        Hipertension esencial (primaria)         I10X
# 3641        Hipertension esencial (primaria)         I10X
# 3642                                     NaN          NaN
# 3643  Otra otitis media aguda, no supurativa         H651
#
# [1491 rows x 21 columns]

# %% [markdown]
# Esta sección del código identifica y muestra todas las filas duplicadas en el DataFrame df y luego calcula y muestra el número total de filas duplicadas encontradas.

# %%
df.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso'],
#       dtype='object')

# %%
df['CIE10 Egreso'].isna().sum()
# Out:
# np.int64(487)

# %%
# Identificar filas duplicadas
duplicados = df[df.duplicated(keep=False)]

# Mostrar filas duplicadas
print(f"Filas duplicadas:{duplicados}")

# Contar cuántas filas duplicadas hay
num_duplicados = len(duplicados)
print(f"Número de filas duplicadas: {num_duplicados}\n")
# Out:
# Filas duplicadas:Empty DataFrame
# Columns: [Aseguradora, Tipo Plan, Tip Doc, Documento, Nombre Paciente, Sexo, Fecha Nacimiento, Edad, Grupo Etareo, Direccion De Residencia, Municipio, Localidad, Tipo Urgencia, Fecha Ingreso, Hora Ingreso, Fecha Atencion, Hora Atencion, Diagnostico principal de Ingreso, Codigo CIE10, Diagnostico Egreso, CIE10 Egreso]
# Index: []
#
# [0 rows x 21 columns]
# Número de filas duplicadas: 0

# %% [markdown]
# # Paso 2: Eliminar todas las filas duplicadas (considerando todas las columnas)

# %% [markdown]
# sirve para eliminar filas duplicadas de un conjunto de datos (DataFrame) en Python. Esto significa que, si hay dos o más filas con exactamente la misma información en todas las columnas, solo se conservará una de ellas, eliminando las demás.
#
# El resultado se guarda en una nueva variable (df_sin_duplicados), dejando el DataFrame original (df) sin cambios.

# %%
df_sin_duplicados = df.drop_duplicates()
df_sin_duplicados
# Out:
#                                     Aseguradora         Tipo Plan Tip Doc  \
# 1                         Salud Total EPS S S A  POS Contributivo      CC
# 2     Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      CC
# 4                     COMPENSAR MICRORED CAPITA  Capitado-Alianza      CC
# 8                                  Nueva Eps Sa  POS Contributivo      CC
# 9                                  Nueva Eps Sa  POS Contributivo      CC
# ...                                         ...               ...     ...
# 3637                       Eps Famisanar S A S   POS Contributivo      CC
# 3640                               Nueva Eps Sa  POS Contributivo      CC
# 3641                               Nueva Eps Sa  POS Contributivo      CC
# 3642                               Nueva Eps Sa  POS Contributivo      CC
# 3643  Hospital Universitario Clinica San Rafael        Particular      PA
#
#        Documento                   Nombre Paciente       Sexo  \
# 1     1000000290     DANNA LISBETH CARDOZO ANDRADE   FEMENINO
# 2     1000007712      MARIA XIMENA ARAQUE SANDOVAL   FEMENINO
# 4     1000020532         MICHELL VANESA LUQUE MORA   FEMENINO
# 8     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# 9     1000213784  GERALDINE YARITZA GARCIA GUEVARA   FEMENINO
# ...          ...                               ...        ...
# 3637    96354747          JOSE SANTOS CABRERA DIAZ  MASCULINO
# 3640      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3643   A25557795          AYLA LUCIA GUZMAN FLOREZ   FEMENINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo  \
# 1          25/12/1999  25 A  15 a 44 años
# 2          13/07/2002  22 A  15 a 44 años
# 4          04/01/2002  23 A  15 a 44 años
# 8          22/10/2001  23 A  15 a 44 años
# 9          22/10/2001  23 A  15 a 44 años
# ...               ...   ...           ...
# 3637       22/12/1976  48 A  45 a 59 años
# 3640       15/06/1934  90 A      60 y mas
# 3641       15/06/1934  90 A      60 y mas
# 3642       15/06/1934  90 A      60 y mas
# 3643       28/04/2023   2 A    1 a 4 años
#
#                     Direccion De Residencia  ...       Localidad  \
# 1                       KRA 5 BIS 12 09 SUR  ...   SAN CRISTOBAL
# 2           KR  3 B BIS  48  SUR  11  ESTE   ...   SAN CRISTOBAL
# 4                  CARE 11 ESTE 55 67 SUR    ...   SAN CRISTOBAL
# 8     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# 9     CLL 1ERA 2A 71 ESTE BR MIRADOR CENTRO  ...        SANTA FE
# ...                                     ...  ...             ...
# 3637                            CL 75 10 30  ...            USME
# 3640                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3641                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3642                  CALLE 11 SUR   12A 08  ...  ANTONIO NARIÑO
# 3643                     CR 8 B SUR 1 C 35   ...   SAN CRISTOBAL
#
#      Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion Hora Atencion  \
# 1          ADULTOS    2025-05-15   07:14:49       2025/05/15    08:54:00
# 2        Ortopedia    2025-05-16   08:39:17       2025/05/16    08:57:00
# 4          ADULTOS    2025-05-15   20:21:13       2025/05/15    22:20:00
# 8          ADULTOS    2025-05-12   08:05:41       2025/05/12    08:59:00
# 9          ADULTOS    2025-05-12   08:05:41       2025/05/12    09:12:00
# ...            ...           ...          ...            ...           ...
# 3637       ADULTOS    2025-05-15   10:39:58       2025/05/15    13:17:00
# 3640       ADULTOS    2025-05-14   14:53:20       2025/05/14    15:17:00
# 3641       ADULTOS    2025-05-15   17:50:12       2025/05/15    20:43:00
# 3642       ADULTOS    2025-05-17   10:16:15       2025/05/17    13:19:00
# 3643    PEDIATRICA    2025-05-14   22:31:36       2025/05/14    23:39:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 1      Contusion de la region lumbosacra y de la pelvis         S300
# 2                                 Contusion del tobillo         S900
# 4                                             Dispepsia         K30X
# 8     Trastornos inflamatorios pelvicos femeninos en...         N748
# 9     Trastornos inflamatorios pelvicos femeninos en...         N748
# ...                                                 ...          ...
# 3637                       Cuerpo extraño en la faringe         T172
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
# 3643  Otitis  media no supurativa, sin otra especifi...         H659
#
#                           Diagnostico Egreso CIE10 Egreso
# 1                        Fractura del coccix         S322
# 2         Esguinces y torceduras del tobillo         S934
# 4                                  Dispepsia         K30X
# 8                       Contractura muscular         M624
# 9                       Contractura muscular         M624
# ...                                      ...          ...
# 3637            Cuerpo extraño en el esofago         T181
# 3640        Hipertension esencial (primaria)         I10X
# 3641        Hipertension esencial (primaria)         I10X
# 3642                                     NaN          NaN
# 3643  Otra otitis media aguda, no supurativa         H651
#
# [1491 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso'],
#       dtype='object')

# %%
df_sin_duplicados['CIE10 Egreso'].isna().sum()
# Out:
# np.int64(487)

# %% [markdown]
# Este codigo filtra los en diagnosticos de egreso y diagnostico de egreso que pertenezcan a la vigilancia

# %%
# Las columnas son de tipo string
df_sin_duplicados['Codigo CIE10'] = df_sin_duplicados['Codigo CIE10'].astype(str)
df_sin_duplicados['CIE10 Egreso'] = df_sin_duplicados['CIE10 Egreso'].astype(str)
df_sin_duplicados['CIE10 Egreso'] = df_sin_duplicados['CIE10 Egreso'].astype(str).replace('nan', '')

# Crear condiciones de filtrado
condicion_ingreso = df_sin_duplicados['Codigo CIE10'].str.startswith(('I', 'J'))
condicion_egreso = df_sin_duplicados['CIE10 Egreso'].str.startswith(('I', 'J', ))

# %% [markdown]
# El sigueinte codigo permite anexar los diagnosticos ajenos a las j y a las i que pertenecen a la vigilancia centinela

# %%
# Lista de códigos específicos de egreso adicionales
codigos_adicionales = ["A419","C340","C341","C349","C450","C716","D022","D381","D386","D430",
                       "G468","R001","R092","R570","R571","R572","R579","R960","R961","R98X","Z515"]  #

#  condición para incluir los códigos específicos adicionales
condicion_codigos_adicionales = (df_sin_duplicados['CIE10 Egreso'].isin(codigos_adicionales)) & condicion_ingreso

condicion_vacios=  (df_sin_duplicados['CIE10 Egreso'] == '') & condicion_ingreso

# Combinar todas las condiciones
condicion_total = condicion_ingreso | condicion_egreso | condicion_codigos_adicionales| condicion_vacios

# Filtrar el DataFrame
df_sin_duplicados = df_sin_duplicados[condicion_total]

# %%
#df_sin_duplicados.to_excel("prueba.xlsx")

# %%
df_sin_duplicados['CIE10 Egreso'].unique()
# Out:
# array(['Z532', 'J329', 'J018', 'I499', '', 'J209', 'J219', 'Z000', 'J343',
#        'J00X', 'J980', 'J158', 'J159', 'J039', 'I208', 'J960', 'J303',
#        'J46X', 'J042', 'J019', 'J22X', 'M545', 'J410', 'M546', 'H651',
#        'I209', 'L031', 'I803', 'J129', 'J030', 'J029', 'J459', 'A689',
#        'J939', 'J050', 'A370', 'M940', 'I899', 'J342', 'M952', 'K922',
#        'G510', 'I828', 'G580', 'Z911', 'J449', 'I679', 'A419', 'I259',
#        'I64X', 'I10X', 'I509', 'J441', 'G252', 'G578', 'I845', 'I219',
#        'I469', 'N390', 'D381', 'C381', 'I200', 'J90X', 'I800', 'R51X',
#        'L039', 'I671', 'G442', 'N645', 'G468', 'I479', 'I868', 'I110',
#        'B349', 'I255', 'I832', 'K625', 'I872'], dtype=object)

# %%
# Eliminar registros donde  no cumpla las condiciones
condicion_egreso_final = df_sin_duplicados['CIE10 Egreso'].str.startswith(('I', 'J')) | df_sin_duplicados['CIE10 Egreso'].isin(codigos_adicionales) | (df_sin_duplicados['CIE10 Egreso'] == '')
df_sin_duplicados = df_sin_duplicados[condicion_egreso_final]

# %%
df_sin_duplicados
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#            Localidad Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion  \
# 31    CIUDAD BOLIVAR       ADULTOS    2025-05-17   13:08:39       2025/05/17
# 54    PUENTE ARANADA       ADULTOS    2025-05-14   21:25:10       2025/05/15
# 177    SAN CRISTOBAL       ADULTOS    2025-05-15   15:38:53       2025/05/15
# 228         FONTIBON       ADULTOS    2025-05-14   17:52:28       2025/05/14
# 279    SAN CRISTOBAL       ADULTOS    2025-05-15   12:14:57       2025/05/15
# ...              ...           ...           ...          ...            ...
# 3625  CIUDAD BOLIVAR       ADULTOS    2025-05-13   08:55:12       2025/05/13
# 3634         KENNEDY       ADULTOS    2025-05-13   12:21:05       2025/05/13
# 3640  ANTONIO NARIÑO       ADULTOS    2025-05-14   14:53:20       2025/05/14
# 3641  ANTONIO NARIÑO       ADULTOS    2025-05-15   17:50:12       2025/05/15
# 3642  ANTONIO NARIÑO       ADULTOS    2025-05-17   10:16:15       2025/05/17
#
#      Hora Atencion                   Diagnostico principal de Ingreso  \
# 31      13:31:00                             Cefalea debida a tension
# 54      04:28:00          Embolia y trombosis de vena no especificada
# 177     16:00:00                     Angina de pecho, no especificada
# 228     17:59:00               Rinofaringitis aguda (resfriado comun)
# 279     15:13:00    Infeccion aguda no especificada de las vias re...
# ...            ...                                                ...
# 3625    10:00:00            Celulitis de otras partes de los miembros
# 3634    17:01:00                  Insuficiencia ventricular izquierda
# 3640    15:17:00                     Hipertension esencial (primaria)
# 3641    20:43:00                     Hipertension esencial (primaria)
# 3642    13:19:00                     Hipertension esencial (primaria)
#
#      Codigo CIE10                                 Diagnostico Egreso  \
# 31           G442                 Sinusitis cronica, no especificada
# 54           I829                            Otras sinusitis  agudas
# 177          I209                 Arritmia cardiaca, no especificada
# 228          J00X                                                NaN
# 279          J22X                  Bronquitis aguda, no especificada
# ...           ...                                                ...
# 3625         L031  Flebitis y tromboflebitis de vasos superficial...
# 3634         I501        Insuficiencia venosa (cronica) (periferica)
# 3640         I10X                   Hipertension esencial (primaria)
# 3641         I10X                   Hipertension esencial (primaria)
# 3642         I10X                                                NaN
#
#      CIE10 Egreso
# 31           J329
# 54           J018
# 177          I499
# 228
# 279          J209
# ...           ...
# 3625         I800
# 3634         I872
# 3640         I10X
# 3641         I10X
# 3642
#
# [320 rows x 21 columns]

# %%
df_sin_duplicados['CIE10 Egreso'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Paso 3: Identificar duplicados basados en ciertas columnas ('Documento', "Fecha Ingreso")

# %% [markdown]
# Resumen general del código:
# - Busca filas duplicadas basándose solo en las columnas especificadas ('Documento', 'Fecha Ingreso', 'Codigo CIE10').
# - Guarda las filas duplicadas en un nuevo DataFrame (duplicados_columnas).
# - Cuenta cuántas filas duplicadas hay en total (num_duplicados_columnas).

# %%
df_sin_duplicados.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso'],
#       dtype='object')

# %%
duplicados_columnas = df_sin_duplicados[df_sin_duplicados.duplicated(subset=['Documento', 'Fecha Ingreso'], keep=False)]
num_duplicados_columnas = len(duplicados_columnas)

# %%
duplicados_columnas
# Out:
#                                     Aseguradora         Tipo Plan Tip Doc  \
# 1446  Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      TI
# 1447  Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      TI
# 2817                       Eps Famisanar S A S   POS Contributivo      CC
# 2818                       Eps Famisanar S A S   POS Contributivo      CC
# 3018  Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      CC
# 3019  Eps Y Medicina Prepagada Suramericana S A  POS Contributivo      CC
# 3194  Eps Y Medicina Prepagada Suramericana S A    Pos Subsidiado      CC
# 3195  Eps Y Medicina Prepagada Suramericana S A    Pos Subsidiado      CC
# 3205                 CAPITAL SALUD EPS-S S.A.S.  POS Contributivo      CC
# 3206                 CAPITAL SALUD EPS-S S.A.S.  POS Contributivo      CC
# 3554                               Nueva Eps Sa  POS Contributivo      CC
# 3555                               Nueva Eps Sa  POS Contributivo      CC
#
#        Documento                   Nombre Paciente       Sexo  \
# 1446  1031425754        MIGUEL ANGEL SUAREZ MEDINA  MASCULINO
# 1447  1031425754        MIGUEL ANGEL SUAREZ MEDINA  MASCULINO
# 2817    51585229      NATIVIDAD  MARTINEZ LIBERATO   FEMENINO
# 2818    51585229      NATIVIDAD  MARTINEZ LIBERATO   FEMENINO
# 3018    52299168          ROSA INES OLAYA GANTIVAR   FEMENINO
# 3019    52299168          ROSA INES OLAYA GANTIVAR   FEMENINO
# 3194    53178068            LUZ AMANDA RUIZ RINCON   FEMENINO
# 3195    53178068            LUZ AMANDA RUIZ RINCON   FEMENINO
# 3205    55100028       MARIA LILIA COLLAZOS VARGAS   FEMENINO
# 3206    55100028       MARIA LILIA COLLAZOS VARGAS   FEMENINO
# 3554    80724733  DARIO ALEJANDRO APONTE RODRIGUEZ  MASCULINO
# 3555    80724733  DARIO ALEJANDRO APONTE RODRIGUEZ  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo    Direccion De Residencia  ...  \
# 1446       30/03/2009  16 A  15 a 44 años              CL 29C  6C15E  ...
# 1447       30/03/2009  16 A  15 a 44 años              CL 29C  6C15E  ...
# 2817       23/11/1960  64 A      60 y mas  km 0 antigua via la llano  ...
# 2818       23/11/1960  64 A      60 y mas  km 0 antigua via la llano  ...
# 3018       25/09/1974  50 A  45 a 59 años     CL 68 BIS SUR 79 B 42   ...
# 3019       25/09/1974  50 A  45 a 59 años     CL 68 BIS SUR 79 B 42   ...
# 3194       05/08/1985  39 A  15 a 44 años  KRA 14 A SUR   75A 06 SUR  ...
# 3195       05/08/1985  39 A  15 a 44 años  KRA 14 A SUR   75A 06 SUR  ...
# 3205       22/03/1958  67 A      60 y mas       CALLE 68I 31 04 SUR   ...
# 3206       22/03/1958  67 A      60 y mas       CALLE 68I 31 04 SUR   ...
# 3554       24/07/1982  42 A  15 a 44 años          CL 145 B 47 27     ...
# 3555       24/07/1982  42 A  15 a 44 años          CL 145 B 47 27     ...
#
#            Localidad Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion  \
# 1446     BOGOTA D.C.       ADULTOS    2025-05-17   13:25:17       2025/05/17
# 1447     BOGOTA D.C.       ADULTOS    2025-05-17   13:25:17       2025/05/18
# 2817            USME       ADULTOS    2025-05-13   18:08:48       2025/05/13
# 2818            USME       ADULTOS    2025-05-13   18:08:48       2025/05/13
# 3018            BOSA       ADULTOS    2025-05-17   21:14:44       2025/05/18
# 3019            BOSA       ADULTOS    2025-05-17   21:14:44       2025/05/18
# 3194            USME       ADULTOS    2025-05-13   09:09:23       2025/05/13
# 3195            USME       ADULTOS    2025-05-13   09:09:23       2025/05/13
# 3205  CIUDAD BOLIVAR       ADULTOS    2025-05-15   22:15:49       2025/05/16
# 3206  CIUDAD BOLIVAR       ADULTOS    2025-05-15   22:15:49       2025/05/16
# 3554            SUBA       ADULTOS    2025-05-12   10:26:03       2025/05/12
# 3555            SUBA       ADULTOS    2025-05-12   10:26:03       2025/05/12
#
#      Hora Atencion                   Diagnostico principal de Ingreso  \
# 1446    20:32:00               Rinofaringitis aguda (resfriado comun)
# 1447    08:12:00                    Faringitis aguda, no especificada
# 2817    18:25:00                       Fibrilacion y aleteo auricular
# 2818    19:01:00                       Fibrilacion y aleteo auricular
# 3018    00:53:00    Enfermedad de las vias respiratorias superiore...
# 3019    08:13:00                    Bronquitis aguda, no especificada
# 3194    13:54:00                    Bronquitis aguda, no especificada
# 3195    14:19:00                    Bronquitis aguda, no especificada
# 3205    01:23:00                                              Cefalea
# 3206    13:41:00                            Consulta, no especificada
# 3554    10:29:00                    Bronquitis aguda, no especificada
# 3555    10:56:00                    Bronquitis aguda, no especificada
#
#      Codigo CIE10                     Diagnostico Egreso CIE10 Egreso
# 1446         J00X                                    NaN
# 1447         J029                                    NaN
# 2817         I48X                                    NaN
# 2818         I48X                                    NaN
# 3018         J399                                    NaN
# 3019         J209                                    NaN
# 3194         J209      Bronquitis aguda, no especificada         J209
# 3195         J209      Bronquitis aguda, no especificada         J209
# 3205         R51X  Varices en otros sitios especificados         I868
# 3206         Z719  Varices en otros sitios especificados         I868
# 3554         J209      Bronquitis aguda, no especificada         J209
# 3555         J209      Bronquitis aguda, no especificada         J209
#
# [12 rows x 21 columns]

# %%
print(f"Número de filas duplicadas basadas :en las columnas: {num_duplicados_columnas}\n")
# Out:
# Número de filas duplicadas basadas :en las columnas: 12

# %% [markdown]
# # Paso 4: Eliminar duplicados basados en ciertas columnas ('col1', 'col2')

# %% [markdown]
# - Identifica duplicados considerando únicamente las columnas 'Documento', 'Fecha Ingreso', y 'Codigo CIE10'.
# - En cada grupo de duplicados, elimina todas las filas excepto la última.
# - Devuelve un nuevo DataFrame sin duplicados llamado df_sin_duplicados_columnas.

# %%
df_sin_duplicados_columnas = df_sin_duplicados.drop_duplicates(subset=['Documento', 'Fecha Ingreso'], keep='last')
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#            Localidad Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion  \
# 31    CIUDAD BOLIVAR       ADULTOS    2025-05-17   13:08:39       2025/05/17
# 54    PUENTE ARANADA       ADULTOS    2025-05-14   21:25:10       2025/05/15
# 177    SAN CRISTOBAL       ADULTOS    2025-05-15   15:38:53       2025/05/15
# 228         FONTIBON       ADULTOS    2025-05-14   17:52:28       2025/05/14
# 279    SAN CRISTOBAL       ADULTOS    2025-05-15   12:14:57       2025/05/15
# ...              ...           ...           ...          ...            ...
# 3625  CIUDAD BOLIVAR       ADULTOS    2025-05-13   08:55:12       2025/05/13
# 3634         KENNEDY       ADULTOS    2025-05-13   12:21:05       2025/05/13
# 3640  ANTONIO NARIÑO       ADULTOS    2025-05-14   14:53:20       2025/05/14
# 3641  ANTONIO NARIÑO       ADULTOS    2025-05-15   17:50:12       2025/05/15
# 3642  ANTONIO NARIÑO       ADULTOS    2025-05-17   10:16:15       2025/05/17
#
#      Hora Atencion                   Diagnostico principal de Ingreso  \
# 31      13:31:00                             Cefalea debida a tension
# 54      04:28:00          Embolia y trombosis de vena no especificada
# 177     16:00:00                     Angina de pecho, no especificada
# 228     17:59:00               Rinofaringitis aguda (resfriado comun)
# 279     15:13:00    Infeccion aguda no especificada de las vias re...
# ...            ...                                                ...
# 3625    10:00:00            Celulitis de otras partes de los miembros
# 3634    17:01:00                  Insuficiencia ventricular izquierda
# 3640    15:17:00                     Hipertension esencial (primaria)
# 3641    20:43:00                     Hipertension esencial (primaria)
# 3642    13:19:00                     Hipertension esencial (primaria)
#
#      Codigo CIE10                                 Diagnostico Egreso  \
# 31           G442                 Sinusitis cronica, no especificada
# 54           I829                            Otras sinusitis  agudas
# 177          I209                 Arritmia cardiaca, no especificada
# 228          J00X                                                NaN
# 279          J22X                  Bronquitis aguda, no especificada
# ...           ...                                                ...
# 3625         L031  Flebitis y tromboflebitis de vasos superficial...
# 3634         I501        Insuficiencia venosa (cronica) (periferica)
# 3640         I10X                   Hipertension esencial (primaria)
# 3641         I10X                   Hipertension esencial (primaria)
# 3642         I10X                                                NaN
#
#      CIE10 Egreso
# 31           J329
# 54           J018
# 177          I499
# 228
# 279          J209
# ...           ...
# 3625         I800
# 3634         I872
# 3640         I10X
# 3641         I10X
# 3642
#
# [314 rows x 21 columns]

# %% [markdown]
# Guarda el DataFrame df_sin_duplicados_columnas en un archivo Excel llamado Base.xlsx.
#
# index=False: Evita incluir la columna de índices del DataFrame en el archivo.

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso'],
#       dtype='object')

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#            Localidad Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion  \
# 31    CIUDAD BOLIVAR       ADULTOS    2025-05-17   13:08:39       2025/05/17
# 54    PUENTE ARANADA       ADULTOS    2025-05-14   21:25:10       2025/05/15
# 177    SAN CRISTOBAL       ADULTOS    2025-05-15   15:38:53       2025/05/15
# 228         FONTIBON       ADULTOS    2025-05-14   17:52:28       2025/05/14
# 279    SAN CRISTOBAL       ADULTOS    2025-05-15   12:14:57       2025/05/15
# ...              ...           ...           ...          ...            ...
# 3625  CIUDAD BOLIVAR       ADULTOS    2025-05-13   08:55:12       2025/05/13
# 3634         KENNEDY       ADULTOS    2025-05-13   12:21:05       2025/05/13
# 3640  ANTONIO NARIÑO       ADULTOS    2025-05-14   14:53:20       2025/05/14
# 3641  ANTONIO NARIÑO       ADULTOS    2025-05-15   17:50:12       2025/05/15
# 3642  ANTONIO NARIÑO       ADULTOS    2025-05-17   10:16:15       2025/05/17
#
#      Hora Atencion                   Diagnostico principal de Ingreso  \
# 31      13:31:00                             Cefalea debida a tension
# 54      04:28:00          Embolia y trombosis de vena no especificada
# 177     16:00:00                     Angina de pecho, no especificada
# 228     17:59:00               Rinofaringitis aguda (resfriado comun)
# 279     15:13:00    Infeccion aguda no especificada de las vias re...
# ...            ...                                                ...
# 3625    10:00:00            Celulitis de otras partes de los miembros
# 3634    17:01:00                  Insuficiencia ventricular izquierda
# 3640    15:17:00                     Hipertension esencial (primaria)
# 3641    20:43:00                     Hipertension esencial (primaria)
# 3642    13:19:00                     Hipertension esencial (primaria)
#
#      Codigo CIE10                                 Diagnostico Egreso  \
# 31           G442                 Sinusitis cronica, no especificada
# 54           I829                            Otras sinusitis  agudas
# 177          I209                 Arritmia cardiaca, no especificada
# 228          J00X                                                NaN
# 279          J22X                  Bronquitis aguda, no especificada
# ...           ...                                                ...
# 3625         L031  Flebitis y tromboflebitis de vasos superficial...
# 3634         I501        Insuficiencia venosa (cronica) (periferica)
# 3640         I10X                   Hipertension esencial (primaria)
# 3641         I10X                   Hipertension esencial (primaria)
# 3642         I10X                                                NaN
#
#      CIE10 Egreso
# 31           J329
# 54           J018
# 177          I499
# 228
# 279          J209
# ...           ...
# 3625         I800
# 3634         I872
# 3640         I10X
# 3641         I10X
# 3642
#
# [314 rows x 21 columns]

# %%
import pandas as pd

def reemplazar_ingreso_por_egreso(row):
    ingreso = str(row['Codigo CIE10']).strip().upper()
    egreso = str(row['CIE10 Egreso']).strip().upper()

    # Si son iguales, no hacer nada
    if ingreso == egreso:
        return row

     # Si ingreso empieza por I o J y egreso por otra letra → no se hace nada
    if ingreso.startswith(('I', 'J')) and not egreso.startswith(('I', 'J')):
        return row


    # Si ingreso no empieza por I o J y egreso sí → se reemplaza ingreso
    if not ingreso.startswith(('I', 'J')) and egreso.startswith(('I', 'J')):
        row['Codigo CIE10'] = egreso
        row["Diagnostico principal de Ingreso"] = row['Diagnostico Egreso']

    # En los demás casos, no se hace nada
    return row

# %%
# Aplicar la función fila por fila
df_sin_duplicados_columnas = df_sin_duplicados_columnas.apply(reemplazar_ingreso_por_egreso, axis=1)

# %%
excluir_codigos=["I770", "I952", "I970", "I971", "I972", "I978", "I979", "J341", "J342", "J380", "J386", "J690",
                 "J691", "J698", "J700", "J701", "J702",
                 "J703", "J704", "J708", "J709", "J940", "J941", "J942", "J950", "J951", "J952", "J953", "J954", "J955", "J958", "J959", "J986" ]

# %% [markdown]
# Se está quedando solo con las filas en las que ambos valores (el de 'Codigo CIE10' y el de 'CIE10 Egreso') no estén en la lista excluir_codigos.

# %% [markdown]
# # tarea:   Escribir en palabras

# %%
df_sin_duplicados_columnas = df_sin_duplicados_columnas[
    ~df_sin_duplicados_columnas['Codigo CIE10'].isin(excluir_codigos) &
    ~df_sin_duplicados_columnas['CIE10 Egreso'].isin(excluir_codigos)
]

# %%
df_sin_duplicados_columnas.to_excel("Base_1_san_rafael.xlsx",index=False)

# %% [markdown]
# # parte 2

# %% [markdown]
# 1.	Unidad centinela: En la base se registra la unidad centinela correspondiente:
# - CAPS CHAPINERO
# - HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# - USS MEISSEN
# - USS KENNEDY

# %%
df_sin_duplicados_columnas["Unidad centinela"]="HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL"

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Tipo Urgencia Fecha Ingreso Hora Ingreso Fecha Atencion Hora Atencion  \
# 31         ADULTOS    2025-05-17   13:08:39       2025/05/17    13:31:00
# 54         ADULTOS    2025-05-14   21:25:10       2025/05/15    04:28:00
# 177        ADULTOS    2025-05-15   15:38:53       2025/05/15    16:00:00
# 228        ADULTOS    2025-05-14   17:52:28       2025/05/14    17:59:00
# 279        ADULTOS    2025-05-15   12:14:57       2025/05/15    15:13:00
# ...            ...           ...          ...            ...           ...
# 3625       ADULTOS    2025-05-13   08:55:12       2025/05/13    10:00:00
# 3634       ADULTOS    2025-05-13   12:21:05       2025/05/13    17:01:00
# 3640       ADULTOS    2025-05-14   14:53:20       2025/05/14    15:17:00
# 3641       ADULTOS    2025-05-15   17:50:12       2025/05/15    20:43:00
# 3642       ADULTOS    2025-05-17   10:16:15       2025/05/17    13:19:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 31                   Sinusitis cronica, no especificada         J329
# 54          Embolia y trombosis de vena no especificada         I829
# 177                    Angina de pecho, no especificada         I209
# 228              Rinofaringitis aguda (resfriado comun)         J00X
# 279   Infeccion aguda no especificada de las vias re...         J22X
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634                Insuficiencia ventricular izquierda         I501
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
#
#                                      Diagnostico Egreso CIE10 Egreso  \
# 31                   Sinusitis cronica, no especificada         J329
# 54                              Otras sinusitis  agudas         J018
# 177                  Arritmia cardiaca, no especificada         I499
# 228                                                 NaN
# 279                   Bronquitis aguda, no especificada         J209
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634        Insuficiencia venosa (cronica) (periferica)         I872
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN
#
#                                Unidad centinela
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# ...                                         ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
#
# [312 rows x 22 columns]

# %%
df_sin_duplicados_columnas['Localidad'].unique()
# Out:
# array(['CIUDAD BOLIVAR', 'PUENTE ARANADA', 'SAN CRISTOBAL', 'FONTIBON',
#        'BOGOTA D.C.', 'RAFAEL URIBE', 'KENNEDY', 'BOSA', 'SANTA FE',
#        'USME', 'TUNJUELITO', 'MARTIRES', 'ANTONIO NARIÑO', 'CANDELARIA',
#        'ENGATIVA', 'SUBA', 'CHAPINERO'], dtype=object)

# %% [markdown]
# ### 	Localidad unidad centinela: Se diligencia la localidad en número y letra:

# %%
# Crear el diccionario con el formato requerido
mapeo_localidades = {
    "CAPS CHAPINERO" : "12. BARRIOS UNIDOS",
    "HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL": "4. SAN CRISTOBAL",
    "USS MEISSEN" : "19. CIUDAD BOLIVAR",
    "USS KENNEDY" : "8. KENNEDY"
}

# %%
df_sin_duplicados_columnas["Localidad unidad centinela"] = df_sin_duplicados_columnas["Unidad centinela"].map(mapeo_localidades)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Fecha Ingreso Hora Ingreso Fecha Atencion Hora Atencion  \
# 31      2025-05-17   13:08:39       2025/05/17    13:31:00
# 54      2025-05-14   21:25:10       2025/05/15    04:28:00
# 177     2025-05-15   15:38:53       2025/05/15    16:00:00
# 228     2025-05-14   17:52:28       2025/05/14    17:59:00
# 279     2025-05-15   12:14:57       2025/05/15    15:13:00
# ...            ...          ...            ...           ...
# 3625    2025-05-13   08:55:12       2025/05/13    10:00:00
# 3634    2025-05-13   12:21:05       2025/05/13    17:01:00
# 3640    2025-05-14   14:53:20       2025/05/14    15:17:00
# 3641    2025-05-15   17:50:12       2025/05/15    20:43:00
# 3642    2025-05-17   10:16:15       2025/05/17    13:19:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 31                   Sinusitis cronica, no especificada         J329
# 54          Embolia y trombosis de vena no especificada         I829
# 177                    Angina de pecho, no especificada         I209
# 228              Rinofaringitis aguda (resfriado comun)         J00X
# 279   Infeccion aguda no especificada de las vias re...         J22X
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634                Insuficiencia ventricular izquierda         I501
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
#
#                                      Diagnostico Egreso CIE10 Egreso  \
# 31                   Sinusitis cronica, no especificada         J329
# 54                              Otras sinusitis  agudas         J018
# 177                  Arritmia cardiaca, no especificada         I499
# 228                                                 NaN
# 279                   Bronquitis aguda, no especificada         J209
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634        Insuficiencia venosa (cronica) (periferica)         I872
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN
#
#                                Unidad centinela Localidad unidad centinela
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
# [312 rows x 23 columns]

# %% [markdown]
# ### MES: En número

# %%
# Convertir a tipo datetime
df_sin_duplicados_columnas['Fecha Ingreso'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha Ingreso'])

# Extraer el número del mes
df_sin_duplicados_columnas['MES'] = df_sin_duplicados_columnas['Fecha Ingreso'].dt.month

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Hora Ingreso Fecha Atencion Hora Atencion  \
# 31     13:08:39       2025/05/17    13:31:00
# 54     21:25:10       2025/05/15    04:28:00
# 177    15:38:53       2025/05/15    16:00:00
# 228    17:52:28       2025/05/14    17:59:00
# 279    12:14:57       2025/05/15    15:13:00
# ...           ...            ...           ...
# 3625   08:55:12       2025/05/13    10:00:00
# 3634   12:21:05       2025/05/13    17:01:00
# 3640   14:53:20       2025/05/14    15:17:00
# 3641   17:50:12       2025/05/15    20:43:00
# 3642   10:16:15       2025/05/17    13:19:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 31                   Sinusitis cronica, no especificada         J329
# 54          Embolia y trombosis de vena no especificada         I829
# 177                    Angina de pecho, no especificada         I209
# 228              Rinofaringitis aguda (resfriado comun)         J00X
# 279   Infeccion aguda no especificada de las vias re...         J22X
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634                Insuficiencia ventricular izquierda         I501
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
#
#                                      Diagnostico Egreso CIE10 Egreso  \
# 31                   Sinusitis cronica, no especificada         J329
# 54                              Otras sinusitis  agudas         J018
# 177                  Arritmia cardiaca, no especificada         I499
# 228                                                 NaN
# 279                   Bronquitis aguda, no especificada         J209
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634        Insuficiencia venosa (cronica) (periferica)         I872
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN
#
#                                Unidad centinela Localidad unidad centinela MES
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# ...                                         ...                        ...  ..
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
#
# [312 rows x 24 columns]

# %% [markdown]
# ### Fecha consulta: Que quede registro de formato fecha dd/mm/aaaa

# %%
df_sin_duplicados_columnas['Fecha consulta'] = df_sin_duplicados_columnas['Fecha Ingreso'].dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Fecha Atencion Hora Atencion  \
# 31       2025/05/17    13:31:00
# 54       2025/05/15    04:28:00
# 177      2025/05/15    16:00:00
# 228      2025/05/14    17:59:00
# 279      2025/05/15    15:13:00
# ...             ...           ...
# 3625     2025/05/13    10:00:00
# 3634     2025/05/13    17:01:00
# 3640     2025/05/14    15:17:00
# 3641     2025/05/15    20:43:00
# 3642     2025/05/17    13:19:00
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 31                   Sinusitis cronica, no especificada         J329
# 54          Embolia y trombosis de vena no especificada         I829
# 177                    Angina de pecho, no especificada         I209
# 228              Rinofaringitis aguda (resfriado comun)         J00X
# 279   Infeccion aguda no especificada de las vias re...         J22X
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634                Insuficiencia ventricular izquierda         I501
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
#
#                                      Diagnostico Egreso CIE10 Egreso  \
# 31                   Sinusitis cronica, no especificada         J329
# 54                              Otras sinusitis  agudas         J018
# 177                  Arritmia cardiaca, no especificada         I499
# 228                                                 NaN
# 279                   Bronquitis aguda, no especificada         J209
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634        Insuficiencia venosa (cronica) (periferica)         I872
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta
# 31     5     17/05/2025
# 54     5     14/05/2025
# 177    5     15/05/2025
# 228    5     14/05/2025
# 279    5     15/05/2025
# ...   ..            ...
# 3625   5     13/05/2025
# 3634   5     13/05/2025
# 3640   5     14/05/2025
# 3641   5     15/05/2025
# 3642   5     17/05/2025
#
# [312 rows x 25 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta'],
#       dtype='object')

# %% [markdown]
# #### Semana epidemiológica: De acuerdo a la semana epidemiológica correspondiente, pero si ya quedó ese código en la otra base, no se si en esta base sea necesario.

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
df_sin_duplicados_columnas["Fecha consulta"] = pd.to_datetime(
    df_sin_duplicados_columnas["Fecha consulta"],
    format="%d/%m/%Y"   # Ajusta según tu necesidad real
)

#

# %%
import pandas as pd

semanas_ordenadas = sorted(semanas_2025.keys())
bins = []

for i in semanas_ordenadas:
    # Inicio exacto tal como está en el diccionario
    inicio = pd.to_datetime(semanas_2025[i][0])
    # Para que 'fin' quede incluido, le sumamos 1 día y usamos el bin abierto
    # a la derecha => [inicio, fin+1)
    bins.append(inicio)

# El "cierre" del último bin será la fecha final de la última semana + 1 día
fin_ultima_sem = pd.to_datetime(semanas_2025[semanas_ordenadas[-1]][1])
bins.append(fin_ultima_sem + pd.Timedelta(days=1))

# Etiquetas
labels = [f"{i}" for i in semanas_ordenadas]

df_sin_duplicados_columnas["Semana epidemiologica"] = pd.cut(
    df_sin_duplicados_columnas["Fecha consulta"],
    bins=bins,
    labels=labels,
    right=False  # ¡Cerramos por la izquierda [inicio, fin)!
)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Hora Atencion                   Diagnostico principal de Ingreso  \
# 31      13:31:00                   Sinusitis cronica, no especificada
# 54      04:28:00          Embolia y trombosis de vena no especificada
# 177     16:00:00                     Angina de pecho, no especificada
# 228     17:59:00               Rinofaringitis aguda (resfriado comun)
# 279     15:13:00    Infeccion aguda no especificada de las vias re...
# ...            ...                                                ...
# 3625    10:00:00    Flebitis y tromboflebitis de vasos superficial...
# 3634    17:01:00                  Insuficiencia ventricular izquierda
# 3640    15:17:00                     Hipertension esencial (primaria)
# 3641    20:43:00                     Hipertension esencial (primaria)
# 3642    13:19:00                     Hipertension esencial (primaria)
#
#      Codigo CIE10                                 Diagnostico Egreso  \
# 31           J329                 Sinusitis cronica, no especificada
# 54           I829                            Otras sinusitis  agudas
# 177          I209                 Arritmia cardiaca, no especificada
# 228          J00X                                                NaN
# 279          J22X                  Bronquitis aguda, no especificada
# ...           ...                                                ...
# 3625         I800  Flebitis y tromboflebitis de vasos superficial...
# 3634         I501        Insuficiencia venosa (cronica) (periferica)
# 3640         I10X                   Hipertension esencial (primaria)
# 3641         I10X                   Hipertension esencial (primaria)
# 3642         I10X                                                NaN
#
#      CIE10 Egreso                           Unidad centinela  \
# 31           J329  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 54           J018  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 177          I499  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 228                HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 279          J209  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# ...           ...                                        ...
# 3625         I800  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3634         I872  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3640         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3641         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3642               HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica
# 31             4. SAN CRISTOBAL   5     2025-05-17                    20
# 54             4. SAN CRISTOBAL   5     2025-05-14                    20
# 177            4. SAN CRISTOBAL   5     2025-05-15                    20
# 228            4. SAN CRISTOBAL   5     2025-05-14                    20
# 279            4. SAN CRISTOBAL   5     2025-05-15                    20
# ...                         ...  ..            ...                   ...
# 3625           4. SAN CRISTOBAL   5     2025-05-13                    20
# 3634           4. SAN CRISTOBAL   5     2025-05-13                    20
# 3640           4. SAN CRISTOBAL   5     2025-05-14                    20
# 3641           4. SAN CRISTOBAL   5     2025-05-15                    20
# 3642           4. SAN CRISTOBAL   5     2025-05-17                    20
#
# [312 rows x 26 columns]

# %% [markdown]
# #### Fecha de nacimiento

# %%
df_sin_duplicados_columnas['Fecha Nacimiento']
# Out:
# 31      25/01/2001
# 54      26/10/2001
# 177     25/02/1958
# 228     22/03/2000
# 279     11/07/1999
#            ...
# 3625    02/06/1968
# 3634    11/07/1957
# 3640    15/06/1934
# 3641    15/06/1934
# 3642    15/06/1934
# Name: Fecha Nacimiento, Length: 312, dtype: object

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['Fecha Nacimiento'], format='%d/%m/%Y', errors='coerce').dt.strftime('%d/%m/%Y')

# %%
  df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#                        Diagnostico principal de Ingreso Codigo CIE10  \
# 31                   Sinusitis cronica, no especificada         J329
# 54          Embolia y trombosis de vena no especificada         I829
# 177                    Angina de pecho, no especificada         I209
# 228              Rinofaringitis aguda (resfriado comun)         J00X
# 279   Infeccion aguda no especificada de las vias re...         J22X
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634                Insuficiencia ventricular izquierda         I501
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                   Hipertension esencial (primaria)         I10X
#
#                                      Diagnostico Egreso CIE10 Egreso  \
# 31                   Sinusitis cronica, no especificada         J329
# 54                              Otras sinusitis  agudas         J018
# 177                  Arritmia cardiaca, no especificada         I499
# 228                                                 NaN
# 279                   Bronquitis aguda, no especificada         J209
# ...                                                 ...          ...
# 3625  Flebitis y tromboflebitis de vasos superficial...         I800
# 3634        Insuficiencia venosa (cronica) (periferica)         I872
# 3640                   Hipertension esencial (primaria)         I10X
# 3641                   Hipertension esencial (primaria)         I10X
# 3642                                                NaN
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento
# 31     5     2025-05-17                    20          25/01/2001
# 54     5     2025-05-14                    20          26/10/2001
# 177    5     2025-05-15                    20          25/02/1958
# 228    5     2025-05-14                    20          22/03/2000
# 279    5     2025-05-15                    20          11/07/1999
# ...   ..            ...                   ...                 ...
# 3625   5     2025-05-13                    20          02/06/1968
# 3634   5     2025-05-13                    20          11/07/1957
# 3640   5     2025-05-14                    20          15/06/1934
# 3641   5     2025-05-15                    20          15/06/1934
# 3642   5     2025-05-17                    20          15/06/1934
#
# [312 rows x 27 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento'],
#       dtype='object')

# %% [markdown]
# #### Tipo de documento: En caso de que el espacio se encuentre en blanco o con raya al piso, generar en ese espacio 999

# %%
df_sin_duplicados_columnas['Tip Doc'].unique()
# Out:
# array(['CC', 'NU ', 'TI', 'CN', 'PT'], dtype=object)

# %%
# Reemplazar espacios en blanco o rayas al piso por "999"
df_sin_duplicados_columnas['Tipo de documento'] = df_sin_duplicados_columnas['Tip Doc'].replace(["", "_"], "999")

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Codigo CIE10                                 Diagnostico Egreso  \
# 31           J329                 Sinusitis cronica, no especificada
# 54           I829                            Otras sinusitis  agudas
# 177          I209                 Arritmia cardiaca, no especificada
# 228          J00X                                                NaN
# 279          J22X                  Bronquitis aguda, no especificada
# ...           ...                                                ...
# 3625         I800  Flebitis y tromboflebitis de vasos superficial...
# 3634         I501        Insuficiencia venosa (cronica) (periferica)
# 3640         I10X                   Hipertension esencial (primaria)
# 3641         I10X                   Hipertension esencial (primaria)
# 3642         I10X                                                NaN
#
#      CIE10 Egreso                           Unidad centinela  \
# 31           J329  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 54           J018  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 177          I499  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 228                HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 279          J209  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# ...           ...                                        ...
# 3625         I800  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3634         I872  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3640         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3641         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3642               HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 31             4. SAN CRISTOBAL   5     2025-05-17                    20
# 54             4. SAN CRISTOBAL   5     2025-05-14                    20
# 177            4. SAN CRISTOBAL   5     2025-05-15                    20
# 228            4. SAN CRISTOBAL   5     2025-05-14                    20
# 279            4. SAN CRISTOBAL   5     2025-05-15                    20
# ...                         ...  ..            ...                   ...
# 3625           4. SAN CRISTOBAL   5     2025-05-13                    20
# 3634           4. SAN CRISTOBAL   5     2025-05-13                    20
# 3640           4. SAN CRISTOBAL   5     2025-05-14                    20
# 3641           4. SAN CRISTOBAL   5     2025-05-15                    20
# 3642           4. SAN CRISTOBAL   5     2025-05-17                    20
#
#      Fecha de nacimiento Tipo de documento
# 31            25/01/2001                CC
# 54            26/10/2001                CC
# 177           25/02/1958                CC
# 228           22/03/2000                CC
# 279           11/07/1999                CC
# ...                  ...               ...
# 3625          02/06/1968                CC
# 3634          11/07/1957                CC
# 3640          15/06/1934                CC
# 3641          15/06/1934                CC
# 3642          15/06/1934                CC
#
# [312 rows x 28 columns]

# %%
df_sin_duplicados_columnas["Tipo de documento"].unique()
# Out:
# array(['CC', 'NU ', 'TI', 'CN', 'PT'], dtype=object)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento'],
#       dtype='object')

# %% [markdown]
# ####	Edad en meses: Calcular en caso de que la edad en años sea cero 0.
# #### Edad años: Calcular de acuerdo a las variables fecha de nacimiento y fecha consulta.

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta

# Convertir las columnas a tipo datetime
df_sin_duplicados_columnas["Fecha de nacimiento"] = pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento'], format='%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta'], format='%d/%m/%Y')

# Función para calcular años y meses
def calcular_edad(row):
    nacimiento = row['Fecha de nacimiento']
    consulta = row['Fecha consulta']

    # Calcular la diferencia con relativedelta (maneja días/meses/años)
    delta = relativedelta(consulta, nacimiento)

    # Si hay al menos 1 año completo
    if delta.years >= 1:
        return pd.Series([delta.years, np.nan])
    else:
        # Calcular meses totales (años * 12 + meses)
        meses_totales = delta.years * 12 + delta.months
        return pd.Series([0, meses_totales])

# Aplicar la función y crear las columnas
df_sin_duplicados_columnas[['Edad años', 'Edad en meses']] = df_sin_duplicados_columnas.apply(calcular_edad, axis=1)

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento']).dt.strftime('%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta']).dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      CIE10 Egreso                           Unidad centinela  \
# 31           J329  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 54           J018  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 177          I499  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 228                HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 279          J209  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# ...           ...                                        ...
# 3625         I800  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3634         I872  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3640         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3641         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3642               HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 31             4. SAN CRISTOBAL   5     17/05/2025                    20
# 54             4. SAN CRISTOBAL   5     14/05/2025                    20
# 177            4. SAN CRISTOBAL   5     15/05/2025                    20
# 228            4. SAN CRISTOBAL   5     14/05/2025                    20
# 279            4. SAN CRISTOBAL   5     15/05/2025                    20
# ...                         ...  ..            ...                   ...
# 3625           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3634           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3640           4. SAN CRISTOBAL   5     14/05/2025                    20
# 3641           4. SAN CRISTOBAL   5     15/05/2025                    20
# 3642           4. SAN CRISTOBAL   5     17/05/2025                    20
#
#      Fecha de nacimiento Tipo de documento Edad años Edad en meses
# 31            25/01/2001                CC      24.0           NaN
# 54            26/10/2001                CC      23.0           NaN
# 177           25/02/1958                CC      67.0           NaN
# 228           22/03/2000                CC      25.0           NaN
# 279           11/07/1999                CC      25.0           NaN
# ...                  ...               ...       ...           ...
# 3625          02/06/1968                CC      56.0           NaN
# 3634          11/07/1957                CC      67.0           NaN
# 3640          15/06/1934                CC      90.0           NaN
# 3641          15/06/1934                CC      90.0           NaN
# 3642          15/06/1934                CC      90.0           NaN
#
# [312 rows x 30 columns]

# %%
df_sin_duplicados_columnas["Edad en meses"].unique()
# Out:
# array([nan,  1.,  2., 10.,  0.,  9.,  8.,  6.,  5.,  3.,  4.,  7.])

# %%
df_sin_duplicados_columnas[df_sin_duplicados_columnas["Edad en meses"]==0]
# Out:
#                                             Aseguradora         Tipo Plan  \
# 476   Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 1093                                       Nueva Eps Sa    Pos Subsidiado
# 1297          Eps Y Medicina Prepagada Suramericana S A    Pos Subsidiado
# 2423          Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 2431  Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 2450  Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
#
#      Tip Doc       Documento                           Nombre Paciente  \
# 476      NU       1013703159                GUADALUPE  PINEDA CALDERON
# 1093     NU       1023996459               LIAM JERONIMO CASTRO MEDINA
# 1297     NU       1028625445              LIA ANTONELLA TERRAZA MENDEZ
# 2423      CN  25043710131611    HIJO DE ANGELA VIIVANA RODRIGUEZ PARRA
# 2431      CN  25046910133388  HIJO DE PAULA VALENTINA JIMENEZ MARTINEZ
# 2450      CN  25057910142031                 MARTIN  CAMPUZANO FUERTES
#
#            Sexo Fecha Nacimiento  Edad Grupo Etareo  \
# 476    FEMENINO       29/04/2025   0 M      < 1 año
# 1093  MASCULINO       26/04/2025   0 M      < 1 año
# 1297   FEMENINO       26/04/2025   0 M      < 1 año
# 2423  MASCULINO       23/04/2025   0 M      < 1 año
# 2431  MASCULINO       24/04/2025   0 M      < 1 año
# 2450  MASCULINO       01/05/2025  14 D      < 1 año
#
#          Direccion De Residencia  ... CIE10 Egreso  \
# 476         CR 26 D 31 B 34 SUR   ...         J219
# 1093             CALLE  36 7A 16  ...
# 1297           CALLE  37 G 12 33  ...         J219
# 2423  CL 84  A SUR  2  ESTE  61   ...         J219
# 2431               KR  14 112 28  ...
# 2450                CRA 3  22 47  ...         J219
#
#                                Unidad centinela Localidad unidad centinela  \
# 476   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 1093  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 1297  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 2423  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 2431  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 2450  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 476    5     15/05/2025                    20          29/04/2025
# 1093   5     17/05/2025                    20          26/04/2025
# 1297   5     15/05/2025                    20          26/04/2025
# 2423   5     13/05/2025                    20          23/04/2025
# 2431   5     13/05/2025                    20          24/04/2025
# 2450   5     15/05/2025                    20          01/05/2025
#
#      Tipo de documento Edad años Edad en meses
# 476                NU        0.0           0.0
# 1093               NU        0.0           0.0
# 1297               NU        0.0           0.0
# 2423                CN       0.0           0.0
# 2431                CN       0.0           0.0
# 2450                CN       0.0           0.0
#
# [6 rows x 30 columns]

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      CIE10 Egreso                           Unidad centinela  \
# 31           J329  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 54           J018  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 177          I499  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 228                HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 279          J209  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# ...           ...                                        ...
# 3625         I800  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3634         I872  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3640         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3641         I10X  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
# 3642               HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 31             4. SAN CRISTOBAL   5     17/05/2025                    20
# 54             4. SAN CRISTOBAL   5     14/05/2025                    20
# 177            4. SAN CRISTOBAL   5     15/05/2025                    20
# 228            4. SAN CRISTOBAL   5     14/05/2025                    20
# 279            4. SAN CRISTOBAL   5     15/05/2025                    20
# ...                         ...  ..            ...                   ...
# 3625           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3634           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3640           4. SAN CRISTOBAL   5     14/05/2025                    20
# 3641           4. SAN CRISTOBAL   5     15/05/2025                    20
# 3642           4. SAN CRISTOBAL   5     17/05/2025                    20
#
#      Fecha de nacimiento Tipo de documento Edad años Edad en meses
# 31            25/01/2001                CC      24.0           NaN
# 54            26/10/2001                CC      23.0           NaN
# 177           25/02/1958                CC      67.0           NaN
# 228           22/03/2000                CC      25.0           NaN
# 279           11/07/1999                CC      25.0           NaN
# ...                  ...               ...       ...           ...
# 3625          02/06/1968                CC      56.0           NaN
# 3634          11/07/1957                CC      67.0           NaN
# 3640          15/06/1934                CC      90.0           NaN
# 3641          15/06/1934                CC      90.0           NaN
# 3642          15/06/1934                CC      90.0           NaN
#
# [312 rows x 30 columns]

# %% [markdown]
# ### GRUPO DE EDAD: De acuerdo al intervalo
# - 0 a 5 años: 1. INFANCIA
# - 6 a 11 años: 2. INFANCIA
# - 12 a 17 años: 3. ADOLESCENCIA
# - 18 a 28 años: 4. JUVENTUD
# - 29 a 59 años: 5. ADULTEZ
# - <60 años: 6. VEJEZ

# %%
# Función para asignar el grupo de edad
def clasificar_grupo_edad(edad):
    if 0 <= edad <= 5:
        return "1. INFANCIA"
    elif 6 <= edad <= 11:
        return "2. INFANCIA"
    elif 12 <= edad <= 17:
        return "3. ADOLESCENCIA"
    elif 18 <= edad <= 28:
        return "4. JUVENTUD"
    elif 29 <= edad <= 59:
        return "5. ADULTEZ"
    else:
        return "6. VEJEZ"

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses'],
#       dtype='object')

# %%
# Aplicar la clasificación de grupo de edad
df_sin_duplicados_columnas['GRUPO DE EDAD'] = df_sin_duplicados_columnas["Edad años"].apply(clasificar_grupo_edad)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente       Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  MASCULINO
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   FEMENINO
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  MASCULINO
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   FEMENINO
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  MASCULINO
# ...      ...         ...                               ...        ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  MASCULINO
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  MASCULINO
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  MASCULINO
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 31     5     17/05/2025                    20          25/01/2001
# 54     5     14/05/2025                    20          26/10/2001
# 177    5     15/05/2025                    20          25/02/1958
# 228    5     14/05/2025                    20          22/03/2000
# 279    5     15/05/2025                    20          11/07/1999
# ...   ..            ...                   ...                 ...
# 3625   5     13/05/2025                    20          02/06/1968
# 3634   5     13/05/2025                    20          11/07/1957
# 3640   5     14/05/2025                    20          15/06/1934
# 3641   5     15/05/2025                    20          15/06/1934
# 3642   5     17/05/2025                    20          15/06/1934
#
#      Tipo de documento Edad años Edad en meses GRUPO DE EDAD
# 31                  CC      24.0           NaN   4. JUVENTUD
# 54                  CC      23.0           NaN   4. JUVENTUD
# 177                 CC      67.0           NaN      6. VEJEZ
# 228                 CC      25.0           NaN   4. JUVENTUD
# 279                 CC      25.0           NaN   4. JUVENTUD
# ...                ...       ...           ...           ...
# 3625                CC      56.0           NaN    5. ADULTEZ
# 3634                CC      67.0           NaN      6. VEJEZ
# 3640                CC      90.0           NaN      6. VEJEZ
# 3641                CC      90.0           NaN      6. VEJEZ
# 3642                CC      90.0           NaN      6. VEJEZ
#
# [312 rows x 31 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['Sexo'].unique()
# Out:
# array(['MASCULINO', 'FEMENINO'], dtype=object)

# %% [markdown]
# ### Sexo: Generar Mujer o Hombre, ya que en las bases aparece FEMENINO/MASCULINO o F/M.

# %%
# Suponiendo que df_sin_duplicados_columnas es el DataFrame original
df_sin_duplicados_columnas["Sexo"] = df_sin_duplicados_columnas['Sexo'].replace({
    "FEMENINO": "MUJER",
    "MASCULINO": "HOMBRE",
    "F": "MUJER",
    "M": "HOMBRE"
})

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora         Tipo Plan  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente    Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  HOMBRE
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   MUJER
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  HOMBRE
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   MUJER
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  HOMBRE
# ...      ...         ...                               ...     ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  HOMBRE
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  HOMBRE
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
#
#      Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 31     5     17/05/2025                    20          25/01/2001
# 54     5     14/05/2025                    20          26/10/2001
# 177    5     15/05/2025                    20          25/02/1958
# 228    5     14/05/2025                    20          22/03/2000
# 279    5     15/05/2025                    20          11/07/1999
# ...   ..            ...                   ...                 ...
# 3625   5     13/05/2025                    20          02/06/1968
# 3634   5     13/05/2025                    20          11/07/1957
# 3640   5     14/05/2025                    20          15/06/1934
# 3641   5     15/05/2025                    20          15/06/1934
# 3642   5     17/05/2025                    20          15/06/1934
#
#      Tipo de documento Edad años Edad en meses GRUPO DE EDAD
# 31                  CC      24.0           NaN   4. JUVENTUD
# 54                  CC      23.0           NaN   4. JUVENTUD
# 177                 CC      67.0           NaN      6. VEJEZ
# 228                 CC      25.0           NaN   4. JUVENTUD
# 279                 CC      25.0           NaN   4. JUVENTUD
# ...                ...       ...           ...           ...
# 3625                CC      56.0           NaN    5. ADULTEZ
# 3634                CC      67.0           NaN      6. VEJEZ
# 3640                CC      90.0           NaN      6. VEJEZ
# 3641                CC      90.0           NaN      6. VEJEZ
# 3642                CC      90.0           NaN      6. VEJEZ
#
# [312 rows x 31 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Tipo Plan', 'Tip Doc', 'Documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.head()
# Out:
#                                            Aseguradora         Tipo Plan  \
# 31   Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54           Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                          COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228          Hospital Universitario Clinica San Rafael        Particular
# 279                              Salud Total EPS S S A  POS Contributivo
#
#     Tip Doc   Documento                   Nombre Paciente    Sexo  \
# 31       CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  HOMBRE
# 54       CC  1000686762      VALENTINA  ATEHORTUA ALARCON   MUJER
# 177      CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  HOMBRE
# 228      CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   MUJER
# 279      CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  HOMBRE
#
#     Fecha Nacimiento  Edad  Grupo Etareo Direccion De Residencia  ...  \
# 31        25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54        26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177       25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228       22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279       11/07/1999  25 A  15 a 44 años                NO SABE   ...
#
#                               Unidad centinela Localidad unidad centinela MES  \
# 31   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 54   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 177  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 228  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
# 279  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL   5
#
#     Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 31      17/05/2025                    20          25/01/2001
# 54      14/05/2025                    20          26/10/2001
# 177     15/05/2025                    20          25/02/1958
# 228     14/05/2025                    20          22/03/2000
# 279     15/05/2025                    20          11/07/1999
#
#     Tipo de documento Edad años Edad en meses GRUPO DE EDAD
# 31                 CC      24.0           NaN   4. JUVENTUD
# 54                 CC      23.0           NaN   4. JUVENTUD
# 177                CC      67.0           NaN      6. VEJEZ
# 228                CC      25.0           NaN   4. JUVENTUD
# 279                CC      25.0           NaN   4. JUVENTUD
#
# [5 rows x 31 columns]

# %%
df_sin_duplicados_columnas["Tipo Plan"].unique()
# Out:
# array(['POS Contributivo', 'Capitado-Alianza', 'Particular',
#        'Pos Subsidiado', 'Riesgos laborales'], dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={"Tipo Plan": "Regimen SGSS"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Regimen SGSS', 'Tip Doc', 'Documento',
#        'Nombre Paciente', 'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Direccion De Residencia', 'Municipio', 'Localidad', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['Direccion De Residencia']
# Out:
# 31              CLL 76 27 C 36
# 54      CALLE 41 A  52 A 64 G
# 177         AV CALLE 1 N 4A 17
# 228           CRA 81 D 25 C 27
# 279                   NO SABE
#                  ...
# 3625        DG 71B SUR 18 J 15
# 3634         CR 92  42F 47 SUR
# 3640     CALLE 11 SUR   12A 08
# 3641     CALLE 11 SUR   12A 08
# 3642     CALLE 11 SUR   12A 08
# Name: Direccion De Residencia, Length: 312, dtype: object

# %% [markdown]
# **Cuando se presenten datos vacios adicionar 999**

# %%
df_sin_duplicados_columnas.rename(columns={'Direccion De Residencia': "Dirección"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora      Regimen SGSS  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente    Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  HOMBRE
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   MUJER
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  HOMBRE
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   MUJER
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  HOMBRE
# ...      ...         ...                               ...     ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  HOMBRE
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  HOMBRE
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
#
#      Fecha Nacimiento  Edad  Grupo Etareo               Dirección  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 31     5     17/05/2025                    20          25/01/2001
# 54     5     14/05/2025                    20          26/10/2001
# 177    5     15/05/2025                    20          25/02/1958
# 228    5     14/05/2025                    20          22/03/2000
# 279    5     15/05/2025                    20          11/07/1999
# ...   ..            ...                   ...                 ...
# 3625   5     13/05/2025                    20          02/06/1968
# 3634   5     13/05/2025                    20          11/07/1957
# 3640   5     14/05/2025                    20          15/06/1934
# 3641   5     15/05/2025                    20          15/06/1934
# 3642   5     17/05/2025                    20          15/06/1934
#
#      Tipo de documento Edad años Edad en meses GRUPO DE EDAD
# 31                  CC      24.0           NaN   4. JUVENTUD
# 54                  CC      23.0           NaN   4. JUVENTUD
# 177                 CC      67.0           NaN      6. VEJEZ
# 228                 CC      25.0           NaN   4. JUVENTUD
# 279                 CC      25.0           NaN   4. JUVENTUD
# ...                ...       ...           ...           ...
# 3625                CC      56.0           NaN    5. ADULTEZ
# 3634                CC      67.0           NaN      6. VEJEZ
# 3640                CC      90.0           NaN      6. VEJEZ
# 3641                CC      90.0           NaN      6. VEJEZ
# 3642                CC      90.0           NaN      6. VEJEZ
#
# [312 rows x 31 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Regimen SGSS', 'Tip Doc', 'Documento',
#        'Nombre Paciente', 'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Dirección', 'Municipio', 'Localidad', 'Tipo Urgencia', 'Fecha Ingreso',
#        'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['Localidad'].unique()
# Out:
# array(['CIUDAD BOLIVAR', 'PUENTE ARANADA', 'SAN CRISTOBAL', 'FONTIBON',
#        'BOGOTA D.C.', 'RAFAEL URIBE', 'KENNEDY', 'BOSA', 'SANTA FE',
#        'USME', 'TUNJUELITO', 'MARTIRES', 'ANTONIO NARIÑO', 'CANDELARIA',
#        'ENGATIVA', 'SUBA', 'CHAPINERO'], dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={'Localidad': "Localidad de residencia base"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Regimen SGSS', 'Tip Doc', 'Documento',
#        'Nombre Paciente', 'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Dirección', 'Municipio', 'Localidad de residencia base',
#        'Tipo Urgencia', 'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion',
#        'Hora Atencion', 'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].unique()
# Out:
# array(['CIUDAD BOLIVAR', 'PUENTE ARANADA', 'SAN CRISTOBAL', 'FONTIBON',
#        'BOGOTA D.C.', 'RAFAEL URIBE', 'KENNEDY', 'BOSA', 'SANTA FE',
#        'USME', 'TUNJUELITO', 'MARTIRES', 'ANTONIO NARIÑO', 'CANDELARIA',
#        'ENGATIVA', 'SUBA', 'CHAPINERO'], dtype=object)

# %% [markdown]
# # preguntar

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].replace({'LOCALIDADES OTRAS CIUDADES':"999",  'BOGOTA D.C.':"999", 'SIN LOCALIDAD':"999",
                                                                   'RAFAEL URIBE':"RAFAEL URIBE URIBE", 'PUENTE ARANADA': "PUENTE ARANDA",
                                                                    'CANDELARIA': 'LA CANDELARIA', 'CANDELARIA ': 'LA CANDELARIA', 'MARTIRES': "LOS MARTIRES"
                                                                    },  inplace=True)
# Out:
# <ipython-input-85-bba1b5fe235f>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Localidad de residencia base"].replace({'LOCALIDADES OTRAS CIUDADES':"999",  'BOGOTA D.C.':"999", 'SIN LOCALIDAD':"999",

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].unique()
# Out:
# array(['CIUDAD BOLIVAR', 'PUENTE ARANDA', 'SAN CRISTOBAL', 'FONTIBON',
#        '999', 'RAFAEL URIBE URIBE', 'KENNEDY', 'BOSA', 'SANTA FE', 'USME',
#        'TUNJUELITO', 'LOS MARTIRES', 'ANTONIO NARIÑO', 'LA CANDELARIA',
#        'ENGATIVA', 'SUBA', 'CHAPINERO'], dtype=object)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['Aseguradora', 'Regimen SGSS', 'Tip Doc', 'Documento',
#        'Nombre Paciente', 'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo',
#        'Dirección', 'Municipio', 'Localidad de residencia base',
#        'Tipo Urgencia', 'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion',
#        'Hora Atencion', 'Diagnostico principal de Ingreso', 'Codigo CIE10',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['Codigo CIE10']
# Out:
# 31      J329
# 54      I829
# 177     I209
# 228     J00X
# 279     J22X
#         ...
# 3625    I800
# 3634    I501
# 3640    I10X
# 3641    I10X
# 3642    I10X
# Name: Codigo CIE10, Length: 312, dtype: object

# %%
df_sin_duplicados_columnas.rename(columns={'Codigo CIE10': "Diagnóstico de ingreso"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora      Regimen SGSS  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente    Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  HOMBRE
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   MUJER
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  HOMBRE
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   MUJER
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  HOMBRE
# ...      ...         ...                               ...     ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  HOMBRE
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  HOMBRE
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
#
#      Fecha Nacimiento  Edad  Grupo Etareo               Dirección  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#                                Unidad centinela Localidad unidad centinela  \
# 31    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 54    HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 177   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 228   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 279   HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# ...                                         ...                        ...
# 3625  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3634  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3640  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3641  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
# 3642  HOSPITAL UNIVERSITARIO CLÍNICA SAN RAFAEL           4. SAN CRISTOBAL
#
#      MES Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 31     5     17/05/2025                    20          25/01/2001
# 54     5     14/05/2025                    20          26/10/2001
# 177    5     15/05/2025                    20          25/02/1958
# 228    5     14/05/2025                    20          22/03/2000
# 279    5     15/05/2025                    20          11/07/1999
# ...   ..            ...                   ...                 ...
# 3625   5     13/05/2025                    20          02/06/1968
# 3634   5     13/05/2025                    20          11/07/1957
# 3640   5     14/05/2025                    20          15/06/1934
# 3641   5     15/05/2025                    20          15/06/1934
# 3642   5     17/05/2025                    20          15/06/1934
#
#      Tipo de documento Edad años Edad en meses GRUPO DE EDAD
# 31                  CC      24.0           NaN   4. JUVENTUD
# 54                  CC      23.0           NaN   4. JUVENTUD
# 177                 CC      67.0           NaN      6. VEJEZ
# 228                 CC      25.0           NaN   4. JUVENTUD
# 279                 CC      25.0           NaN   4. JUVENTUD
# ...                ...       ...           ...           ...
# 3625                CC      56.0           NaN    5. ADULTEZ
# 3634                CC      67.0           NaN      6. VEJEZ
# 3640                CC      90.0           NaN      6. VEJEZ
# 3641                CC      90.0           NaN      6. VEJEZ
# 3642                CC      90.0           NaN      6. VEJEZ
#
# [312 rows x 31 columns]

# %%
df_sin_duplicados_columnas['Diagnostico principal de Ingreso'].unique()
# Out:
# array(['Sinusitis cronica, no especificada',
#        'Embolia y trombosis de vena no especificada',
#        'Angina de pecho, no especificada',
#        'Rinofaringitis aguda (resfriado comun)',
#        'Infeccion aguda no especificada de las vias respiratorias inferiores',
#        'Otras linfadenitis inespecificas',
#        'Bronquiolitis aguda, no especificada',
#        'Hipertrofia de los cornetes nasales', 'Neumonia, no especificada',
#        'Enfermedades de la traquea y de los bronquios, no clasificadas en otra parte',
#        'Neumonia  bacteriana, no especificada',
#        'Amigdalitis aguda, no especificada',
#        'Otras formas especificadas de angina de pecho', 'Estado asmatico',
#        'Sinusitis aguda, no especificada', 'Otras sinusitis  agudas',
#        'Laringotraqueitis aguda', 'Sinusitis frontal aguda',
#        'Insuficiencia respiratoria aguda',
#        'Infeccion aguda de las vias respiratorias superiores, no especificada',
#        'Bronquitis aguda, no especificada', 'Angina inestable',
#        'Flebitis y tromboflebitis de   los miembros inferiores, no especificada',
#        'Faringitis aguda, no especificada',
#        'Laringitis obstructiva, aguda [crup]',
#        'Trastorno respiratorio, no especificado', 'Asma, no especificada',
#        'Neumotorax, no especificado', 'Neumonia viral, no especificada',
#        'Venas varicosas de los miembros inferiores con ulcera',
#        'Embolia pulmonar sin mencion de corazon pulmonar agudo',
#        'Trastorno no infeccioso de vasos y ganglios linfaticos, no especificado',
#        'Embolia y trombosis de otras venas especificadas',
#        'Laringitis aguda', 'Insuficiencia cardiaca congestiva',
#        'Accidente vascular encefalico agudo, no especificado como hemorragico o isquemico',
#        'Linfedema, no clasificado en otra parte',
#        'Enfermedad pulmonar obstructiva cronica con exacerbacion aguda, no especificada',
#        'Arritmia cardiaca, no especificada',
#        'Infarto agudo del miocardio, sin otra especificacion',
#        'Enfermedad cerebrovascular, no especificada',
#        'Fibrilacion y aleteo auricular',
#        'Varices esofagicas con hemorragia',
#        'Enfermedad de los vasos pulmonares, no especificada',
#        'Hipertension esencial (primaria)',
#        'Enfermedad isquemia cronica del corazon, no especificada',
#        'Enfermedad pulmonar obstructiva cronica, no especificada',
#        'Bronquitis, no especificada como aguda o cronica',
#        'Enfermedad de las vias respiratorias superiores, no especificada',
#        'Otros trastornos cerebrovasculares en enfermedades clasificadas en otra parte',
#        'Rinofaringitis cronica', 'Otras neumonias bacterianas',
#        'Hemorroides internas sin complicacion',
#        'Bronconeumonia, no especificada',
#        'Angina de pecho con espasmo documentado',
#        'Neumonia debida a otros virus', 'Paro cardiaco, no especificado',
#        'Embolia y trombosis de arterias de los miembros inferiores',
#        'Insuficiencia cardiaca, no especificada',
#        'Derrame pleural no clasificado en otra parte',
#        'Aterosclerosis de las arterias de los miembros',
#        'Flebitis y tromboflebitis de vasos superficiales de los miembros inferiores',
#        'Aneurisma cerebral, sin ruptura',
#        'Hemorroides externas sin complicacion',
#        'Insuficiencia venosa (cronica) (periferica)',
#        'Taquicardia paroxistica, no especificada',
#        'Varices en otros sitios especificados',
#        'Enfermedad cardiaca hipertensiva con insuficiencia cardiaca (congestiva)',
#        'Otras enfermedades especificadas de los vasos pulmonares',
#        'Taquicardia ventricular',
#        'Venas varicosas de los miembros inferiores con ulcera e inflamacion',
#        'Insuficiencia ventricular izquierda'], dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={'Diagnostico principal de Ingreso': "Nombre del diagnóstico de ingreso"}, inplace=True)

# %%
def asignar_tipo_dx(diagnostico):
    """
    Si el diagnóstco empieza con 'I', devolvemos 'CARDIO'.
    Si empieza con 'J', devolvemos 'RESPIRATORIO'.
    En otros casos, devolvemos vacío o lo que prefieras.
    """
    if str(diagnostico).startswith('I'):
        return 'CARDIO'
    elif str(diagnostico).startswith('J'):
        return 'RESPIRATORIO'
    else:
        return ''  # puedes poner OTRO si deseas

# %%
# Creamos la nueva columna TIPO_DX
df_sin_duplicados_columnas['TIPO_DX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(asignar_tipo_dx)

# %%
df_sin_duplicados_columnas
# Out:
#                                             Aseguradora      Regimen SGSS  \
# 31    Entidad Promotora De Salud Sanitas Sas  En Int...  POS Contributivo
# 54            Eps Y Medicina Prepagada Suramericana S A  POS Contributivo
# 177                           COMPENSAR MICRORED CAPITA  Capitado-Alianza
# 228           Hospital Universitario Clinica San Rafael        Particular
# 279                               Salud Total EPS S S A  POS Contributivo
# ...                                                 ...               ...
# 3625          Hospital Universitario Clinica San Rafael        Particular
# 3634                               Eps Famisanar S A S   POS Contributivo
# 3640                                       Nueva Eps Sa  POS Contributivo
# 3641                                       Nueva Eps Sa  POS Contributivo
# 3642                                       Nueva Eps Sa  POS Contributivo
#
#      Tip Doc   Documento                   Nombre Paciente    Sexo  \
# 31        CC  1000454540  JUAN SEBASTIAN CORDOBA RODRIQUEZ  HOMBRE
# 54        CC  1000686762      VALENTINA  ATEHORTUA ALARCON   MUJER
# 177       CC    10070253  GENTIL DE JESUS RESTREPO MUÑETON  HOMBRE
# 228       CC  1010107868     MARIA ALEJANDRA BERNAL ROMERO   MUJER
# 279       CC  1010246535   DAVID FERNANDO ALVAREZ PALENCIA  HOMBRE
# ...      ...         ...                               ...     ...
# 3625      CC    93417039     JESUS ALBEIRO RAMIREZ CARDONA  HOMBRE
# 3634      CC     9519313        LUIS ANTONIO GUERRERO MELO  HOMBRE
# 3640      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3641      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
# 3642      CC      996506      JOSE ARCENIO IGLESIAS RIVERA  HOMBRE
#
#      Fecha Nacimiento  Edad  Grupo Etareo               Dirección  ...  \
# 31         25/01/2001  24 A  15 a 44 años          CLL 76 27 C 36  ...
# 54         26/10/2001  23 A  15 a 44 años  CALLE 41 A  52 A 64 G   ...
# 177        25/02/1958  67 A      60 y mas      AV CALLE 1 N 4A 17  ...
# 228        22/03/2000  25 A  15 a 44 años        CRA 81 D 25 C 27  ...
# 279        11/07/1999  25 A  15 a 44 años                NO SABE   ...
# ...               ...   ...           ...                     ...  ...
# 3625       02/06/1968  56 A  45 a 59 años      DG 71B SUR 18 J 15  ...
# 3634       11/07/1957  67 A      60 y mas       CR 92  42F 47 SUR  ...
# 3640       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3641       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
# 3642       15/06/1934  90 A      60 y mas   CALLE 11 SUR   12A 08  ...
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 31             4. SAN CRISTOBAL   5     17/05/2025                    20
# 54             4. SAN CRISTOBAL   5     14/05/2025                    20
# 177            4. SAN CRISTOBAL   5     15/05/2025                    20
# 228            4. SAN CRISTOBAL   5     14/05/2025                    20
# 279            4. SAN CRISTOBAL   5     15/05/2025                    20
# ...                         ...  ..            ...                   ...
# 3625           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3634           4. SAN CRISTOBAL   5     13/05/2025                    20
# 3640           4. SAN CRISTOBAL   5     14/05/2025                    20
# 3641           4. SAN CRISTOBAL   5     15/05/2025                    20
# 3642           4. SAN CRISTOBAL   5     17/05/2025                    20
#
#      Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 31            25/01/2001                CC      24.0           NaN
# 54            26/10/2001                CC      23.0           NaN
# 177           25/02/1958                CC      67.0           NaN
# 228           22/03/2000                CC      25.0           NaN
# 279           11/07/1999                CC      25.0           NaN
# ...                  ...               ...       ...           ...
# 3625          02/06/1968                CC      56.0           NaN
# 3634          11/07/1957                CC      67.0           NaN
# 3640          15/06/1934                CC      90.0           NaN
# 3641          15/06/1934                CC      90.0           NaN
# 3642          15/06/1934                CC      90.0           NaN
#
#      GRUPO DE EDAD       TIPO_DX
# 31     4. JUVENTUD  RESPIRATORIO
# 54     4. JUVENTUD        CARDIO
# 177       6. VEJEZ        CARDIO
# 228    4. JUVENTUD  RESPIRATORIO
# 279    4. JUVENTUD  RESPIRATORIO
# ...            ...           ...
# 3625    5. ADULTEZ        CARDIO
# 3634      6. VEJEZ        CARDIO
# 3640      6. VEJEZ        CARDIO
# 3641      6. VEJEZ        CARDIO
# 3642      6. VEJEZ        CARDIO
#
# [312 rows x 32 columns]

# %%
import pandas as pd

# Códigos por grupo
EIC = {'I200', 'I201', 'I208', 'I209', 'I210', 'I211', 'I212', 'I213', 'I214', 'I219',
       'I220', 'I221', 'I228', 'I229', 'I230', 'I231', 'I232', 'I233', 'I234', 'I235',
       'I236', 'I237', 'I238', 'I240', 'I241', 'I248', 'I249', 'I250', 'I251', 'I252',
       'I253', 'I254', 'I255', 'I256', 'I257', 'I258', 'I259'}

ECV = {'I600', 'I601', 'I602', 'I603', 'I604', 'I605', 'I606', 'I607', 'I608', 'I609',
       'I610', 'I611', 'I612', 'I613', 'I614', 'I615', 'I616', 'I617', 'I618', 'I619',
       'I620', 'I621', 'I629', 'I630', 'I631', 'I632', 'I633', 'I634', 'I635', 'I636',
       'I637', 'I638', 'I639', 'I64X', 'I650', 'I651', 'I652', 'I653', 'I658', 'I659',
       'I660', 'I661', 'I662', 'I663', 'I664', 'I668', 'I669', 'I670', 'I671', 'I672',
       'I673', 'I674', 'I675', 'I676', 'I677', 'I678', 'I679', 'I680', 'I681', 'I682', 'I688',
       'I690', 'I691', 'I692', 'I693', 'I694', 'I698'}

IRA = {'J00X', 'J09X', 'J13X', 'J14X', 'J22X',
       'J010', 'J011', 'J012', 'J013', 'J014', 'J015', 'J016', 'J017', 'J018', 'J019',
       'J020', 'J028', 'J029', 'J030', 'J038', 'J039', 'J040', 'J041', 'J042', 'J050', 'J051',
       'J060', 'J068', 'J069', 'J100', 'J101', 'J108', 'J110', 'J111', 'J118', 'J120', 'J121',
       'J122', 'J123', 'J128', 'J129', 'J150', 'J151', 'J152', 'J153', 'J154', 'J155', 'J156',
       'J157', 'J158', 'J159', 'J160', 'J168', 'J170', 'J171', 'J172', 'J173', 'J178',
       'J180', 'J181', 'J182', 'J188', 'J189', 'J200', 'J201', 'J202', 'J203', 'J204', 'J205',
       'J206', 'J207', 'J208', 'J209', 'J210', 'J211', 'J218', 'J219'}

EPOC = {'J40X', 'J410', 'J411', 'J418', 'J42X', 'J430',
        'J431', 'J432', 'J438', 'J439', 'J440', 'J441', 'J448', 'J449', 'J47X'}

ASMA = {'J450', 'J451', 'J458', 'J459', 'J46X'}

# %%
# Función de clasificación
def clasificar_diagnostico(codigo):
    if pd.isna(codigo):
        return None
    codigo = str(codigo).strip().upper()
    if codigo in EIC:
        return "EIC"
    elif codigo in ECV:
        return "ECV"
    elif codigo.startswith('I'):
        return "OTRAS CARDIO"
    elif codigo in IRA:
        return "INFECCIONES RESPIRATORIAS AGUDAS"
    elif codigo in EPOC:
        return "EPOC"
    elif codigo in ASMA:
        return "ASMA"
    elif codigo.startswith('J'):
        return "OTRAS RESPIRATORIAS"
    else:
        return None


df_sin_duplicados_columnas['SUBDX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(clasificar_diagnostico)

# %%
df_sin_duplicados_columnas.rename(columns={"Documento": "No de documento"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={"Aseguradora": "EAPB"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['EAPB', 'Regimen SGSS', 'Tip Doc', 'No de documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo', 'Dirección',
#        'Municipio', 'Localidad de residencia base', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Nombre del diagnóstico de ingreso', 'Diagnóstico de ingreso',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'TIPO_DX', 'SUBDX'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['EAPB', 'Regimen SGSS', 'Tip Doc', 'No de documento', 'Nombre Paciente',
#        'Sexo', 'Fecha Nacimiento', 'Edad', 'Grupo Etareo', 'Dirección',
#        'Municipio', 'Localidad de residencia base', 'Tipo Urgencia',
#        'Fecha Ingreso', 'Hora Ingreso', 'Fecha Atencion', 'Hora Atencion',
#        'Nombre del diagnóstico de ingreso', 'Diagnóstico de ingreso',
#        'Diagnostico Egreso', 'CIE10 Egreso', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'TIPO_DX', 'SUBDX',
#        'Diagnóstico secundario', 'Nombre del diagnóstico secundario'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.rename(columns={'CIE10 Egreso': "Diagnóstico de egreso",  'Diagnostico Egreso': "Nombre del diagnóstico de egreso"}, inplace=True)

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].unique()
# Out:
# array(['J329', 'J018', 'I499', '', 'J209', 'J219', 'J343', 'J00X', 'J980',
#        'J158', 'J159', 'J039', 'I208', 'J960', 'J303', 'J46X', 'J042',
#        'J019', 'J22X', 'J410', 'I209', 'I803', 'J129', 'J030', 'J029',
#        'J459', 'J939', 'J050', 'I899', 'I828', 'J449', 'I679', 'A419',
#        'I259', 'I64X', 'I10X', 'I509', 'J441', 'I845', 'I219', 'I469',
#        'D381', 'I200', 'J90X', 'I800', 'I671', 'G468', 'I479', 'I868',
#        'I110', 'I255', 'I832', 'I872'], dtype=object)

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].replace('',"999", inplace=True)
# Out:
# <ipython-input-106-0b76f42dcf32>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Diagnóstico de egreso"].replace('',"999", inplace=True)

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)
# Out:
# <ipython-input-107-aa0c04562abd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Fecha egreso"]="999"

# %%
variables_def=['Unidad centinela',  'Localidad unidad centinela', 'MES', 'Fecha consulta',
       'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento', 'No de documento', 'Edad en meses',
 'Edad años','GRUPO DE EDAD', 'Sexo', 'EAPB', 'Regimen SGSS', 'Dirección',
       'Localidad de residencia base', 'Diagnóstico de ingreso',
       'Nombre del diagnóstico de ingreso', 'TIPO_DX', 'SUBDX', "Diagnóstico secundario", "Nombre del diagnóstico secundario", "Diagnóstico secundario", "Nombre del diagnóstico secundario",
        "Diagnóstico de egreso",   "Nombre del diagnóstico de egreso"  , "Fecha egreso"  ]

# %%
df_sin_duplicados_columnas_filtrada=df_sin_duplicados_columnas[variables_def]

# %%
df_sin_duplicados_columnas_filtrada.to_excel("Base_HUCSR_CONSOLIDADO16.xlsx",index=False)
