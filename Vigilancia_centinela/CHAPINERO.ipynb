# %% [markdown]
# </center>
#
# ---
# # CHAPINERO
# ---

# %% [markdown]
# ## **NOTAS:**
# - Actualizar las fecha correspondiente a la semana.

# %% [markdown]
# ## Identificación, Filtrado y Exportación de Registros Duplicados en un DataFrame

# %% [markdown]
#  estas dos líneas de código preparan tu entorno para trabajar con datos cargando las herramientas necesarias (pandas y numpy) y proporcionando nombres abreviados convenientes para ellos (pd y np).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Las siguientes dos líneas de código hacen lo siguiente:
#
# - Leen un archivo de Excel ubicado en una ruta específica.
# - Ignoran las primeras 5 filas del archivo.
# - Crean un DataFrame llamado df con los datos del archivo.
# - Muestran el DataFrame df

# %% [markdown]
# Reemplazar la ruta del archivo

# %%
df=pd.read_excel("/content/BASE AIRE SEMANA 19.xlsx", skiprows=0)
df.head(3)
# Out:
#                CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 0  HOSPITAL CHAPINERO  00000002627879 2025-05-04 12:32:29.450  2964209
# 1  HOSPITAL CHAPINERO  00000002627883 2025-05-04 12:59:41.657  2964418
# 2  HOSPITAL CHAPINERO  00000002627895 2025-05-04 14:44:22.673  2964445
#
#               FEC_INGRESO DOC_PACIENTE TIPO_DOC  \
# 0 2025-05-03 19:35:23.237     41691294       CC
# 1 2025-05-04 10:29:30.327      6006022       PT
# 2 2025-05-04 11:49:34.973   1015456869       CC
#
#                     NOMBRE_PACIENTE          FEC_NACIMIENTO  AÑOS  ...  \
# 0    MARIA LICENIA QUINTERO VASQUEZ 1956-08-20 17:56:01.900    69  ...
# 1  YOLIET \t SAMANTHA PRIETO PRIETO 2017-08-22 12:52:39.387     8  ...
# 2      NICOLAS DARIO CAMARGO CORREA 1995-09-11 11:48:36.747    30  ...
#
#    COD_ENTIDAD1                                       NOM_ENTIDAD1 NUM_EGRESO  \
# 0        EPSS34  CAPITAL SALUD EPS SAS - ENTIDAD PROMOTORA DE S...     243710
# ...

# %% [markdown]
# Esta línea es la encargada de mostrar las dimensiones (número de filas y columnas) del DataFrame llamado df

# %%
print(f"La base tiene {df.shape[0]} filas y {df.shape[1]} columnas  ")
# Out:
# La base tiene 235 filas y 32 columnas

# %% [markdown]
# **Actualizar las fechas de las semana epidemiólogica**

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
# Función para filtrar datos con solo ingresar el número de la semana
import pandas as pd

def filtrar_por_semana(df, semana):
    if semana not in semanas_2025:
        raise ValueError("Número de semana no válido. Debe estar entre 1 y 53.")

    Fecha_Inicio_Semana, Fecha_Final_Semana = semanas_2025[semana]

    # Convertir la columna de fechas a formato datetime si no lo está
    df["FEC_INGRESO"] = pd.to_datetime(df["FEC_INGRESO"])

    # Filtrar el DataFrame por la semana seleccionada
    df = df[
        (df["FEC_INGRESO"] >= Fecha_Inicio_Semana) &
        (df["FEC_INGRESO"] <= Fecha_Final_Semana)
    ]

    return df

# %% [markdown]
# # Ingrese el número de semana epidemiologica

# %%
df=filtrar_por_semana(df,19)
df.head(3)
# Out:
#                CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 1  HOSPITAL CHAPINERO  00000002627883 2025-05-04 12:59:41.657  2964418
# 2  HOSPITAL CHAPINERO  00000002627895 2025-05-04 14:44:22.673  2964445
# 3  HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
#
#               FEC_INGRESO DOC_PACIENTE TIPO_DOC  \
# 1 2025-05-04 10:29:30.327      6006022       PT
# 2 2025-05-04 11:49:34.973   1015456869       CC
# 3 2025-05-04 12:21:58.790   1014597867       RC
#
#                     NOMBRE_PACIENTE          FEC_NACIMIENTO  AÑOS  ...  \
# 1  YOLIET \t SAMANTHA PRIETO PRIETO 2017-08-22 12:52:39.387     8  ...
# 2      NICOLAS DARIO CAMARGO CORREA 1995-09-11 11:48:36.747    30  ...
# 3       EMMANUEL  RAMIREZ GUTIERREZ 2023-06-07 11:53:21.013     2  ...
#
#    COD_ENTIDAD1                                       NOM_ENTIDAD1 NUM_EGRESO  \
# 1        EPSS34  CAPITAL SALUD EPS SAS - ENTIDAD PROMOTORA DE S...     243724
# ...

# %% [markdown]
# Esta sección del código identifica y muestra todas las filas duplicadas en el DataFrame df y luego calcula y muestra el número total de filas duplicadas encontradas.

# %%
df['COD_dx_EGRESO'].isna().sum()
# Out:
# np.int64(0)

# %%
# Identificar filas duplicadas
duplicados = df[df.duplicated(keep=False)]

# Mostrar filas duplicadas
print(f"Filas duplicadas:{duplicados}")

# Contar cuántas filas duplicadas hay
num_duplicados = len(duplicados)
print(f"Número de filas duplicadas: {num_duplicados}\n")
# Out:
# Filas duplicadas:Empty DataFrame
# Columns: [CENTRO, FACTURA, FECHA_FACT, INGRESO, FEC_INGRESO, DOC_PACIENTE, TIPO_DOC, NOMBRE_PACIENTE, FEC_NACIMIENTO, AÑOS, MESES, DIA, GENERO, Direccion, LOCALIDAD, SERVICIO, regimen, COD_PLAN, NOM_PLAN, COD_MEDICO, NOM_MEDICO, SIPCODCUP, COD_ENTIDAD1, NOM_ENTIDAD1, NUM_EGRESO, CODIGO_CUMS, GMETIPMED, NOM_SERVICIO_PRODUCTO, COD_dx_EGRESO, NOM_dx_EGRESO, DX_INGRESO, DX_INGRESO1]
# Index: []
#
# [0 rows x 32 columns]
# Número de filas duplicadas: 0

# %% [markdown]
# # Paso 2: Eliminar todas las filas duplicadas (considerando todas las columnas)

# %% [markdown]
# sirve para eliminar filas duplicadas de un conjunto de datos (DataFrame) en Python. Esto significa que, si hay dos o más filas con exactamente la misma información en todas las columnas, solo se conservará una de ellas, eliminando las demás.
#
# El resultado se guarda en una nueva variable (df_sin_duplicados), dejando el DataFrame original (df) sin cambios.

# %%
df_sin_duplicados = df.drop_duplicates()
df_sin_duplicados
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 1    HOSPITAL CHAPINERO  00000002627883 2025-05-04 12:59:41.657  2964418
# 2    HOSPITAL CHAPINERO  00000002627895 2025-05-04 14:44:22.673  2964445
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 4    HOSPITAL CHAPINERO  00000002627914 2025-05-04 16:33:21.390  2964442
# 5    HOSPITAL CHAPINERO  00000002627922 2025-05-04 17:45:24.493  2964481
# ..                  ...             ...                     ...      ...
# 229  HOSPITAL CHAPINERO    SN0000415913 2025-05-09 20:29:38.760  2993778
# 230  HOSPITAL CHAPINERO    SN0000415915 2025-05-09 20:41:11.563  2992570
# 231  HOSPITAL CHAPINERO    SN0000415921 2025-05-09 22:29:19.890  2993792
# 232  HOSPITAL CHAPINERO    SN0000415922 2025-05-09 22:43:29.843  2993779
# 233  HOSPITAL CHAPINERO    SN0000415924 2025-05-09 23:24:07.330  2993844
#
#                 FEC_INGRESO DOC_PACIENTE TIPO_DOC  \
# ...

# %%
df.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1'],
#       dtype='object')

# %%
df_sin_duplicados['COD_dx_EGRESO'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Este codigo filtra los en diagnosticos de egreso y diagnostico de egreso que pertenezcan a la vigilancia

# %%
# Las columnas son de tipo string
df_sin_duplicados['DX_INGRESO1'] = df_sin_duplicados['DX_INGRESO1'].astype(str)
df_sin_duplicados['COD_dx_EGRESO'] = df_sin_duplicados['COD_dx_EGRESO'].astype(str)
df_sin_duplicados['COD_dx_EGRESO'] = df_sin_duplicados['COD_dx_EGRESO'].astype(str).replace('nan', '')

# Crear condiciones de filtrado
condicion_ingreso = df_sin_duplicados['DX_INGRESO1'].str.startswith(('I', 'J'))
condicion_egreso = df_sin_duplicados['COD_dx_EGRESO'].str.startswith(('I', 'J', ))

# %% [markdown]
# El sigueinte codigo permite anexar los diagnosticos ajenos a las j y a las i que pertenecen a la vigilancia centinela

# %%
# Lista de códigos específicos de egreso adicionales
codigos_adicionales = ["A419","C340","C341","C349","C450","C716","D022","D381","D386","D430",
                       "G468","R001","R092","R570","R571","R572","R579","R960","R961","R98X","Z515"]  #

#  condición para incluir los códigos específicos adicionales
condicion_codigos_adicionales = (df_sin_duplicados['COD_dx_EGRESO'].isin(codigos_adicionales)) & condicion_ingreso

condicion_vacios=  (df_sin_duplicados['COD_dx_EGRESO'] == '') & condicion_ingreso

# Combinar todas las condiciones
condicion_total = condicion_ingreso | condicion_egreso | condicion_codigos_adicionales| condicion_vacios

# Filtrar el DataFrame
df_sin_duplicados = df_sin_duplicados[condicion_total]

# %%
df_sin_duplicados['COD_dx_EGRESO'].unique()
# Out:
# array(['J050', 'J219', 'J449', 'I500', 'J22X', 'I10X', 'J340', 'J159',
#        'J00X', 'J039', 'I420', 'J209', 'I842', 'J81X'], dtype=object)

# %%
# Eliminar registros donde  no cumpla las condiciones
condicion_egreso_final = df_sin_duplicados['COD_dx_EGRESO'].str.startswith(('I', 'J')) | df_sin_duplicados['COD_dx_EGRESO'].isin(codigos_adicionales) | (df_sin_duplicados['COD_dx_EGRESO'] == '')
df_sin_duplicados = df_sin_duplicados[condicion_egreso_final]

# %%
df_sin_duplicados
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados['COD_dx_EGRESO'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Paso 3: Identificar duplicados basados en ciertas columnas ('Documento', "Fecha Ingreso")

# %% [markdown]
# Resumen general del código:
# - Busca filas duplicadas basándose solo en las columnas especificadas ('Documento', 'Fecha Ingreso', 'Codigo CIE10').
# - Guarda las filas duplicadas en un nuevo DataFrame (duplicados_columnas).
# - Cuenta cuántas filas duplicadas hay en total (num_duplicados_columnas).

# %%
df_sin_duplicados.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1'],
#       dtype='object')

# %%
duplicados_columnas = df_sin_duplicados[df_sin_duplicados.duplicated(subset=['DOC_PACIENTE', 'FEC_INGRESO'], keep=False)]
num_duplicados_columnas = len(duplicados_columnas)

# %%
duplicados_columnas
# Out:
#                  CENTRO       FACTURA              FECHA_FACT  INGRESO  \
# 110  HOSPITAL CHAPINERO  SN0000410280 2025-05-05 20:42:55.247  2970266
# 111  HOSPITAL CHAPINERO  SN0000410280 2025-05-05 20:42:55.247  2970266
#
#                 FEC_INGRESO DOC_PACIENTE TIPO_DOC  \
# 110 2025-05-05 17:43:24.760   1171714846       RC
# 111 2025-05-05 17:43:24.760   1171714846       RC
#
#                           NOMBRE_PACIENTE          FEC_NACIMIENTO  AÑOS  ...  \
# 110  SOFIA VICTORIA CASTELLANOS SANTAELLA 2024-03-24 12:41:40.887     1  ...
# 111  SOFIA VICTORIA CASTELLANOS SANTAELLA 2024-03-24 12:41:40.887     1  ...
#
#      COD_ENTIDAD1                          NOM_ENTIDAD1 NUM_EGRESO  \
# 110        EPSS41  NUEVA EPSS S.A. - REGIMEN SUBSIDIADO     244328
# 111        EPSS41  NUEVA EPSS S.A. - REGIMEN SUBSIDIADO     244328
#
#     CODIGO_CUMS GMETIPMED                       NOM_SERVICIO_PRODUCTO  \
# 110         NaN         1  CONSULTA DE URGENCIAS POR MEDICINA GENERAL
# ...

# %%
print(f"Número de filas duplicadas basadas :en las columnas: {num_duplicados_columnas}\n")
# Out:
# Número de filas duplicadas basadas :en las columnas: 2

# %% [markdown]
# # Paso 4: Eliminar duplicados basados en ciertas columnas ('col1', 'col2')

# %% [markdown]
# - Identifica duplicados considerando únicamente las columnas 'Documento', 'Fecha Ingreso', y 'Codigo CIE10'.
# - En cada grupo de duplicados, elimina todas las filas excepto la última.
# - Devuelve un nuevo DataFrame sin duplicados llamado df_sin_duplicados_columnas.

# %%
df_sin_duplicados_columnas = df_sin_duplicados.drop_duplicates(subset=['DOC_PACIENTE', 'FEC_INGRESO'], keep='last')
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
# Extraer la abreviatura antes del guion en la columna 'BARRIO'
df_sin_duplicados_columnas['LOCALIDAD_1'] = df_sin_duplicados_columnas['LOCALIDAD'].str.split('-').str[0]
# Out:
# <ipython-input-23-f6cc72e3e8fa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados_columnas['LOCALIDAD_1'] = df_sin_duplicados_columnas['LOCALIDAD'].str.split('-').str[0]

# %%
df_sin_duplicados_columnas["LOCALIDAD"].unique()
# Out:
# array(['ENGATIVA - GARCES NAVAS - BOSQUES DE GRADANA',
#        'BARRIOS UNIDOS - DOCE DE OCTUBRE - BARRIO SIMON BOLIVAR',
#        'USAQUEN - PASEO DE LOS LIBERTADORES - COLEGIO CAMPESTRE',
#        'CENTRO - SAN CRISTOBAL',
#        'BARRIOS UNIDOS - DOCE DE OCTUBRE - URBANIZACION SANTA SOFIA',
#        'ENGATIVA - BOYACA REAL - BOYACA',
#        'USAQUEN - COUNTRY CLUB - COUNTRY CLUB DE BOGOTA',
#        'TEUSAQUILLO - GALERIAS - GALERIAS',
#        'ANTONIO NARIÑO - RESTREPO - UNIDAD UNIVERSITARIA DEL SUR DE BOGOTA',
#        'CHAPINERO - EL REFUGIO - BARRIO LOS ROSALES',
#        'BARRIOS UNIDOS - LOS ANDES - FAC SUBOFICIALES',
#        'BOSA - APOGEO - URBANIZACION OLARTE',
#        'CHAPINERO - EL REFUGIO - SEMINARIO MAYOR DE BOGOTA',
#        'CHAPINERO - LOS ALCAZARES - BARRIO CHAPINERO CENTRAL',
#        'CIUDAD BOLIVAR - VENECIA - PROTECHO BOGOTA II ETAPA I',
#        'CHAPINERO - PARDO RUBIO - CHAPINERO ALTO',
# ...

# %%
# Mostrar el DataFrame con la nueva columna
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %% [markdown]
# Guarda el DataFrame df_sin_duplicados_columnas en un archivo Excel llamado Base.xlsx.
#
# index=False: Evita incluir la columna de índices del DataFrame en el archivo.

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1'],
#       dtype='object')

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['NOM_dx_EGRESO']
# Out:
# 3                   LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]
# 8                   BRONQUIOLITIS AGUDA, NO ESPECIFICADA
# 13     ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA, NO ES...
# 14                     INSUFICIENCIA CARDIACA CONGESTIVA
# 15     INFECCION AGUDA NO ESPECIFICADA DE LAS VIAS RE...
# 25                      HIPERTENSION ESENCIAL (PRIMARIA)
# 26             ABSCESO, FURUNCULO Y CARBUNCO DE LA NARIZ
# 27                  NEUMONIA BACTERIANA, NO ESPECIFICADA
# 31                RINOFARINGITIS AGUDA [RESFRIADO COMUN]
# 33                    AMIGDALITIS AGUDA, NO ESPECIFICADA
# 36                    AMIGDALITIS AGUDA, NO ESPECIFICADA
# 37                               CARDIOMIOPATIA DILATADA
# 43                     BRONQUITIS AGUDA, NO ESPECIFICADA
# 47                 HEMORROIDES INTERNAS SIN COMPLICACION
# 49                      HIPERTENSION ESENCIAL (PRIMARIA)
# 51                RINOFARINGITIS AGUDA [RESFRIADO COMUN]
# ...

# %%
import pandas as pd

def reemplazar_ingreso_por_egreso(row):
    ingreso = str(row['DX_INGRESO1']).strip().upper()
    egreso = str(row['COD_dx_EGRESO']).strip().upper()

    # Si son iguales, no hacer nada
    if ingreso == egreso:
        return row

     # Si ingreso empieza por I o J y egreso por otra letra → no se hace nada
    if ingreso.startswith(('I', 'J')) and not egreso.startswith(('I', 'J')):
        return row


    # Si ingreso no empieza por I o J y egreso sí → se reemplaza ingreso
    if not ingreso.startswith(('I', 'J')) and egreso.startswith(('I', 'J')):
        row['DX_INGRESO1'] = egreso
        row['DX_INGRESO'] = row['NOM_dx_EGRESO']

    # En los demás casos, no se hace nada
    return row

# %%
# Aplicar la función fila por fila
df_sin_duplicados_columnas = df_sin_duplicados_columnas.apply(reemplazar_ingreso_por_egreso, axis=1)

# %%
excluir_codigos=["I770", "I952", "I970", "I971", "I972", "I978", "I979", "J341", "J342", "J380", "J386", "J690", "J691", "J698", "J700", "J701", "J702", "J703", "J704", "J708", "J709", "J940", "J941", "J942", "J950", "J951", "J952", "J953", "J954", "J955", "J958", "J959", "J986" ]

# %%
df_sin_duplicados_columnas = df_sin_duplicados_columnas[
    ~df_sin_duplicados_columnas['DX_INGRESO1'].isin(excluir_codigos) &
    ~df_sin_duplicados_columnas['COD_dx_EGRESO'].isin(excluir_codigos)
]

# %%
df_sin_duplicados_columnas.to_excel("Base_Chapinero_PRIMERA BASE.xlsx",index=False)

# %% [markdown]
# # parte 2

# %% [markdown]
# 1.	Unidad centinela: En la base se registra la unidad centinela correspondiente:
# - CAPS CHAPINERO
# - HOSPITAL UNIVERSITARIO CLINICA SAN RAFAEL
# - USS MEISSEN
# - USS KENNEDY

# %%
df_sin_duplicados_columnas["Unidad centinela"]="CAPS CHAPINERO"

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela'],
#       dtype='object')

# %% [markdown]
# ### 	Localidad unidad centinela: Se diligencia la localidad en número y letra:

# %%
# Crear el diccionario con el formato requerido
mapeo_localidades = {
    "CAPS CHAPINERO" : "12. BARRIOS UNIDOS",
    "HOSPITAL UNIVERSITARIO CLINICA SANA RAFAEL": "4. SAN CRISTOBAL",
    "USS MEISSEN" : "19. CIUDAD BOLIVAR",
    "USS KENNEDY" : "8. KENNEDY"
}

# %%
df_sin_duplicados_columnas["Localidad unidad centinela"] = df_sin_duplicados_columnas["Unidad centinela"].map(mapeo_localidades)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %% [markdown]
# ### MES: En número

# %%
# Convertir a tipo datetime
df_sin_duplicados_columnas['FEC_INGRESO'] = pd.to_datetime(df_sin_duplicados_columnas['FEC_INGRESO'])

# Extraer el número del mes
df_sin_duplicados_columnas['MES'] = df_sin_duplicados_columnas['FEC_INGRESO'].dt.month

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas['Fecha consulta'] = df_sin_duplicados_columnas['FEC_INGRESO'].dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta'],
#       dtype='object')

# %% [markdown]
# #### Semana epidemiológica: De acuerdo a la semana epidemiológica correspondiente, pero si ya quedó ese código en la otra base, no se si en esta base sea necesario.

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
df_sin_duplicados_columnas["Fecha consulta"] = pd.to_datetime(
    df_sin_duplicados_columnas["Fecha consulta"],
    format="%d/%m/%Y"   # Ajusta según tu necesidad real
)

#

# %%
import pandas as pd

semanas_ordenadas = sorted(semanas_2025.keys())
bins = []

for i in semanas_ordenadas:
    # Inicio exacto tal como está en el diccionario
    inicio = pd.to_datetime(semanas_2025[i][0])
    # Para que 'fin' quede incluido, le sumamos 1 día y usamos el bin abierto
    # a la derecha => [inicio, fin+1)
    bins.append(inicio)

# El "cierre" del último bin será la fecha final de la última semana + 1 día
fin_ultima_sem = pd.to_datetime(semanas_2025[semanas_ordenadas[-1]][1])
bins.append(fin_ultima_sem + pd.Timedelta(days=1))

# Etiquetas
labels = [f"{i}" for i in semanas_ordenadas]

df_sin_duplicados_columnas["Semana epidemiologica"] = pd.cut(
    df_sin_duplicados_columnas["Fecha consulta"],
    bins=bins,
    labels=labels,
    right=False  # ¡Cerrar por la izquierda [inicio, fin)!
)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %% [markdown]
# #### Fecha de nacimiento

# %%
df_sin_duplicados_columnas['FEC_NACIMIENTO']
# Out:
# 3     2023-06-07 11:53:21.013
# 8     2024-10-22 12:16:48.260
# 13    1948-05-07 00:00:00.000
# 14    1960-08-15 12:49:39.947
# 15    2024-01-20 07:26:02.123
# 25    1940-08-03 06:48:06.343
# 26    1978-12-08 00:00:00.000
# 27    1958-02-26 15:56:10.480
# 31    2012-03-14 13:48:16.550
# 33    1967-11-24 22:12:35.523
# 36    2020-05-03 08:45:00.000
# 37    1962-09-03 12:07:08.330
# 43    1989-01-11 08:09:41.627
# 47    1969-10-08 16:11:52.707
# 49    1940-11-13 00:00:00.000
# 51    2016-09-17 10:39:26.407
# 57    1945-10-24 12:46:00.000
# 65    2022-10-24 12:59:55.337
# 70    2023-09-30 11:39:18.437
# 111   2024-03-24 12:41:40.887
# 112   2022-09-22 18:01:41.067
# 150   2024-05-04 08:01:44.950
# 190   2021-04-06 15:30:27.433
# 195   1997-11-23 00:00:00.000
# 213   1973-12-31 12:16:23.950
# 225   1988-03-06 00:26:10.230
# 227   2021-11-09 13:55:26.530
# 229   2024-01-25 19:02:54.323
# Name: FEC_NACIMIENTO, dtype: datetime64[ns]

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['FEC_NACIMIENTO'], format='%d/%m/%Y', errors='coerce').dt.strftime('%d/%m/%Y')

# %%
  df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %% [markdown]
# #### Tipo de documento: En caso de que el espacio se encuentre en blanco o con raya al piso, generar en ese espacio 999

# %%
df_sin_duplicados_columnas["TIPO_DOC"].unique()
# Out:
# array(['RC', 'CC', 'TI', 'PT', 'AS'], dtype=object)

# %%
# Reemplazar espacios en blanco o rayas al piso por "999"
df_sin_duplicados_columnas['Tipo de documento'] = df_sin_duplicados_columnas['TIPO_DOC'].replace(["", "_"], "999")

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas["Tipo de documento"].unique()
# Out:
# array(['RC', 'CC', 'TI', 'PT', 'AS'], dtype=object)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento'],
#       dtype='object')

# %% [markdown]
# ####	Edad en meses: Calcular en caso de que la edad en años sea cero 0.
# #### Edad años: Calcular de acuerdo a las variables fecha de nacimiento y fecha consulta.

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta

# Convertir las columnas a tipo datetime
df_sin_duplicados_columnas["Fecha de nacimiento"] = pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento'], format='%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta'], format='%d/%m/%Y')

# Función para calcular años y meses
def calcular_edad(row):
    nacimiento = row['Fecha de nacimiento']
    consulta = row['Fecha consulta']

    # Calcular la diferencia con relativedelta (maneja días/meses/años)
    delta = relativedelta(consulta, nacimiento)

    # Si hay al menos 1 año completo
    if delta.years >= 1:
        return pd.Series([delta.years, np.nan])
    else:
        # Calcular meses totales (años * 12 + meses)
        meses_totales = delta.years * 12 + delta.months
        return pd.Series([0, meses_totales])

# Aplicar la función y crear las columnas
df_sin_duplicados_columnas[['Edad años', 'Edad en meses']] = df_sin_duplicados_columnas.apply(calcular_edad, axis=1)

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento']).dt.strftime('%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta']).dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas["Edad en meses"].unique()
# Out:
# array([nan,  6.])

# %%
df_sin_duplicados_columnas[df_sin_duplicados_columnas["Edad en meses"]==0]
# Out:
# Empty DataFrame
# Columns: [CENTRO, FACTURA, FECHA_FACT, INGRESO, FEC_INGRESO, DOC_PACIENTE, TIPO_DOC, NOMBRE_PACIENTE, FEC_NACIMIENTO, AÑOS, MESES, DIA, GENERO, Direccion, LOCALIDAD, SERVICIO, regimen, COD_PLAN, NOM_PLAN, COD_MEDICO, NOM_MEDICO, SIPCODCUP, COD_ENTIDAD1, NOM_ENTIDAD1, NUM_EGRESO, CODIGO_CUMS, GMETIPMED, NOM_SERVICIO_PRODUCTO, COD_dx_EGRESO, NOM_dx_EGRESO, DX_INGRESO, DX_INGRESO1, LOCALIDAD_1, Unidad centinela, Localidad unidad centinela, MES, Fecha consulta, Semana epidemiologica, Fecha de nacimiento, Tipo de documento, Edad años, Edad en meses]
# Index: []
#
# [0 rows x 42 columns]

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %% [markdown]
# ### GRUPO DE EDAD: De acuerdo al intervalo
# - 0 a 5 años: 1. INFANCIA
# - 6 a 11 años: 2. INFANCIA
# - 12 a 17 años: 3. ADOLESCENCIA
# - 18 a 28 años: 4. JUVENTUD
# - 29 a 59 años: 5. ADULTEZ
# - <60 años: 6. VEJEZ

# %%
# Función para asignar el grupo de edad
def clasificar_grupo_edad(edad):
    if 0 <= edad <= 5:
        return "1. INFANCIA"
    elif 6 <= edad <= 11:
        return "2. INFANCIA"
    elif 12 <= edad <= 17:
        return "3. ADOLESCENCIA"
    elif 18 <= edad <= 28:
        return "4. JUVENTUD"
    elif 29 <= edad <= 59:
        return "5. ADULTEZ"
    else:
        return "6. VEJEZ"

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses'],
#       dtype='object')

# %%
# Aplicar la clasificación de grupo de edad
df_sin_duplicados_columnas['GRUPO DE EDAD'] = df_sin_duplicados_columnas["Edad años"].apply(clasificar_grupo_edad)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas['GENERO'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# ### Sexo: Generar Mujer o Hombre, ya que en las bases aparece FEMENINO/MASCULINO o F/M.

# %%
# Suponiendo que df_sin_duplicados_columnas es el DataFrame original
df_sin_duplicados_columnas["Sexo"] = df_sin_duplicados_columnas['GENERO'].replace({
    "FEMENINO": "MUJER",
    "MASCULINO": "HOMBRE",
    "F": "MUJER",
    "M": "HOMBRE"
})

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses', 'GRUPO DE EDAD',
#        'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.head()
# Out:
#                 CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3   HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8   HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13  HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14  HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15  HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
#
#                FEC_INGRESO DOC_PACIENTE TIPO_DOC  \
# 3  2025-05-04 12:21:58.790   1014597867       RC
# 8  2025-05-04 18:24:45.317   1015490349       RC
# 13 2025-05-05 09:33:16.663     26710756       CC
# 14 2025-05-05 14:19:40.133     35600901       CC
# 15 2025-05-05 11:51:49.843   1015489783       RC
#
#                    NOMBRE_PACIENTE          FEC_NACIMIENTO  AÑOS  ...  \
# 3      EMMANUEL  RAMIREZ GUTIERREZ 2023-06-07 11:53:21.013     2  ...
# 8      JERONIMO  TORREJANO ECHAVES 2024-10-22 12:16:48.260     1  ...
# ...

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Direccion', 'LOCALIDAD', 'SERVICIO',
#        'regimen', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1', 'LOCALIDAD_1',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses', 'GRUPO DE EDAD',
#        'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['regimen'].unique()
# Out:
# array(['SUBSIDIADO', 'CONTRIBUTIVO', 'PARTICULAR'], dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={'regimen': "Regimen SGSS"}, inplace=True)

# %%
df_sin_duplicados_columnas['Direccion']
# Out:
# 3                         CL 77 120A 60
# 8                        CALLE 76 63 20
# 13                       CL 89 B 116 30
# 14                    CARRERA 12 22 41
# 15                        KR 29B# 79 26
# 25                   Calle 72 B # 85-14
# 26                        CALLE 63-0-53
# 27                      CALLE 52 23 28
# 31                   CARRERA  65 75 27
# 33                    CARRERA 15 43 58
# 36                         CL 74  54 53
# 37                         CL 72 20A 48
# 43                CALLE  56A#72A-55 SUR
# 47                      CALLE 70A 57 34
# 49                     CALLE 79C 64 70
# 51                   TV 4 B ESTE 58 05
# 57                   CARRERA 1 65 C 17
# 65                 CARRERA 4 ESTE 49 38
# 70             CL 47 B SUR 13 C 03 ESTE
# 111    CARRERA 3 B ETE N 46  A ESTE -01
# 112      CARRERA 3  B ESTE  N 46 -A -13
# 150         CALLE 45  B N 03  ESTE  -10
# 190                CLL73  A  N 69 P -56
# 195                    CLL67   N22 -20
# ...

# %% [markdown]
# **Cuando se presenten datos vacios adicionar 999**

# %%
df_sin_duplicados_columnas.rename(columns={'Direccion': "Dirección"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas["LOCALIDAD_1"].unique()
# Out:
# array(['ENGATIVA ', 'BARRIOS UNIDOS ', 'USAQUEN ', 'CENTRO ',
#        'TEUSAQUILLO ', 'ANTONIO NARIÑO ', 'CHAPINERO ', 'BOSA ',
#        'CIUDAD BOLIVAR ', 'CANDELARIA ', 'SANTAFE '], dtype=object)

# %%
df_sin_duplicados_columnas["LOCALIDAD_1"].replace({"CENTRO ": "999", "CENTRO": "999",  "CANDELARIA": "LA CANDELARIA", 'CANDELARIA ': "LA CANDELARIA",  "MARTIRES ": "LOS MARTIRES",
                                                   "MARTIRES": "LOS MARTIRES"}, inplace=True)
# Out:
# <ipython-input-80-b0157349ee45>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["LOCALIDAD_1"].replace({"CENTRO ": "999", "CENTRO": "999"}, inplace=True)

# %%
df_sin_duplicados_columnas["LOCALIDAD"].unique()
# Out:
# array(['ENGATIVA - GARCES NAVAS - BOSQUES DE GRADANA',
#        'BARRIOS UNIDOS - DOCE DE OCTUBRE - BARRIO SIMON BOLIVAR',
#        'USAQUEN - PASEO DE LOS LIBERTADORES - COLEGIO CAMPESTRE',
#        'CENTRO - SAN CRISTOBAL',
#        'BARRIOS UNIDOS - DOCE DE OCTUBRE - URBANIZACION SANTA SOFIA',
#        'ENGATIVA - BOYACA REAL - BOYACA',
#        'USAQUEN - COUNTRY CLUB - COUNTRY CLUB DE BOGOTA',
#        'TEUSAQUILLO - GALERIAS - GALERIAS',
#        'ANTONIO NARIÑO - RESTREPO - UNIDAD UNIVERSITARIA DEL SUR DE BOGOTA',
#        'CHAPINERO - EL REFUGIO - BARRIO LOS ROSALES',
#        'BARRIOS UNIDOS - LOS ANDES - FAC SUBOFICIALES',
#        'BOSA - APOGEO - URBANIZACION OLARTE',
#        'CHAPINERO - EL REFUGIO - SEMINARIO MAYOR DE BOGOTA',
#        'CHAPINERO - LOS ALCAZARES - BARRIO CHAPINERO CENTRAL',
#        'CIUDAD BOLIVAR - VENECIA - PROTECHO BOGOTA II ETAPA I',
#        'CHAPINERO - PARDO RUBIO - CHAPINERO ALTO',
# ...

# %%
df_sin_duplicados_columnas.rename(columns={'LOCALIDAD_1': "Localidad de residencia base"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'DOC_PACIENTE', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO', 'AÑOS',
#        'MESES', 'DIA', 'GENERO', 'Dirección', 'LOCALIDAD', 'SERVICIO',
#        'Regimen SGSS', 'COD_PLAN', 'NOM_PLAN', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'DX_INGRESO', 'DX_INGRESO1',
#        'Localidad de residencia base', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].replace('LOCALIDADES OTRAS CIUDADES', "999", inplace=True)
# Out:
# <ipython-input-84-8947d2676a5d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Localidad de residencia base"].replace('LOCALIDADES OTRAS CIUDADES', "999", inplace=True)

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].unique()
# Out:
# array(['ENGATIVA ', 'BARRIOS UNIDOS ', 'USAQUEN ', '999', 'TEUSAQUILLO ',
#        'ANTONIO NARIÑO ', 'CHAPINERO ', 'BOSA ', 'CIUDAD BOLIVAR ',
#        'CANDELARIA ', 'SANTAFE '], dtype=object)

# %%
df_sin_duplicados_columnas['DX_INGRESO1']
# Out:
# 3      J050
# 8      J219
# 13     J449
# 14     I500
# 15     J22X
# 25     I10X
# 26     J340
# 27     J159
# 31     J00X
# 33     J039
# 36     J039
# 37     I420
# 43     J209
# 47     I842
# 49     I10X
# 51     J00X
# 57     J449
# 65     J039
# 70     J22X
# 111    J00X
# 112    J00X
# 150    J039
# 190    J22X
# 195    J209
# 213    I10X
# 225    J209
# 227    J22X
# 229    J00X
# Name: DX_INGRESO1, dtype: object

# %%
df_sin_duplicados_columnas.rename(columns={'DX_INGRESO1': "Diagnóstico de ingreso"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas['DX_INGRESO'].unique()
# Out:
# array(['LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]',
#        'BRONQUIOLITIS AGUDA, NO ESPECIFICADA',
#        'ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA, NO ESPECIFICADA',
#        'INSUFICIENCIA CARDIACA CONGESTIVA',
#        'INFECCION AGUDA NO ESPECIFICADA DE LAS VIAS RESPIRATORIAS INFERIORES',
#        'HIPERTENSION ESENCIAL (PRIMARIA)',
#        'ABSCESO, FURUNCULO Y CARBUNCO DE LA NARIZ',
#        'NEUMONIA BACTERIANA, NO ESPECIFICADA',
#        'RINOFARINGITIS AGUDA [RESFRIADO COMUN]',
#        'AMIGDALITIS AGUDA, NO ESPECIFICADA', 'CARDIOMIOPATIA DILATADA',
#        'BRONQUITIS AGUDA, NO ESPECIFICADA',
#        'HEMORROIDES INTERNAS SIN COMPLICACION'], dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={'DX_INGRESO': "Nombre del diagnóstico de ingreso"}, inplace=True)

# %%
def asignar_tipo_dx(diagnostico):
    """
    Si el diagnóstco empieza con 'I', devolvemos 'CARDIO'.
    Si empieza con 'J', devolvemos 'RESPIRATORIO'.
    En otros casos, devolvemos vacío o lo que prefieras.
    """
    if str(diagnostico).startswith('I'):
        return 'CARDIO'
    elif str(diagnostico).startswith('J'):
        return 'RESPIRATORIO'
    else:
        return ''  # puedes poner OTRO si deseas

# %%
# Creamos la nueva columna TIPO_DX
df_sin_duplicados_columnas['TIPO_DX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(asignar_tipo_dx)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
import pandas as pd

# Códigos por grupo
EIC = {'I200', 'I201', 'I208', 'I209', 'I210', 'I211', 'I212', 'I213', 'I214', 'I219',
       'I220', 'I221', 'I228', 'I229', 'I230', 'I231', 'I232', 'I233', 'I234', 'I235',
       'I236', 'I237', 'I238', 'I240', 'I241', 'I248', 'I249', 'I250', 'I251', 'I252',
       'I253', 'I254', 'I255', 'I256', 'I257', 'I258', 'I259'}

ECV = {'I600', 'I601', 'I602', 'I603', 'I604', 'I605', 'I606', 'I607', 'I608', 'I609',
       'I610', 'I611', 'I612', 'I613', 'I614', 'I615', 'I616', 'I617', 'I618', 'I619',
       'I620', 'I621', 'I629', 'I630', 'I631', 'I632', 'I633', 'I634', 'I635', 'I636',
       'I637', 'I638', 'I639', 'I64X', 'I650', 'I651', 'I652', 'I653', 'I658', 'I659',
       'I660', 'I661', 'I662', 'I663', 'I664', 'I668', 'I669', 'I670', 'I671', 'I672',
       'I673', 'I674', 'I675', 'I676', 'I677', 'I678', 'I679', 'I680', 'I681', 'I682', 'I688',
       'I690', 'I691', 'I692', 'I693', 'I694', 'I698'}

IRA = {'J00X', 'J09X', 'J13X', 'J14X', 'J22X',
       'J010', 'J011', 'J012', 'J013', 'J014', 'J015', 'J016', 'J017', 'J018', 'J019',
       'J020', 'J028', 'J029', 'J030', 'J038', 'J039', 'J040', 'J041', 'J042', 'J050', 'J051',
       'J060', 'J068', 'J069', 'J100', 'J101', 'J108', 'J110', 'J111', 'J118', 'J120', 'J121',
       'J122', 'J123', 'J128', 'J129', 'J150', 'J151', 'J152', 'J153', 'J154', 'J155', 'J156',
       'J157', 'J158', 'J159', 'J160', 'J168', 'J170', 'J171', 'J172', 'J173', 'J178',
       'J180', 'J181', 'J182', 'J188', 'J189', 'J200', 'J201', 'J202', 'J203', 'J204', 'J205',
       'J206', 'J207', 'J208', 'J209', 'J210', 'J211', 'J218', 'J219'}

EPOC = {'J40X', 'J410', 'J411', 'J418', 'J42X', 'J430',
        'J431', 'J432', 'J438', 'J439', 'J440', 'J441', 'J448', 'J449', 'J47X'}

ASMA = {'J450', 'J451', 'J458', 'J459', 'J46X'}

# %%
# Función de clasificación
def clasificar_diagnostico(codigo):
    if pd.isna(codigo):
        return None
    codigo = str(codigo).strip().upper()
    if codigo in EIC:
        return "EIC"
    elif codigo in ECV:
        return "ECV"
    elif codigo.startswith('I'):
        return "OTRAS CARDIO"
    elif codigo in IRA:
        return "INFECCIONES RESPIRATORIAS AGUDAS"
    elif codigo in EPOC:
        return "EPOC"
    elif codigo in ASMA:
        return "ASMA"
    elif codigo.startswith('J'):
        return "OTRAS RESPIRATORIAS"
    else:
        return None


df_sin_duplicados_columnas['SUBDX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(clasificar_diagnostico)

# %%
df_sin_duplicados_columnas.rename(columns={'DOC_PACIENTE': "No de documento"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={'NOM_PLAN': "EAPB"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#                  CENTRO         FACTURA              FECHA_FACT  INGRESO  \
# 3    HOSPITAL CHAPINERO  00000002627913 2025-05-04 16:27:42.367  2964461
# 8    HOSPITAL CHAPINERO  00000002627961 2025-05-04 22:53:04.037  2964615
# 13   HOSPITAL CHAPINERO  00000002632139 2025-05-05 13:53:59.577  2967211
# 14   HOSPITAL CHAPINERO  00000002632846 2025-05-05 16:21:24.413  2969554
# 15   HOSPITAL CHAPINERO  00000002633039 2025-05-05 18:17:54.893  2968629
# 25   HOSPITAL CHAPINERO  00000002638260 2025-05-06 17:04:11.010  2975543
# 26   HOSPITAL CHAPINERO  00000002638313 2025-05-06 18:08:42.867  2976268
# 27   HOSPITAL CHAPINERO  00000002638318 2025-05-06 18:17:20.747  2974408
# 31   HOSPITAL CHAPINERO  00000002638391 2025-05-06 22:36:07.753  2976353
# 33   HOSPITAL CHAPINERO  00000002638403 2025-05-06 23:12:26.347  2976555
# 36   HOSPITAL CHAPINERO  00000002638416 2025-05-07 01:27:40.727  2976595
# 37   HOSPITAL CHAPINERO  00000002638587 2025-05-07 06:18:33.813  2976463
# ...

# %%
df_sin_duplicados_columnas["Diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CENTRO', 'FACTURA', 'FECHA_FACT', 'INGRESO', 'FEC_INGRESO',
#        'No de documento', 'TIPO_DOC', 'NOMBRE_PACIENTE', 'FEC_NACIMIENTO',
#        'AÑOS', 'MESES', 'DIA', 'GENERO', 'Dirección', 'LOCALIDAD', 'SERVICIO',
#        'Regimen SGSS', 'COD_PLAN', 'EAPB', 'COD_MEDICO', 'NOM_MEDICO',
#        'SIPCODCUP', 'COD_ENTIDAD1', 'NOM_ENTIDAD1', 'NUM_EGRESO',
#        'CODIGO_CUMS', 'GMETIPMED', 'NOM_SERVICIO_PRODUCTO', 'COD_dx_EGRESO',
#        'NOM_dx_EGRESO', 'Nombre del diagnóstico de ingreso',
#        'Diagnóstico de ingreso', 'Localidad de residencia base',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses', 'GRUPO DE EDAD',
#        'Sexo', 'TIPO_DX', 'SUBDX', 'Diagnóstico secundario',
#        'Nombre del diagnóstico secundario'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.rename(columns={'COD_dx_EGRESO': "Diagnóstico de egreso",  'NOM_dx_EGRESO': "Nombre del diagnóstico de egreso"}, inplace=True)

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)
# Out:
# <ipython-input-103-8f51a3f2211d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].replace('',"999", inplace=True)
# Out:
# <ipython-input-104-f5ff6740bc39>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)
# <ipython-input-104-f5ff6740bc39>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df_sin_duplicados_columnas["Fecha egreso"]="999"

# %%
variables_def=['Unidad centinela',  'Localidad unidad centinela', 'MES', 'Fecha consulta',
       'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento', 'No de documento', 'Edad en meses',
 'Edad años','GRUPO DE EDAD', 'Sexo', 'EAPB', 'Regimen SGSS', 'Dirección',
       'Localidad de residencia base', 'Diagnóstico de ingreso',
       'Nombre del diagnóstico de ingreso', 'TIPO_DX', 'SUBDX', "Diagnóstico secundario", "Nombre del diagnóstico secundario", "Diagnóstico secundario", "Nombre del diagnóstico secundario",
        "Diagnóstico de egreso",   "Nombre del diagnóstico de egreso"  , "Fecha egreso"  ]

# %%
df_sin_duplicados_columnas_filtrada=df_sin_duplicados_columnas[variables_def]

# %%
df_sin_duplicados_columnas_filtrada
# Out:
#     Unidad centinela Localidad unidad centinela  MES Fecha consulta  \
# 3     CAPS CHAPINERO         12. BARRIOS UNIDOS    5     04/05/2025
# 8     CAPS CHAPINERO         12. BARRIOS UNIDOS    5     04/05/2025
# 13    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     05/05/2025
# 14    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     05/05/2025
# 15    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     05/05/2025
# 25    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 26    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 27    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 31    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 33    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 36    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 37    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     06/05/2025
# 43    CAPS CHAPINERO         12. BARRIOS UNIDOS    5     07/05/2025
# ...

# %%
df_sin_duplicados_columnas_filtrada.to_excel("Base_Chapinero_CONSOLIDADO16.xlsx",index=False)
