# %% [markdown]
# ## Identificación, Filtrado y Exportación de Registros Duplicados en un DataFrame

# %% [markdown]
#  estas dos líneas de código preparan tu entorno para trabajar con datos cargando las herramientas necesarias (pandas y numpy) y proporcionando nombres abreviados convenientes para ellos (pd y np).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Las siguientes dos líneas de código hacen lo siguiente:
#
# - Leen un archivo de Excel ubicado en una ruta específica.
# - Ignoran las primeras 5 filas del archivo.
# - Crean un DataFrame llamado df con los datos del archivo.
# - Muestran el DataFrame df

# %% [markdown]
# Reemplazar la ruta del archivo

# %%
df=pd.read_excel("/content/USS_Kennedy_SE16.xlsx", skiprows=0)
df
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 0           12663994       2025-04-14 12:49:32.383                      CC
# 1           12670175       2025-04-15 12:14:59.153                      CC
# 2           12678351       2025-04-18 06:58:16.580                      CC
# 3           12678351       2025-04-18 06:58:16.580                      CC
# 4           12661992       2025-04-14 09:27:49.980                      CC
# ...              ...                           ...                     ...
# 1398        12676996       2025-04-16 14:51:35.933                      DE
# 1399        12676996       2025-04-16 14:51:35.933                      DE
# 1400        12677749       2025-04-17 06:34:33.643                      DE
# 1401        12678803       2025-04-19 05:34:30.863                      DE
# 1402        12679177       2025-04-19 13:07:29.153                      AS
#
#      NUMERO_DE_IDENTIFICACION          NOMBRE_COMPLETO_PACIENTE  \
# 0                  1000006343  BRALLAN ESTIBEN SANCHEZ CUBILLOS
# 1                  1000116720     DANIELA BRILLID ALFARO RINCON
# 2                  1000117438      ANGIE LILIANA SALGADO GARZON
# 3                  1000117438      ANGIE LILIANA SALGADO GARZON
# 4                  1000123115    DURLEY GINETH TORRES DOMINGUEZ
# ...                       ...                               ...
# 1398                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1399                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1400               VEN8150418    RAFAEL TARCISIO MORENO SALAZAR
# 1401               VEN8150418    RAFAEL TARCISIO MORENO SALAZAR
# 1402             ZAF520127869               NEIL RICHARD HERVEY
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 0    2001-01-16 12:48:45.580    24    M
# 1    2000-06-07 00:00:00.000    25    F
# 2    2000-12-11 00:00:00.000    25    F
# 3    2000-12-11 00:00:00.000    25    F
# 4    2001-11-07 00:00:00.000    24    F
# ...                      ...   ...  ...
# 1398 2009-04-03 13:47:12.180    16    F
# 1399 2009-04-03 13:47:12.180    16    F
# 1400 1959-09-07 12:10:03.727    66    M
# 1401 1959-09-07 12:10:03.727    66    M
# 1402 1952-01-27 00:00:00.000    73    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 0                         COMPAÑIA MUNDIAL DE SEGUROS         ESPECIAL
# 1                                       CAPITAL SALUD       SUBSIDIADO
# 2                                       CAPITAL SALUD       SUBSIDIADO
# 3                                       CAPITAL SALUD       SUBSIDIADO
# 4                                       CAPITAL SALUD       SUBSIDIADO
# ...                                               ...              ...
# 1398  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1399  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1400  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1401  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1402  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
#
#                                  DIRECCION                         BARRIO  \
# 0                       CALLE 25 89 63 SUR    KENN-CIUDAD KENNEDY CENTRAL
# 1                     dig 73 H SUR N 79 64                 BOSA-SAN PABLO
# 2     CALLE 84 C SUR 81A-34 BOSA SAN JOSE                BOSA-SAN EUGENIO
# 3     CALLE 84 C SUR 81A-34 BOSA SAN JOSE                BOSA-SAN EUGENIO
# 4                      CL 49 A SUR 88G 16                 BOSA-ARGELIA II
# ...                                    ...                            ...
# 1398              CALLE 5 CARRERA 88C- 16             KENN-PATIO BONITO I
# 1399              CALLE 5 CARRERA 88C- 16             KENN-PATIO BONITO I
# 1400             CARRERA 87 C # 56C SUR 33              BOSA-LA LIBERTAD
# 1401             CARRERA 87 C # 56C SUR 33              BOSA-LA LIBERTAD
# 1402                                BOGOTA  CBOL-BOGOTA SECTOR TEQUENDAMA
#
#      LOCALIDAD CIE10_INGRESO  \
# 0       BOGOTA          M759
# 1       BOGOTA          R51X
# 2       BOGOTA          O620
# 3       BOGOTA          O620
# 4       BOGOTA          N751
# ...        ...           ...
# 1398    BOGOTA          R102
# 1399    BOGOTA          R102
# 1400    BOGOTA          C887
# 1401    BOGOTA          C887
# 1402    BOGOTA          J449
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...                M759
# 1     CEFALEA                                       ...                R103
# 2     TRABAJO DE PARTO                              ...                O829
# 3     TRABAJO DE PARTO                              ...                Z309
# 4     ABSCESO DE LA GLANDULA DE BARTHOLIN           ...                N750
# ...                                                 ...                 ...
# 1398  DOLOR PELVICO Y PERINEAL                      ...                Z357
# 1399  DOLOR PELVICO Y PERINEAL                      ...                Z358
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...                C887
# 1401  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...                C887
# 1402  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA, NO ES...                 NaN
#
#                                     NOMBRE_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...
# 1     DOLOR LOCALIZADO EN OTRAS PARTES INFERIORES DE...
# 2     PARTO POR CESAREA, SIN OTRA ESPECIFICACION    ...
# 3     ASISTENCIA PARA LA ANTICONCEPCION, NO ESPECIFI...
# 4     QUISTE DE LA GLANDULA DE BARTHOLIN            ...
# ...                                                 ...
# 1398  SUPERVISION DE EMBARAZO DE ALTO RIESGO DEBIDO ...
# 1399  SUPERVISION DE OTROS EMBARAZOS DE ALTO RIESGO ...
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...
# 1401  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...
# 1402                                                NaN
#
#              DESTINO_EGRESO                                 NOMBRE HC  \
# 0     URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1     URGENCIAS_OBSERVACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 2           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 3           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 4           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# ...                     ...                                       ...
# 1398                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1399                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1400                 SALIDA           INGRESO A ATENCION DE URGENCIAS
# 1401                 SALIDA           INGRESO A ATENCION DE URGENCIAS
# 1402  URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                     VALIDACION
# 0       126639941000006343M759
# 1       126701751000116720R51X
# 2       126783511000117438O620
# 3       126783511000117438O620
# 4       126619921000123115N751
# ...                        ...
# 1398        12676996VEN795R102
# 1399        12676996VEN795R102
# 1400    12677749VEN8150418C887
# 1401    12678803VEN8150418C887
# 1402  12679177ZAF520127869J449
#
# [1403 rows x 20 columns]

# %% [markdown]
# Esta línea es la encargada de mostrar las dimensiones (número de filas y columnas) del DataFrame llamado df

# %%
print(f"La base tiene {df.shape[0]} filas y {df.shape[1]} columnas  ")
# Out:
# La base tiene 1403 filas y 20 columnas

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
# Función para filtrar datos con solo ingresar el número de la semana
import pandas as pd

def filtrar_por_semana(df, semana):
    if semana not in semanas_2025:
        raise ValueError("Número de semana no válido. Debe estar entre 1 y 53.")

    Fecha_Inicio_Semana, Fecha_Final_Semana = semanas_2025[semana]

    # Convertir la columna de fechas a formato datetime si no lo está
    df["FECHA_HORA_INGRESO_DEL_EVENTO"] = pd.to_datetime(df["FECHA_HORA_INGRESO_DEL_EVENTO"])

    # Filtrar el DataFrame por la semana seleccionada
    df = df[
        (df["FECHA_HORA_INGRESO_DEL_EVENTO"] >= Fecha_Inicio_Semana) &
        (df["FECHA_HORA_INGRESO_DEL_EVENTO"] <= Fecha_Final_Semana)
    ]

    return df

# %% [markdown]
# Ingresar el número de semana epidemiológica

# %%
df=filtrar_por_semana(df,16)
df
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 0           12663994       2025-04-14 12:49:32.383                      CC
# 1           12670175       2025-04-15 12:14:59.153                      CC
# 2           12678351       2025-04-18 06:58:16.580                      CC
# 3           12678351       2025-04-18 06:58:16.580                      CC
# 4           12661992       2025-04-14 09:27:49.980                      CC
# ...              ...                           ...                     ...
# 1395        12677955       2025-04-17 11:05:48.493                      DE
# 1397        12678475       2025-04-18 11:54:56.553                      DE
# 1398        12676996       2025-04-16 14:51:35.933                      DE
# 1399        12676996       2025-04-16 14:51:35.933                      DE
# 1400        12677749       2025-04-17 06:34:33.643                      DE
#
#      NUMERO_DE_IDENTIFICACION          NOMBRE_COMPLETO_PACIENTE  \
# 0                  1000006343  BRALLAN ESTIBEN SANCHEZ CUBILLOS
# 1                  1000116720     DANIELA BRILLID ALFARO RINCON
# 2                  1000117438      ANGIE LILIANA SALGADO GARZON
# 3                  1000117438      ANGIE LILIANA SALGADO GARZON
# 4                  1000123115    DURLEY GINETH TORRES DOMINGUEZ
# ...                       ...                               ...
# 1395               VEN5388549           ROSAURA PANIAGUA FARFAN
# 1397               VEN7794925      DEYSI JOSEFINA SALAS OLIVERA
# 1398                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1399                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1400               VEN8150418    RAFAEL TARCISIO MORENO SALAZAR
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 0    2001-01-16 12:48:45.580    24    M
# 1    2000-06-07 00:00:00.000    25    F
# 2    2000-12-11 00:00:00.000    25    F
# 3    2000-12-11 00:00:00.000    25    F
# 4    2001-11-07 00:00:00.000    24    F
# ...                      ...   ...  ...
# 1395 1957-07-09 06:57:36.813    68    F
# 1397 1962-05-23 11:53:53.343    63    F
# 1398 2009-04-03 13:47:12.180    16    F
# 1399 2009-04-03 13:47:12.180    16    F
# 1400 1959-09-07 12:10:03.727    66    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 0                         COMPAÑIA MUNDIAL DE SEGUROS         ESPECIAL
# 1                                       CAPITAL SALUD       SUBSIDIADO
# 2                                       CAPITAL SALUD       SUBSIDIADO
# 3                                       CAPITAL SALUD       SUBSIDIADO
# 4                                       CAPITAL SALUD       SUBSIDIADO
# ...                                               ...              ...
# 1395  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1397                                     PARTICULARES         ESPECIAL
# 1398  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1399  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1400  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
#
#                                  DIRECCION                       BARRIO  \
# 0                       CALLE 25 89 63 SUR  KENN-CIUDAD KENNEDY CENTRAL
# 1                     dig 73 H SUR N 79 64               BOSA-SAN PABLO
# 2     CALLE 84 C SUR 81A-34 BOSA SAN JOSE              BOSA-SAN EUGENIO
# 3     CALLE 84 C SUR 81A-34 BOSA SAN JOSE              BOSA-SAN EUGENIO
# 4                      CL 49 A SUR 88G 16               BOSA-ARGELIA II
# ...                                    ...                          ...
# 1395                               5388549           USAQ-SANTA BARBARA
# 1397                             COVIPROF           KENN-CIUDAD KENNEDY
# 1398              CALLE 5 CARRERA 88C- 16           KENN-PATIO BONITO I
# 1399              CALLE 5 CARRERA 88C- 16           KENN-PATIO BONITO I
# 1400             CARRERA 87 C # 56C SUR 33            BOSA-LA LIBERTAD
#
#      LOCALIDAD CIE10_INGRESO  \
# 0       BOGOTA          M759
# 1       BOGOTA          R51X
# 2       BOGOTA          O620
# 3       BOGOTA          O620
# 4       BOGOTA          N751
# ...        ...           ...
# 1395    BOGOTA          N189
# 1397    BOGOTA          R100
# 1398    BOGOTA          R102
# 1399    BOGOTA          R102
# 1400    BOGOTA          C887
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...                M759
# 1     CEFALEA                                       ...                R103
# 2     TRABAJO DE PARTO                              ...                O829
# 3     TRABAJO DE PARTO                              ...                Z309
# 4     ABSCESO DE LA GLANDULA DE BARTHOLIN           ...                N750
# ...                                                 ...                 ...
# 1395  INSUFICIENCIA RENAL CRONICA, NO ESPECIFICADA  ...                N189
# 1397  ABDOMEN AGUDO                                 ...                 NaN
# 1398  DOLOR PELVICO Y PERINEAL                      ...                Z357
# 1399  DOLOR PELVICO Y PERINEAL                      ...                Z358
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...                C887
#
#                                     NOMBRE_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...
# 1     DOLOR LOCALIZADO EN OTRAS PARTES INFERIORES DE...
# 2     PARTO POR CESAREA, SIN OTRA ESPECIFICACION    ...
# 3     ASISTENCIA PARA LA ANTICONCEPCION, NO ESPECIFI...
# 4     QUISTE DE LA GLANDULA DE BARTHOLIN            ...
# ...                                                 ...
# 1395  INSUFICIENCIA RENAL CRONICA, NO ESPECIFICADA  ...
# 1397                                                NaN
# 1398  SUPERVISION DE EMBARAZO DE ALTO RIESGO DEBIDO ...
# 1399  SUPERVISION DE OTROS EMBARAZOS DE ALTO RIESGO ...
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...
#
#              DESTINO_EGRESO                                 NOMBRE HC  \
# 0     URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1     URGENCIAS_OBSERVACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 2           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 3           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 4           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# ...                     ...                                       ...
# 1395  URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1397  URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1398                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1399                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1400                 SALIDA           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 0     126639941000006343M759
# 1     126701751000116720R51X
# 2     126783511000117438O620
# 3     126783511000117438O620
# 4     126619921000123115N751
# ...                      ...
# 1395  12677955VEN5388549N189
# 1397  12678475VEN7794925R100
# 1398      12676996VEN795R102
# 1399      12676996VEN795R102
# 1400  12677749VEN8150418C887
#
# [1231 rows x 20 columns]

# %% [markdown]
# Esta sección del código identifica y muestra todas las filas duplicadas en el DataFrame df y luego calcula y muestra el número total de filas duplicadas encontradas.

# %%
df.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION'],
#       dtype='object')

# %%
df['CODIGO_CIE10_EGRESO'].isna().sum()
# Out:
# np.int64(126)

# %%
# Identificar filas duplicadas
duplicados = df[df.duplicated(keep=False)]

# Mostrar filas duplicadas
print(f"Filas duplicadas:{duplicados}")

# Contar cuántas filas duplicadas hay
num_duplicados = len(duplicados)
print(f"Número de filas duplicadas: {num_duplicados}\n")
# Out:
# Filas duplicadas:Empty DataFrame
# Columns: [NUMERO_INGRESO, FECHA_HORA_INGRESO_DEL_EVENTO, TIPO DOCUMENTO PACIENTE, NUMERO_DE_IDENTIFICACION, NOMBRE_COMPLETO_PACIENTE, FECHA_NACIMIENTO, EDAD, SEXO, EAPB, REGIMEN_AFILIADO, DIRECCION, BARRIO, LOCALIDAD, CIE10_INGRESO, NOMBRE_CIE10_INGRESO, CODIGO_CIE10_EGRESO, NOMBRE_CIE10_EGRESO, DESTINO_EGRESO, NOMBRE HC, VALIDACION]
# Index: []
# Número de filas duplicadas: 0

# %% [markdown]
# # Paso 2: Eliminar todas las filas duplicadas (considerando todas las columnas)

# %% [markdown]
# sirve para eliminar filas duplicadas de un conjunto de datos (DataFrame) en Python. Esto significa que, si hay dos o más filas con exactamente la misma información en todas las columnas, solo se conservará una de ellas, eliminando las demás.
#
# El resultado se guarda en una nueva variable (df_sin_duplicados), dejando el DataFrame original (df) sin cambios.

# %%
df_sin_duplicados = df.drop_duplicates()
df_sin_duplicados
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 0           12663994       2025-04-14 12:49:32.383                      CC
# 1           12670175       2025-04-15 12:14:59.153                      CC
# 2           12678351       2025-04-18 06:58:16.580                      CC
# 3           12678351       2025-04-18 06:58:16.580                      CC
# 4           12661992       2025-04-14 09:27:49.980                      CC
# ...              ...                           ...                     ...
# 1395        12677955       2025-04-17 11:05:48.493                      DE
# 1397        12678475       2025-04-18 11:54:56.553                      DE
# 1398        12676996       2025-04-16 14:51:35.933                      DE
# 1399        12676996       2025-04-16 14:51:35.933                      DE
# 1400        12677749       2025-04-17 06:34:33.643                      DE
#
#      NUMERO_DE_IDENTIFICACION          NOMBRE_COMPLETO_PACIENTE  \
# 0                  1000006343  BRALLAN ESTIBEN SANCHEZ CUBILLOS
# 1                  1000116720     DANIELA BRILLID ALFARO RINCON
# 2                  1000117438      ANGIE LILIANA SALGADO GARZON
# 3                  1000117438      ANGIE LILIANA SALGADO GARZON
# 4                  1000123115    DURLEY GINETH TORRES DOMINGUEZ
# ...                       ...                               ...
# 1395               VEN5388549           ROSAURA PANIAGUA FARFAN
# 1397               VEN7794925      DEYSI JOSEFINA SALAS OLIVERA
# 1398                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1399                   VEN795    ROSA DELCARMEN BARRAZA BARBOSA
# 1400               VEN8150418    RAFAEL TARCISIO MORENO SALAZAR
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 0    2001-01-16 12:48:45.580    24    M
# 1    2000-06-07 00:00:00.000    25    F
# 2    2000-12-11 00:00:00.000    25    F
# 3    2000-12-11 00:00:00.000    25    F
# 4    2001-11-07 00:00:00.000    24    F
# ...                      ...   ...  ...
# 1395 1957-07-09 06:57:36.813    68    F
# 1397 1962-05-23 11:53:53.343    63    F
# 1398 2009-04-03 13:47:12.180    16    F
# 1399 2009-04-03 13:47:12.180    16    F
# 1400 1959-09-07 12:10:03.727    66    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 0                         COMPAÑIA MUNDIAL DE SEGUROS         ESPECIAL
# 1                                       CAPITAL SALUD       SUBSIDIADO
# 2                                       CAPITAL SALUD       SUBSIDIADO
# 3                                       CAPITAL SALUD       SUBSIDIADO
# 4                                       CAPITAL SALUD       SUBSIDIADO
# ...                                               ...              ...
# 1395  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1397                                     PARTICULARES         ESPECIAL
# 1398  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1399  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
# 1400  FONDO FINANCIERO DISTRITAL DE SALUD -VINCULADOS     NO_ASEGURADO
#
#                                  DIRECCION                       BARRIO  \
# 0                       CALLE 25 89 63 SUR  KENN-CIUDAD KENNEDY CENTRAL
# 1                     dig 73 H SUR N 79 64               BOSA-SAN PABLO
# 2     CALLE 84 C SUR 81A-34 BOSA SAN JOSE              BOSA-SAN EUGENIO
# 3     CALLE 84 C SUR 81A-34 BOSA SAN JOSE              BOSA-SAN EUGENIO
# 4                      CL 49 A SUR 88G 16               BOSA-ARGELIA II
# ...                                    ...                          ...
# 1395                               5388549           USAQ-SANTA BARBARA
# 1397                             COVIPROF           KENN-CIUDAD KENNEDY
# 1398              CALLE 5 CARRERA 88C- 16           KENN-PATIO BONITO I
# 1399              CALLE 5 CARRERA 88C- 16           KENN-PATIO BONITO I
# 1400             CARRERA 87 C # 56C SUR 33            BOSA-LA LIBERTAD
#
#      LOCALIDAD CIE10_INGRESO  \
# 0       BOGOTA          M759
# 1       BOGOTA          R51X
# 2       BOGOTA          O620
# 3       BOGOTA          O620
# 4       BOGOTA          N751
# ...        ...           ...
# 1395    BOGOTA          N189
# 1397    BOGOTA          R100
# 1398    BOGOTA          R102
# 1399    BOGOTA          R102
# 1400    BOGOTA          C887
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...                M759
# 1     CEFALEA                                       ...                R103
# 2     TRABAJO DE PARTO                              ...                O829
# 3     TRABAJO DE PARTO                              ...                Z309
# 4     ABSCESO DE LA GLANDULA DE BARTHOLIN           ...                N750
# ...                                                 ...                 ...
# 1395  INSUFICIENCIA RENAL CRONICA, NO ESPECIFICADA  ...                N189
# 1397  ABDOMEN AGUDO                                 ...                 NaN
# 1398  DOLOR PELVICO Y PERINEAL                      ...                Z357
# 1399  DOLOR PELVICO Y PERINEAL                      ...                Z358
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...                C887
#
#                                     NOMBRE_CIE10_EGRESO  \
# 0     LESIONES DEL HOMBRO, NO ESPECIFICADA          ...
# 1     DOLOR LOCALIZADO EN OTRAS PARTES INFERIORES DE...
# 2     PARTO POR CESAREA, SIN OTRA ESPECIFICACION    ...
# 3     ASISTENCIA PARA LA ANTICONCEPCION, NO ESPECIFI...
# 4     QUISTE DE LA GLANDULA DE BARTHOLIN            ...
# ...                                                 ...
# 1395  INSUFICIENCIA RENAL CRONICA, NO ESPECIFICADA  ...
# 1397                                                NaN
# 1398  SUPERVISION DE EMBARAZO DE ALTO RIESGO DEBIDO ...
# 1399  SUPERVISION DE OTROS EMBARAZOS DE ALTO RIESGO ...
# 1400  OTRAS ENFERMEDADES INMUNOPROLIFERATIVAS MALIGN...
#
#              DESTINO_EGRESO                                 NOMBRE HC  \
# 0     URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1     URGENCIAS_OBSERVACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 2           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 3           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 4           HOSPITALIZACION  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# ...                     ...                                       ...
# 1395  URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1397  URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1398                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1399                 SALIDA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 1400                 SALIDA           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 0     126639941000006343M759
# 1     126701751000116720R51X
# 2     126783511000117438O620
# 3     126783511000117438O620
# 4     126619921000123115N751
# ...                      ...
# 1395  12677955VEN5388549N189
# 1397  12678475VEN7794925R100
# 1398      12676996VEN795R102
# 1399      12676996VEN795R102
# 1400  12677749VEN8150418C887
#
# [1231 rows x 20 columns]

# %% [markdown]
# Identifica la cantidad de vacios que hay en la columna indicada

# %%
df_sin_duplicados['CODIGO_CIE10_EGRESO'].isna().sum()
# Out:
# np.int64(126)

# %%
df.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION'],
#       dtype='object')

# %% [markdown]
# Este codigo filtra los CIE 10 en diagnosticos de ingreso y diagnostico de egreso que pertenezcan a la vigilancia

# %%
# Las columnas son de tipo string
df_sin_duplicados['CIE10_INGRESO'] = df_sin_duplicados['CIE10_INGRESO'].astype(str)
df_sin_duplicados['CODIGO_CIE10_EGRESO'] = df_sin_duplicados['CODIGO_CIE10_EGRESO'].astype(str)
df_sin_duplicados['CODIGO_CIE10_EGRESO'] = df_sin_duplicados['CODIGO_CIE10_EGRESO'].astype(str).replace('nan', '')

# Crear condiciones de filtrado
condicion_ingreso = df_sin_duplicados['CIE10_INGRESO'].str.startswith(('I', 'J'))
condicion_egreso = df_sin_duplicados['CODIGO_CIE10_EGRESO'].str.startswith(('I', 'J', ))

# %% [markdown]
# El siguiente codigo permite anexar los diagnosticos ajenos a las j y a las i que pertenecen a la vigilancia centinela

# %%
# Lista de códigos específicos de egreso adicionales
codigos_adicionales = ["A419","C340","C341","C349","C450","C716","D022","D381","D386","D430",
                       "G468","R001","R092","R570","R571","R572","R579","R960","R961","R98X","Z515"]  #

#  condición para incluir los códigos específicos adicionales
condicion_codigos_adicionales = (df_sin_duplicados['CODIGO_CIE10_EGRESO'].isin(codigos_adicionales)) & condicion_ingreso

condicion_vacios=  (df_sin_duplicados['CODIGO_CIE10_EGRESO'] == '') & condicion_ingreso

# Combinar todas las condiciones
condicion_total = condicion_ingreso | condicion_egreso | condicion_codigos_adicionales| condicion_vacios

# Filtrar el DataFrame
df_sin_duplicados = df_sin_duplicados[condicion_total]

# %%
df_sin_duplicados['CODIGO_CIE10_EGRESO'].unique()
# Out:
# array(['R102', 'J00X', 'I828', 'J451', 'J980', 'I10X', 'R51X', 'J018',
#        'J208', 'J449', 'N760', '', 'J459', 'J441', 'Z340', 'A09X', 'I500',
#        'J22X', 'R520', 'I749', 'I845', 'I209', 'I219', 'I679', 'D410',
#        'I499', 'I832', 'H353', 'J209', 'I609', 'J440', 'I228', 'I64X',
#        'J129', 'J448', 'K449', 'J029', 'J159', 'I872', 'L031', 'M621',
#        'E039', 'R13X', 'E139', 'M791', 'N912', 'I469', 'I429', 'J46X',
#        'I255', 'I612', 'J410', 'I211', 'I420', 'D849', 'N390'],
#       dtype=object)

# %%
# Eliminar registros donde 'CODIGO_CIE10_EGRESO' no cumpla las condiciones
condicion_egreso_final = df_sin_duplicados['CODIGO_CIE10_EGRESO'].str.startswith(('I', 'J')) | df_sin_duplicados['CODIGO_CIE10_EGRESO'].isin(codigos_adicionales) | (df_sin_duplicados['CODIGO_CIE10_EGRESO'] == '')
df_sin_duplicados = df_sin_duplicados[condicion_egreso_final]

# %%
df_sin_duplicados
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1271        12673353       2025-04-16 07:43:30.090                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1271                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1250 1981-12-07 00:00:00.000    44    M
# 1271 1985-10-02 00:00:00.000    40    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO
# 38                                      CAPITAL SALUD       SUBSIDIADO
# 94                                      CAPITAL SALUD       SUBSIDIADO
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO
# 132                                     EPS FAMISANAR     CONTRIBUTIVO
# ...                                               ...              ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO
# 1271                                    CAPITAL SALUD       SUBSIDIADO
# 1273                                    CAPITAL SALUD       SUBSIDIADO
# 1281                                    CAPITAL SALUD       SUBSIDIADO
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO
#
#                                               DIRECCION  \
# 24                          CARRERA 73 H N 62 D 93 SUR
# 38                                   CLL 55A 78J SUR 66
# 94                                    CL 42 SUR 90 C 16
# 122                                CARRERA 78 50 55 SUR
# 132                                CALLE 54C SUR 98D 05
# ...                                                 ...
# 1250  CR 78  K 26 -38  SUR    bloque 27 apart  201 e...
# 1271                                  CL 58M 79B 21 SUR
# 1273                                  CL 58M 79B 21 SUR
# 1281                               CALLE 48 77P 48 SUR
# 1289                                    CL 28 N 10AW 27
#
#                            BARRIO LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY    BOGOTA          R509
# 38                  KENN-CATALINA    BOGOTA          R31X
# 94    KENN-CIUDAD KENNEDY CENTRAL    BOGOTA          R104
# 122                KENN-CASA LOMA    BOGOTA          J00X
# 132           KENN-CIUDAD KENNEDY    BOGOTA          R509
# ...                           ...       ...           ...
# 1250           PTEA-PUENTE ARANDA    BOGOTA          R000
# 1271          KENN-CIUDAD KENNEDY    BOGOTA          G401
# 1273          KENN-CIUDAD KENNEDY    BOGOTA          S009
# 1281        KENN-PERPETUO SOCORRO    BOGOTA          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL    BOGOTA          B24X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    FIEBRE, NO ESPECIFICADA                       ...                J00X
# 38    HEMATURIA, NO ESPECIFICADA                    ...                I828
# 94    OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   FIEBRE, NO ESPECIFICADA                       ...                J451
# ...                                                 ...                 ...
# 1250  TAQUICARDIA, NO ESPECIFICADA                  ...                I420
# 1271  EPILEPSIA Y SINDROMES EPILEPTICOS SINTOMATICOS...                I612
# 1273  TRAUMATISMO SUPERFICIAL DE LA CABEZA, PARTE NO...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  ENFERMEDAD POR VIRUS DE LA INMUNODEFICIENCIA H...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1271  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1271          HOSPITALIZACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 24    126763091000938874R509
# 38    126780521001219260R31X
# 94    126619811006385628R104
# 122   126752731007851688J00X
# 132   126694371010844997R509
# ...                      ...
# 1250    1267776580731245R000
# 1271    1267335380920668G401
# 1273    1267335380920668S009
# 1281    1266394785433904J129
# 1289    1265880388258409B24X
#
# [110 rows x 20 columns]

# %%
df_sin_duplicados['CODIGO_CIE10_EGRESO'].isna().sum()
# Out:
# np.int64(0)

# %%
df_sin_duplicados.to_excel("Base_prueba.xlsx",index=False)

# %% [markdown]
# # Paso 3: Identificar duplicados basados en ciertas columnas ('Documento', "Fecha Ingreso", "Codigo CIE10")

# %% [markdown]
# Resumen general del código:
# - Busca filas duplicadas basándose solo en las columnas especificadas ('Documento', 'Fecha Ingreso', 'Codigo CIE10').
# - Guarda las filas duplicadas en un nuevo DataFrame (duplicados_columnas).
# - Cuenta cuántas filas duplicadas hay en total (num_duplicados_columnas).

# %%
duplicados_columnas = df_sin_duplicados[df_sin_duplicados.duplicated(subset=['NUMERO_DE_IDENTIFICACION', "FECHA_HORA_INGRESO_DEL_EVENTO"], keep=False)]
num_duplicados_columnas = len(duplicados_columnas)

# %%
duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 784         12661552       2025-04-14 08:48:33.153                      CC
# 785         12661552       2025-04-14 08:48:33.153                      CC
# 852         12665575       2025-04-14 16:16:50.430                      CC
# 853         12665575       2025-04-14 16:16:50.430                      CC
# 859         12667611       2025-04-15 08:04:19.247                      CC
# 861         12667611       2025-04-15 08:04:19.247                      CC
# 1114        12678428       2025-04-18 10:01:45.540                     PPT
# 1115        12678428       2025-04-18 10:01:45.540                     PPT
# 1139        12661109       2025-04-14 08:10:52.483                     PPT
# 1140        12661109       2025-04-14 08:10:52.483                     PPT
# 1233        12677909       2025-04-17 10:16:47.817                      CC
# 1234        12677909       2025-04-17 10:16:47.817                      CC
# 1247        12662053       2025-04-14 09:35:25.887                      CC
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1271        12673353       2025-04-16 07:43:30.090                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 784                  20543422           MARTHA  LA ROTTA DE MOLANO
# 785                  20543422           MARTHA  LA ROTTA DE MOLANO
# 852                  29806315              LUZ MARINA OSORIO AYALA
# 853                  29806315              LUZ MARINA OSORIO AYALA
# 859                   3081007                HERIBERTO LOZANO TORO
# 861                   3081007                HERIBERTO LOZANO TORO
# 1114                  6315472        TIBISAY LOURDES PARRA GIMENEZ
# 1115                  6315472        TIBISAY LOURDES PARRA GIMENEZ
# 1139                  6929762   ERICK ESLEATHER GERDETT VALLADARES
# 1140                  6929762   ERICK ESLEATHER GERDETT VALLADARES
# 1233                 80204152                   IVAN DARIO RIVEROS
# 1234                 80204152                   IVAN DARIO RIVEROS
# 1247                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1271                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
#
#             FECHA_NACIMIENTO  EDAD SEXO           EAPB REGIMEN_AFILIADO  \
# 784  1945-11-18 00:00:00.000    80    F  EPS NUEVA EPS     CONTRIBUTIVO
# 785  1945-11-18 00:00:00.000    80    F  EPS NUEVA EPS     CONTRIBUTIVO
# 852  1948-01-27 00:00:00.000    77    F  CAPITAL SALUD       SUBSIDIADO
# 853  1948-01-27 00:00:00.000    77    F  CAPITAL SALUD       SUBSIDIADO
# 859  1953-10-29 00:00:00.000    72    M  CAPITAL SALUD       SUBSIDIADO
# 861  1953-10-29 00:00:00.000    72    M  CAPITAL SALUD       SUBSIDIADO
# 1114 1976-04-27 00:00:00.000    49    F  CAPITAL SALUD       SUBSIDIADO
# 1115 1976-04-27 00:00:00.000    49    F  CAPITAL SALUD       SUBSIDIADO
# 1139 1999-01-30 08:09:44.120    26    M  CAPITAL SALUD       SUBSIDIADO
# 1140 1999-01-30 08:09:44.120    26    M  CAPITAL SALUD       SUBSIDIADO
# 1233 1983-12-30 00:00:00.000    42    M  CAPITAL SALUD       SUBSIDIADO
# 1234 1983-12-30 00:00:00.000    42    M  CAPITAL SALUD       SUBSIDIADO
# 1247 1980-09-10 09:34:43.667    45    M  CAPITAL SALUD       SUBSIDIADO
# 1248 1980-09-10 09:34:43.667    45    M  CAPITAL SALUD       SUBSIDIADO
# 1271 1985-10-02 00:00:00.000    40    M  CAPITAL SALUD       SUBSIDIADO
# 1273 1985-10-02 00:00:00.000    40    M  CAPITAL SALUD       SUBSIDIADO
#
#                                   DIRECCION                       BARRIO  \
# 784   Transversal 96b 21a- 70 BQ A-6 ap311                  FONT-EL RUBI
# 785   Transversal 96b 21a- 70 BQ A-6 ap311                  FONT-EL RUBI
# 852                    KR 80 H  49 B 09 SUR                KENN-BRITALIA
# 853                    KR 80 H  49 B 09 SUR                KENN-BRITALIA
# 859                      CALLE 41 A 81 H 22          KENN-PATIO BONITO I
# 861                      CALLE 41 A 81 H 22          KENN-PATIO BONITO I
# 1114                    cra77c # 60b -33SUR            BOSA-EL REGALO II
# 1115                    cra77c # 60b -33SUR            BOSA-EL REGALO II
# 1139                       CALLE 29 103 58   KENN-CIUDAD KENNEDY CENTRAL
# 1140                       CALLE 29 103 58   KENN-CIUDAD KENNEDY CENTRAL
# 1233                  CALLE 7 D # 81 B - 03             KENN-EL CASTILLO
# 1234                  CALLE 7 D # 81 B - 03             KENN-EL CASTILLO
# 1247                     CALLE 58 96 36 SUR  KENN-CIUDAD KENNEDY CENTRAL
# 1248                     CALLE 58 96 36 SUR  KENN-CIUDAD KENNEDY CENTRAL
# 1271                      CL 58M 79B 21 SUR          KENN-CIUDAD KENNEDY
# 1273                      CL 58M 79B 21 SUR          KENN-CIUDAD KENNEDY
#
#      LOCALIDAD CIE10_INGRESO  \
# 784     BOGOTA          I219
# 785     BOGOTA          I219
# 852     BOGOTA          I500
# 853     BOGOTA          I500
# 859     BOGOTA          H545
# 861     BOGOTA          I832
# 1114    BOGOTA          K85X
# 1115    BOGOTA          K85X
# 1139    BOGOTA          J209
# 1140    BOGOTA          J209
# 1233    BOGOTA          J410
# 1234    BOGOTA          J410
# 1247    BOGOTA          I211
# 1248    BOGOTA          I211
# 1271    BOGOTA          G401
# 1273    BOGOTA          S009
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 784   INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...                I219
# 785   INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...                I679
# 852   INSUFICIENCIA CARDIACA CONGESTIVA             ...                I499
# 853   INSUFICIENCIA CARDIACA CONGESTIVA             ...                I500
# 859   VISION SUBNORMAL DE UN OJO                    ...                I832
# 861   VENAS VARICOSAS DE LOS MIEMBROS INFERIORES CON...                I832
# 1114  PANCREATITIS AGUDA                            ...                I429
# 1115  PANCREATITIS AGUDA                            ...                I500
# 1139  BRONQUITIS AGUDA, NO ESPECIFICADA             ...                J209
# 1140  BRONQUITIS AGUDA, NO ESPECIFICADA             ...                J459
# 1233  BRONQUITIS CRONICA SIMPLE                     ...                J208
# 1234  BRONQUITIS CRONICA SIMPLE                     ...                J410
# 1247  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I211
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1271  EPILEPSIA Y SINDROMES EPILEPTICOS SINTOMATICOS...                I612
# 1273  TRAUMATISMO SUPERFICIAL DE LA CABEZA, PARTE NO...                I612
#
#                                     NOMBRE_CIE10_EGRESO  \
# 784   INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 785   ENFERMEDAD CEREBROVASCULAR, NO ESPECIFICADA   ...
# 852   ARRITMIA CARDIACA, NO ESPECIFICADA            ...
# 853   INSUFICIENCIA CARDIACA CONGESTIVA             ...
# 859   VENAS VARICOSAS DE LOS MIEMBROS INFERIORES CON...
# 861   VENAS VARICOSAS DE LOS MIEMBROS INFERIORES CON...
# 1114  CARDIOMIOPATIA, NO ESPECIFICADA               ...
# 1115  INSUFICIENCIA CARDIACA CONGESTIVA             ...
# 1139  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1140  ASMA, NO ESPECIFICADA                         ...
# 1233  BRONQUITIS AGUDA DEBIDA A OTROS MICROORGANISMO...
# 1234  BRONQUITIS CRONICA SIMPLE                     ...
# 1247  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1271  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
#
#              DESTINO_EGRESO                        NOMBRE HC  \
# 784         HOSPITALIZACION  INGRESO A ATENCION DE URGENCIAS
# 785         HOSPITALIZACION  INGRESO A ATENCION DE URGENCIAS
# 852   URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 853   URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 859   URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 861                  SALIDA  INGRESO A ATENCION DE URGENCIAS
# 1114  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1115  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1139  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1140  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1233  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1234  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1247  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1248  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
# 1271        HOSPITALIZACION  INGRESO A ATENCION DE URGENCIAS
# 1273  URGENCIAS_OBSERVACION  INGRESO A ATENCION DE URGENCIAS
#
#                 VALIDACION
# 784   1266155220543422I219
# 785   1266155220543422I219
# 852   1266557529806315I500
# 853   1266557529806315I500
# 859    126676113081007H545
# 861    126676113081007I832
# 1114   126784286315472K85X
# 1115   126784286315472K85X
# 1139   126611096929762J209
# 1140   126611096929762J209
# 1233  1267790980204152J410
# 1234  1267790980204152J410
# 1247  1266205380357279I211
# 1248  1266205380357279I211
# 1271  1267335380920668G401
# 1273  1267335380920668S009

# %%
print(f"Número de filas duplicadas basadas :en las columnas: {num_duplicados_columnas}\n")
# Out:
# Número de filas duplicadas basadas :en las columnas: 16

# %% [markdown]
# # Paso 4: Eliminar duplicados basados en ciertas columnas ('col1', 'col2')

# %% [markdown]
# - Identifica duplicados considerando únicamente las columnas 'Documento', 'Fecha Ingreso', y 'Codigo CIE10'.
# - En cada grupo de duplicados, elimina todas las filas excepto la última.
# - Devuelve un nuevo DataFrame sin duplicados llamado df_sin_duplicados_columnas.

# %%
df_sin_duplicados_columnas = df_sin_duplicados.drop_duplicates(subset=['NUMERO_DE_IDENTIFICACION', "FECHA_HORA_INGRESO_DEL_EVENTO"], keep='last')
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO
# 38                                      CAPITAL SALUD       SUBSIDIADO
# 94                                      CAPITAL SALUD       SUBSIDIADO
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO
# 132                                     EPS FAMISANAR     CONTRIBUTIVO
# ...                                               ...              ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO
# 1273                                    CAPITAL SALUD       SUBSIDIADO
# 1281                                    CAPITAL SALUD       SUBSIDIADO
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO
#
#                                               DIRECCION  \
# 24                          CARRERA 73 H N 62 D 93 SUR
# 38                                   CLL 55A 78J SUR 66
# 94                                    CL 42 SUR 90 C 16
# 122                                CARRERA 78 50 55 SUR
# 132                                CALLE 54C SUR 98D 05
# ...                                                 ...
# 1248                                 CALLE 58 96 36 SUR
# 1250  CR 78  K 26 -38  SUR    bloque 27 apart  201 e...
# 1273                                  CL 58M 79B 21 SUR
# 1281                               CALLE 48 77P 48 SUR
# 1289                                    CL 28 N 10AW 27
#
#                            BARRIO LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY    BOGOTA          R509
# 38                  KENN-CATALINA    BOGOTA          R31X
# 94    KENN-CIUDAD KENNEDY CENTRAL    BOGOTA          R104
# 122                KENN-CASA LOMA    BOGOTA          J00X
# 132           KENN-CIUDAD KENNEDY    BOGOTA          R509
# ...                           ...       ...           ...
# 1248  KENN-CIUDAD KENNEDY CENTRAL    BOGOTA          I211
# 1250           PTEA-PUENTE ARANDA    BOGOTA          R000
# 1273          KENN-CIUDAD KENNEDY    BOGOTA          S009
# 1281        KENN-PERPETUO SOCORRO    BOGOTA          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL    BOGOTA          B24X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    FIEBRE, NO ESPECIFICADA                       ...                J00X
# 38    HEMATURIA, NO ESPECIFICADA                    ...                I828
# 94    OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   FIEBRE, NO ESPECIFICADA                       ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  TAQUICARDIA, NO ESPECIFICADA                  ...                I420
# 1273  TRAUMATISMO SUPERFICIAL DE LA CABEZA, PARTE NO...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  ENFERMEDAD POR VIRUS DE LA INMUNODEFICIENCIA H...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 24    126763091000938874R509
# 38    126780521001219260R31X
# 94    126619811006385628R104
# 122   126752731007851688J00X
# 132   126694371010844997R509
# ...                      ...
# 1248    1266205380357279I211
# 1250    1267776580731245R000
# 1273    1267335380920668S009
# 1281    1266394785433904J129
# 1289    1265880388258409B24X
#
# [102 rows x 20 columns]

# %%
# Crear un diccionario con las abreviaturas y sus respectivos nombres
diccionario_localidades = {
    "USAQ": "USAQUEN",
    "CHAP": "CHAPINERO",
    "STFE": "SANTA FE",
    "SCRI": "SAN CRISTOBAL",
    "USME": "USME",
    "TUNJ": "TUNJUELITO",
    "BOSA": "BOSA",
    "KENN": "KENNEDY",
    "FONT": "FONTIBON",
    "ENGA": "ENGATIVA",
    "SUBA": "SUBA",
    "BRRU": "BARRIOS UNIDOS",
    "TEUS": "TEUSAQUILLO",
    "MART": "LOS MARTIRES",
    "ANTN": "ANTONIO NARIÑO",
    "PTEA": "PUENTE ARANDA",
    "CAND": "LA CANDELARIA",
    "RAFU": "RAFAEL URIBE URIBE",
    "CBOL": "CIUDAD BOLIVAR"
}

# Extraer la abreviatura antes del guion en la columna 'BARRIO'
df_sin_duplicados_columnas['ABREVIATURA'] = df_sin_duplicados_columnas['BARRIO'].str.split('-').str[0]

# Mapear la abreviatura con el nombre completo usando el diccionario
df_sin_duplicados_columnas['LOCALIDAD'] = df_sin_duplicados_columnas['ABREVIATURA'].map(diccionario_localidades)
df_sin_duplicados_columnas.drop(columns=['ABREVIATURA'], inplace=True)
# Out:
# <ipython-input-30-6487deb72624>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados_columnas['ABREVIATURA'] = df_sin_duplicados_columnas['BARRIO'].str.split('-').str[0]
# <ipython-input-30-6487deb72624>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados_columnas['LOCALIDAD'] = df_sin_duplicados_columnas['ABREVIATURA'].map(diccionario_localidades)
# <ipython-input-30-6487deb72624>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados_columnas.drop(columns=['ABREVIATURA'], inplace=True)

# %%
# Mostrar el DataFrame con la nueva columna
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO
# 38                                      CAPITAL SALUD       SUBSIDIADO
# 94                                      CAPITAL SALUD       SUBSIDIADO
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO
# 132                                     EPS FAMISANAR     CONTRIBUTIVO
# ...                                               ...              ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO
# 1273                                    CAPITAL SALUD       SUBSIDIADO
# 1281                                    CAPITAL SALUD       SUBSIDIADO
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO
#
#                                               DIRECCION  \
# 24                          CARRERA 73 H N 62 D 93 SUR
# 38                                   CLL 55A 78J SUR 66
# 94                                    CL 42 SUR 90 C 16
# 122                                CARRERA 78 50 55 SUR
# 132                                CALLE 54C SUR 98D 05
# ...                                                 ...
# 1248                                 CALLE 58 96 36 SUR
# 1250  CR 78  K 26 -38  SUR    bloque 27 apart  201 e...
# 1273                                  CL 58M 79B 21 SUR
# 1281                               CALLE 48 77P 48 SUR
# 1289                                    CL 28 N 10AW 27
#
#                            BARRIO      LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY        KENNEDY          R509
# 38                  KENN-CATALINA        KENNEDY          R31X
# 94    KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          R104
# 122                KENN-CASA LOMA        KENNEDY          J00X
# 132           KENN-CIUDAD KENNEDY        KENNEDY          R509
# ...                           ...            ...           ...
# 1248  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          I211
# 1250           PTEA-PUENTE ARANDA  PUENTE ARANDA          R000
# 1273          KENN-CIUDAD KENNEDY        KENNEDY          S009
# 1281        KENN-PERPETUO SOCORRO        KENNEDY          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          B24X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    FIEBRE, NO ESPECIFICADA                       ...                J00X
# 38    HEMATURIA, NO ESPECIFICADA                    ...                I828
# 94    OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   FIEBRE, NO ESPECIFICADA                       ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  TAQUICARDIA, NO ESPECIFICADA                  ...                I420
# 1273  TRAUMATISMO SUPERFICIAL DE LA CABEZA, PARTE NO...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  ENFERMEDAD POR VIRUS DE LA INMUNODEFICIENCIA H...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 24    126763091000938874R509
# 38    126780521001219260R31X
# 94    126619811006385628R104
# 122   126752731007851688J00X
# 132   126694371010844997R509
# ...                      ...
# 1248    1266205380357279I211
# 1250    1267776580731245R000
# 1273    1267335380920668S009
# 1281    1266394785433904J129
# 1289    1265880388258409B24X
#
# [102 rows x 20 columns]

# %% [markdown]
# Guarda el DataFrame df_sin_duplicados_columnas en un archivo Excel llamado Base.xlsx.
#
# index=False: Evita incluir la columna de índices del DataFrame en el archivo.

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION'],
#       dtype='object')

# %%
condicion_eliminar= (df_sin_duplicados_columnas['NOMBRE HC']=='HISTORIA CLINICA URGENCIAS-GINECOLOGICAS')&(df_sin_duplicados_columnas['CODIGO_CIE10_EGRESO']=='I10X')

# %%
df_sin_duplicados_columnas= df_sin_duplicados_columnas[~condicion_eliminar]

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO
# 38                                      CAPITAL SALUD       SUBSIDIADO
# 94                                      CAPITAL SALUD       SUBSIDIADO
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO
# 132                                     EPS FAMISANAR     CONTRIBUTIVO
# ...                                               ...              ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO
# 1273                                    CAPITAL SALUD       SUBSIDIADO
# 1281                                    CAPITAL SALUD       SUBSIDIADO
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO
#
#                                               DIRECCION  \
# 24                          CARRERA 73 H N 62 D 93 SUR
# 38                                   CLL 55A 78J SUR 66
# 94                                    CL 42 SUR 90 C 16
# 122                                CARRERA 78 50 55 SUR
# 132                                CALLE 54C SUR 98D 05
# ...                                                 ...
# 1248                                 CALLE 58 96 36 SUR
# 1250  CR 78  K 26 -38  SUR    bloque 27 apart  201 e...
# 1273                                  CL 58M 79B 21 SUR
# 1281                               CALLE 48 77P 48 SUR
# 1289                                    CL 28 N 10AW 27
#
#                            BARRIO      LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY        KENNEDY          R509
# 38                  KENN-CATALINA        KENNEDY          R31X
# 94    KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          R104
# 122                KENN-CASA LOMA        KENNEDY          J00X
# 132           KENN-CIUDAD KENNEDY        KENNEDY          R509
# ...                           ...            ...           ...
# 1248  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          I211
# 1250           PTEA-PUENTE ARANDA  PUENTE ARANDA          R000
# 1273          KENN-CIUDAD KENNEDY        KENNEDY          S009
# 1281        KENN-PERPETUO SOCORRO        KENNEDY          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          B24X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    FIEBRE, NO ESPECIFICADA                       ...                J00X
# 38    HEMATURIA, NO ESPECIFICADA                    ...                I828
# 94    OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   FIEBRE, NO ESPECIFICADA                       ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  TAQUICARDIA, NO ESPECIFICADA                  ...                I420
# 1273  TRAUMATISMO SUPERFICIAL DE LA CABEZA, PARTE NO...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  ENFERMEDAD POR VIRUS DE LA INMUNODEFICIENCIA H...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 24    126763091000938874R509
# 38    126780521001219260R31X
# 94    126619811006385628R104
# 122   126752731007851688J00X
# 132   126694371010844997R509
# ...                      ...
# 1248    1266205380357279I211
# 1250    1267776580731245R000
# 1273    1267335380920668S009
# 1281    1266394785433904J129
# 1289    1265880388258409B24X
#
# [101 rows x 20 columns]

# %%
#df_sin_duplicados_columnas.to_excel("Base_sin_intercambio.xlsx",index=False)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION'],
#       dtype='object')

# %% [markdown]
# # **pendiente**  si en ingreso y egreso son diferentes pero ingreso empieza por  I o J y Egreso es una letra difrente a I o J  no se cambia
#
#
# # si en ingreso es difrente  a I O J pero en egreso es igfual a I, J entonces se cambia  el egreso por el ingreso.
#
#
#
# -  eXCLUIR DE LA BASE Despues de hacer el intercambio
#
# Excepto los códigos CIE- 10: I770, I952, I970, I971, I972, I978, I979. . (SE DEBEN EXCLUIR DE LA BASE)
#
#
# Excepto los códigos CIE-10: J341, J342, J380, J386, J690, J691, J698, J700, J701, J702, J703, J704, J708, J709, J940, J941, J942, J950, J951, J952, J953, J954, J955, J958, J959, J986. (SE DEBEN EXCLUIR DE LA BASE)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['NOMBRE_CIE10_EGRESO']
# Out:
# 24      RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38      EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94      RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122     RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132     ASMA NO ALERGICA                              ...
#                               ...
# 1248    INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250    CARDIOMIOPATIA DILATADA                       ...
# 1273    HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281    BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# Name: NOMBRE_CIE10_EGRESO, Length: 101, dtype: object

# %%
import pandas as pd

def reemplazar_ingreso_por_egreso(row):
    ingreso = str(row['CIE10_INGRESO']).strip().upper()
    egreso = str(row["CODIGO_CIE10_EGRESO"]).strip().upper()

    # Si son iguales, no hacer nada
    if ingreso == egreso:
        return row

     # Si ingreso empieza por I o J y egreso por otra letra → no se hace nada
    if ingreso.startswith(('I', 'J')) and not egreso.startswith(('I', 'J')):
        return row


    # Si ingreso no empieza por I o J y egreso sí → se reemplaza ingreso
    if not ingreso.startswith(('I', 'J')) and egreso.startswith(('I', 'J')):
        row['CIE10_INGRESO'] = egreso
        row['NOMBRE_CIE10_INGRESO'] = row['NOMBRE_CIE10_EGRESO']

    # En los demás casos, no se hace nada
    return row

# %%
# Aplicar la función fila por fila
df_sin_duplicados_columnas = df_sin_duplicados_columnas.apply(reemplazar_ingreso_por_egreso, axis=1)

# %%
excluir_codigos=["I770", "I952", "I970", "I971", "I972", "I978", "I979", "J341", "J342", "J380", "J386", "J690", "J691", "J698", "J700", "J701", "J702", "J703", "J704", "J708", "J709", "J940", "J941", "J942", "J950", "J951", "J952", "J953", "J954", "J955", "J958", "J959", "J986" ]

# %%
df_sin_duplicados_columnas = df_sin_duplicados_columnas[
    ~df_sin_duplicados_columnas['CIE10_INGRESO'].isin(excluir_codigos) &
    ~df_sin_duplicados_columnas["CODIGO_CIE10_EGRESO"].isin(excluir_codigos)
]

# %%
df_sin_duplicados_columnas.to_excel("Base_1_Kennedy.xlsx",index=False)

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO
# 38                                      CAPITAL SALUD       SUBSIDIADO
# 94                                      CAPITAL SALUD       SUBSIDIADO
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO
# 132                                     EPS FAMISANAR     CONTRIBUTIVO
# ...                                               ...              ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO
# 1273                                    CAPITAL SALUD       SUBSIDIADO
# 1281                                    CAPITAL SALUD       SUBSIDIADO
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO
#
#                                               DIRECCION  \
# 24                          CARRERA 73 H N 62 D 93 SUR
# 38                                   CLL 55A 78J SUR 66
# 94                                    CL 42 SUR 90 C 16
# 122                                CARRERA 78 50 55 SUR
# 132                                CALLE 54C SUR 98D 05
# ...                                                 ...
# 1248                                 CALLE 58 96 36 SUR
# 1250  CR 78  K 26 -38  SUR    bloque 27 apart  201 e...
# 1273                                  CL 58M 79B 21 SUR
# 1281                               CALLE 48 77P 48 SUR
# 1289                                    CL 28 N 10AW 27
#
#                            BARRIO      LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY        KENNEDY          J00X
# 38                  KENN-CATALINA        KENNEDY          I828
# 94    KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          J00X
# 122                KENN-CASA LOMA        KENNEDY          J00X
# 132           KENN-CIUDAD KENNEDY        KENNEDY          J451
# ...                           ...            ...           ...
# 1248  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          I211
# 1250           PTEA-PUENTE ARANDA  PUENTE ARANDA          I420
# 1273          KENN-CIUDAD KENNEDY        KENNEDY          I612
# 1281        KENN-PERPETUO SOCORRO        KENNEDY          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          J00X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...                I828
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   ASMA NO ALERGICA                              ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  CARDIOMIOPATIA DILATADA                       ...                I420
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION
# 24    126763091000938874R509
# 38    126780521001219260R31X
# 94    126619811006385628R104
# 122   126752731007851688J00X
# 132   126694371010844997R509
# ...                      ...
# 1248    1266205380357279I211
# 1250    1267776580731245R000
# 1273    1267335380920668S009
# 1281    1266394785433904J129
# 1289    1265880388258409B24X
#
# [101 rows x 20 columns]

# %% [markdown]
# 1.	Unidad centinela: En la base se registra la unidad centinela correspondiente:
# - CAPS CHAPINERO
# - HOSPITAL UNIVERSITARIO CLINICA SANA RAFAEL
# - USS MEISSEN
# - USS KENNEDY

# %%
df_sin_duplicados_columnas["Unidad centinela"]="USS KENNEDY"

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#                            BARRIO      LOCALIDAD CIE10_INGRESO  \
# 24            KENN-CIUDAD KENNEDY        KENNEDY          J00X
# 38                  KENN-CATALINA        KENNEDY          I828
# 94    KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          J00X
# 122                KENN-CASA LOMA        KENNEDY          J00X
# 132           KENN-CIUDAD KENNEDY        KENNEDY          J451
# ...                           ...            ...           ...
# 1248  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          I211
# 1250           PTEA-PUENTE ARANDA  PUENTE ARANDA          I420
# 1273          KENN-CIUDAD KENNEDY        KENNEDY          I612
# 1281        KENN-PERPETUO SOCORRO        KENNEDY          J129
# 1289  KENN-CIUDAD KENNEDY CENTRAL        KENNEDY          J00X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...                I828
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   ASMA NO ALERGICA                              ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  CARDIOMIOPATIA DILATADA                       ...                I420
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela
# 24    126763091000938874R509      USS KENNEDY
# 38    126780521001219260R31X      USS KENNEDY
# 94    126619811006385628R104      USS KENNEDY
# 122   126752731007851688J00X      USS KENNEDY
# 132   126694371010844997R509      USS KENNEDY
# ...                      ...              ...
# 1248    1266205380357279I211      USS KENNEDY
# 1250    1267776580731245R000      USS KENNEDY
# 1273    1267335380920668S009      USS KENNEDY
# 1281    1266394785433904J129      USS KENNEDY
# 1289    1265880388258409B24X      USS KENNEDY
#
# [101 rows x 21 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION', 'Unidad centinela'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['LOCALIDAD'].unique()
# Out:
# array(['KENNEDY', 'SAN CRISTOBAL', 'FONTIBON', 'BOSA', 'SANTA FE', nan,
#        'SUBA', 'PUENTE ARANDA', 'ENGATIVA', 'LOS MARTIRES',
#        'CIUDAD BOLIVAR'], dtype=object)

# %% [markdown]
# ### 	Localidad unidad centinela: Se diligencia la localidad en número y letra:

# %%
# Crear el diccionario con el formato requerido
mapeo_localidades = {
    "CAPS CHAPINERO" : "12. BARRIOS UNIDOS",
    "HOSPITAL UNIVERSITARIO CLINICA SAN RAFAEL": "4. SAN CRISTOBAL",
    "USS MEISSEN" : "19. CIUDAD BOLIVAR",
    "USS KENNEDY" : "8. KENNEDY"
}

# %%
df_sin_duplicados_columnas["Localidad unidad centinela"] = df_sin_duplicados_columnas["Unidad centinela"].map(mapeo_localidades)

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#           LOCALIDAD CIE10_INGRESO  \
# 24          KENNEDY          J00X
# 38          KENNEDY          I828
# 94          KENNEDY          J00X
# 122         KENNEDY          J00X
# 132         KENNEDY          J451
# ...             ...           ...
# 1248        KENNEDY          I211
# 1250  PUENTE ARANDA          I420
# 1273        KENNEDY          I612
# 1281        KENNEDY          J129
# 1289        KENNEDY          J00X
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...                I828
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   ASMA NO ALERGICA                              ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  CARDIOMIOPATIA DILATADA                       ...                I420
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY
# ...                      ...              ...                        ...
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY
#
# [101 rows x 22 columns]

# %% [markdown]
# ### MES: En número

# %%
# Convertir a tipo datetime
df_sin_duplicados_columnas['FECHA_HORA_INGRESO_DEL_EVENTO'] = pd.to_datetime(df_sin_duplicados_columnas['FECHA_HORA_INGRESO_DEL_EVENTO'])

# Extraer el número del mes
df_sin_duplicados_columnas['MES'] = df_sin_duplicados_columnas['FECHA_HORA_INGRESO_DEL_EVENTO'].dt.month

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#      CIE10_INGRESO                               NOMBRE_CIE10_INGRESO  \
# 24            J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38            I828  EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94            J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122           J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132           J451  ASMA NO ALERGICA                              ...
# ...            ...                                                ...
# 1248          I211  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...
# 1250          I420  CARDIOMIOPATIA DILATADA                       ...
# 1273          I612  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281          J129  NEUMONIA VIRAL, NO ESPECIFICADA               ...
# 1289          J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#      CODIGO_CIE10_EGRESO                                NOMBRE_CIE10_EGRESO  \
# 24                  J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38                  I828  EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94                  J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122                 J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132                 J451  ASMA NO ALERGICA                              ...
# ...                  ...                                                ...
# 1248                I219  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250                I420  CARDIOMIOPATIA DILATADA                       ...
# 1273                I612  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281                J209  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289                J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
# [101 rows x 23 columns]

# %% [markdown]
# ### Fecha consulta: Que quede registro de formato fecha dd/mm/aaaa

# %%
df_sin_duplicados_columnas['Fecha consulta'] = df_sin_duplicados_columnas['FECHA_HORA_INGRESO_DEL_EVENTO'].dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#                                    NOMBRE_CIE10_INGRESO CODIGO_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...                I828
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
# 132   ASMA NO ALERGICA                              ...                J451
# ...                                                 ...                 ...
# 1248  INFARTO TRANSMURAL AGUDO DEL MIOCARDIO DE LA P...                I219
# 1250  CARDIOMIOPATIA DILATADA                       ...                I420
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...                I612
# 1281  NEUMONIA VIRAL, NO ESPECIFICADA               ...                J209
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...                J00X
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES  \
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
#      Fecha consulta
# 24       16/04/2025
# 38       17/04/2025
# 94       14/04/2025
# 122      16/04/2025
# 132      15/04/2025
# ...             ...
# 1248     14/04/2025
# 1250     17/04/2025
# 1273     16/04/2025
# 1281     14/04/2025
# 1289     13/04/2025
#
# [101 rows x 24 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Fecha consulta"] = pd.to_datetime(
    df_sin_duplicados_columnas["Fecha consulta"],
    format="%d/%m/%Y"   # Ajusta según tu necesidad real
)

#

# %%
import pandas as pd

semanas_ordenadas = sorted(semanas_2025.keys())
bins = []

for i in semanas_ordenadas:
    # Inicio exacto tal como está en el diccionario
    inicio = pd.to_datetime(semanas_2025[i][0])
    # Para que 'fin' quede incluido, le sumamos 1 día y usamos el bin abierto
    # a la derecha => [inicio, fin+1)
    bins.append(inicio)

# El "cierre" del último bin será la fecha final de la última semana + 1 día
fin_ultima_sem = pd.to_datetime(semanas_2025[semanas_ordenadas[-1]][1])
bins.append(fin_ultima_sem + pd.Timedelta(days=1))

# Etiquetas
labels = [f"{i}" for i in semanas_ordenadas]

df_sin_duplicados_columnas["Semana epidemiologica"] = pd.cut(
    df_sin_duplicados_columnas["Fecha consulta"],
    bins=bins,
    labels=labels,
    right=False  # ¡Cerramos por la izquierda [inicio, fin)!
)

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#      CODIGO_CIE10_EGRESO                                NOMBRE_CIE10_EGRESO  \
# 24                  J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38                  I828  EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94                  J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122                 J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132                 J451  ASMA NO ALERGICA                              ...
# ...                  ...                                                ...
# 1248                I219  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250                I420  CARDIOMIOPATIA DILATADA                       ...
# 1273                I612  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281                J209  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289                J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES  \
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
#      Fecha consulta Semana epidemiologica
# 24       2025-04-16                    16
# 38       2025-04-17                    16
# 94       2025-04-14                    16
# 122      2025-04-16                    16
# 132      2025-04-15                    16
# ...             ...                   ...
# 1248     2025-04-14                    16
# 1250     2025-04-17                    16
# 1273     2025-04-16                    16
# 1281     2025-04-14                    16
# 1289     2025-04-13                    16
#
# [101 rows x 25 columns]

# %% [markdown]
# #### Fecha de nacimiento

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['FECHA_NACIMIENTO'],  format='%d/%m/%Y', errors='coerce').dt.strftime('%d/%m/%Y')

# %%
  df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#                                     NOMBRE_CIE10_EGRESO  \
# 24    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 38    EMBOLIA Y TROMBOSIS DE OTRAS VENAS ESPECIFICAD...
# 94    RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 122   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 132   ASMA NO ALERGICA                              ...
# ...                                                 ...
# 1248  INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFI...
# 1250  CARDIOMIOPATIA DILATADA                       ...
# 1273  HEMORRAGIA INTRACEREBRAL EN HEMISFERIO, NO ESP...
# 1281  BRONQUITIS AGUDA, NO ESPECIFICADA             ...
# 1289  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES  \
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
#      Fecha consulta Semana epidemiologica Fecha de nacimiento
# 24       2025-04-16                    16          23/06/2003
# 38       2025-04-17                    16          27/11/2002
# 94       2025-04-14                    16          21/10/1997
# 122      2025-04-16                    16          15/07/2000
# 132      2025-04-15                    16          05/08/2014
# ...             ...                   ...                 ...
# 1248     2025-04-14                    16          10/09/1980
# 1250     2025-04-17                    16          07/12/1981
# 1273     2025-04-16                    16          02/10/1985
# 1281     2025-04-14                    16          26/08/1965
# 1289     2025-04-13                    16          30/06/1981
#
# [101 rows x 26 columns]

# %% [markdown]
# #### Tipo de documento: En caso de que el espacio se encuentre en blanco o con raya al piso, generar en ese espacio 999

# %%
# Reemplazar espacios en blanco o rayas al piso por "999"
df_sin_duplicados_columnas['Tipo de documento'] = df_sin_duplicados_columnas['TIPO DOCUMENTO PACIENTE'].replace(["", "_"], "999")

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#                DESTINO_EGRESO                                 NOMBRE HC  \
# 24      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 38      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 94      URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 122   SALIDA_CONSULTA_EXTERNA  HISTORIA CLINICA URGENCIAS-GINECOLOGICAS
# 132     URGENCIAS_OBSERVACION    HISTORIA CLINICA URGENCIAS-PEDIATRICAS
# ...                       ...                                       ...
# 1248    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1250    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1273    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1281    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
# 1289    URGENCIAS_OBSERVACION           INGRESO A ATENCION DE URGENCIAS
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES  \
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
#      Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 24       2025-04-16                    16          23/06/2003
# 38       2025-04-17                    16          27/11/2002
# 94       2025-04-14                    16          21/10/1997
# 122      2025-04-16                    16          15/07/2000
# 132      2025-04-15                    16          05/08/2014
# ...             ...                   ...                 ...
# 1248     2025-04-14                    16          10/09/1980
# 1250     2025-04-17                    16          07/12/1981
# 1273     2025-04-16                    16          02/10/1985
# 1281     2025-04-14                    16          26/08/1965
# 1289     2025-04-13                    16          30/06/1981
#
#      Tipo de documento
# 24                  CC
# 38                  CC
# 94                  CC
# 122                 CC
# 132                 TI
# ...                ...
# 1248                CC
# 1250                CC
# 1273                CC
# 1281                CC
# 1289                CC
#
# [101 rows x 27 columns]

# %%
df_sin_duplicados_columnas["Tipo de documento"].unique()
# Out:
# array(['CC', 'TI', 'RC', 'PPT', 'PA', 'AS', 'CN', 'SC'], dtype=object)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento'],
#       dtype='object')

# %% [markdown]
# ####	Edad en meses: Calcular en caso de que la edad en años sea cero 0.
# #### Edad años: Calcular de acuerdo a las variables fecha de nacimiento y fecha consulta.

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta

# Convertir las columnas a tipo datetime
df_sin_duplicados_columnas["Fecha de nacimiento"] = pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento'], format='%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta'], format='%d/%m/%Y')

# Función para calcular años y meses
def calcular_edad(row):
    nacimiento = row['Fecha de nacimiento']
    consulta = row['Fecha consulta']

    # Calcular la diferencia con relativedelta (maneja días/meses/años)
    delta = relativedelta(consulta, nacimiento)

    # Si hay al menos 1 año completo
    if delta.years >= 1:
        return pd.Series([delta.years, np.nan])
    else:
        # Calcular meses totales (años * 12 + meses)
        meses_totales = delta.years * 12 + delta.months
        return pd.Series([0, meses_totales])

# Aplicar la función y crear las columnas
df_sin_duplicados_columnas[['Edad años', 'Edad en meses']] = df_sin_duplicados_columnas.apply(calcular_edad, axis=1)

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento']).dt.strftime('%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta']).dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#                   VALIDACION Unidad centinela Localidad unidad centinela MES  \
# 24    126763091000938874R509      USS KENNEDY                 8. KENNEDY   4
# 38    126780521001219260R31X      USS KENNEDY                 8. KENNEDY   4
# 94    126619811006385628R104      USS KENNEDY                 8. KENNEDY   4
# 122   126752731007851688J00X      USS KENNEDY                 8. KENNEDY   4
# 132   126694371010844997R509      USS KENNEDY                 8. KENNEDY   4
# ...                      ...              ...                        ...  ..
# 1248    1266205380357279I211      USS KENNEDY                 8. KENNEDY   4
# 1250    1267776580731245R000      USS KENNEDY                 8. KENNEDY   4
# 1273    1267335380920668S009      USS KENNEDY                 8. KENNEDY   4
# 1281    1266394785433904J129      USS KENNEDY                 8. KENNEDY   4
# 1289    1265880388258409B24X      USS KENNEDY                 8. KENNEDY   4
#
#      Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 24       16/04/2025                    16          23/06/2003
# 38       17/04/2025                    16          27/11/2002
# 94       14/04/2025                    16          21/10/1997
# 122      16/04/2025                    16          15/07/2000
# 132      15/04/2025                    16          05/08/2014
# ...             ...                   ...                 ...
# 1248     14/04/2025                    16          10/09/1980
# 1250     17/04/2025                    16          07/12/1981
# 1273     16/04/2025                    16          02/10/1985
# 1281     14/04/2025                    16          26/08/1965
# 1289     13/04/2025                    16          30/06/1981
#
#      Tipo de documento Edad años Edad en meses
# 24                  CC      21.0           NaN
# 38                  CC      22.0           NaN
# 94                  CC      27.0           NaN
# 122                 CC      24.0           NaN
# 132                 TI      10.0           NaN
# ...                ...       ...           ...
# 1248                CC      44.0           NaN
# 1250                CC      43.0           NaN
# 1273                CC      39.0           NaN
# 1281                CC      59.0           NaN
# 1289                CC      43.0           NaN
#
# [101 rows x 29 columns]

# %%
df_sin_duplicados_columnas["Edad en meses"].unique()
# Out:
# array([nan,  5.,  0.])

# %%
df_sin_duplicados_columnas[df_sin_duplicados_columnas["Edad en meses"]==0]
# Out:
#      NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 690        12659136       2025-04-13 15:47:49.627                      RC
# 692        12678038       2025-04-17 13:04:47.880                      RC
# 693        12663784       2025-04-14 12:20:58.067                      RC
# 826        12664737       2025-04-14 14:00:32.900                      CN
#
#     NUMERO_DE_IDENTIFICACION                 NOMBRE_COMPLETO_PACIENTE  \
# 690               1300004947         LEONARD JEREMIAS MORENO CISNEROS
# 692               1300004974              MIA ISABELLA HUERTAS FRANCO
# 693               1300004979       ADHARA ISABELLA MERCADO ECHEVERRIA
# 826           25033010097196  HIJO DE MAYRIN ALEXANDRA GUZMAN CROQUER
#
#            FECHA_NACIMIENTO  EDAD SEXO              EAPB REGIMEN_AFILIADO  \
# 690 2025-03-14 12:44:07.257     0    M  EPS-S MUTUAL SER       SUBSIDIADO
# 692 2025-03-26 13:03:51.940     0    F     CAPITAL SALUD       SUBSIDIADO
# 693 2025-03-27 11:56:00.000     0    F     CAPITAL SALUD       SUBSIDIADO
# 826 2025-03-24 14:17:48.877     0    M     CAPITAL SALUD       SUBSIDIADO
#
#      ...                  VALIDACION Unidad centinela  \
# 690  ...      126591361300004947P599      USS KENNEDY
# 692  ...      126780381300004974J219      USS KENNEDY
# 693  ...      126637841300004979J219      USS KENNEDY
# 826  ...  1266473725033010097196J980      USS KENNEDY
#
#     Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 690                 8. KENNEDY   4     13/04/2025                    16
# 692                 8. KENNEDY   4     17/04/2025                    16
# 693                 8. KENNEDY   4     14/04/2025                    16
# 826                 8. KENNEDY   4     14/04/2025                    16
#
#     Fecha de nacimiento Tipo de documento Edad años Edad en meses
# 690          14/03/2025                RC       0.0           0.0
# 692          26/03/2025                RC       0.0           0.0
# 693          27/03/2025                RC       0.0           0.0
# 826          24/03/2025                CN       0.0           0.0
#
# [4 rows x 29 columns]

# %% [markdown]
# ### GRUPO DE EDAD: De acuerdo al intervalo
# - 0 a 5 años: 1. INFANCIA
# - 6 a 11 años: 2. INFANCIA
# - 12 a 17 años: 3. ADOLESCENCIA
# - 18 a 28 años: 4. JUVENTUD
# - 29 a 59 años: 5. ADULTEZ
# - <60 años: 6. VEJEZ

# %%
# Función para asignar el grupo de edad
def clasificar_grupo_edad(edad):
    if 0 <= edad <= 5:
        return "1. INFANCIA"
    elif 6 <= edad <= 11:
        return "2. INFANCIA"
    elif 12 <= edad <= 17:
        return "3. ADOLESCENCIA"
    elif 18 <= edad <= 28:
        return "4. JUVENTUD"
    elif 29 <= edad <= 59:
        return "5. ADULTEZ"
    else:
        return "6. VEJEZ"

# %%
# Aplicar la clasificación de grupo de edad
df_sin_duplicados_columnas['GRUPO DE EDAD'] = df_sin_duplicados_columnas["Edad años"].apply(clasificar_grupo_edad)

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#      Unidad centinela Localidad unidad centinela MES Fecha consulta  \
# 24        USS KENNEDY                 8. KENNEDY   4     16/04/2025
# 38        USS KENNEDY                 8. KENNEDY   4     17/04/2025
# 94        USS KENNEDY                 8. KENNEDY   4     14/04/2025
# 122       USS KENNEDY                 8. KENNEDY   4     16/04/2025
# 132       USS KENNEDY                 8. KENNEDY   4     15/04/2025
# ...               ...                        ...  ..            ...
# 1248      USS KENNEDY                 8. KENNEDY   4     14/04/2025
# 1250      USS KENNEDY                 8. KENNEDY   4     17/04/2025
# 1273      USS KENNEDY                 8. KENNEDY   4     16/04/2025
# 1281      USS KENNEDY                 8. KENNEDY   4     14/04/2025
# 1289      USS KENNEDY                 8. KENNEDY   4     13/04/2025
#
#      Semana epidemiologica Fecha de nacimiento Tipo de documento Edad años  \
# 24                      16          23/06/2003                CC      21.0
# 38                      16          27/11/2002                CC      22.0
# 94                      16          21/10/1997                CC      27.0
# 122                     16          15/07/2000                CC      24.0
# 132                     16          05/08/2014                TI      10.0
# ...                    ...                 ...               ...       ...
# 1248                    16          10/09/1980                CC      44.0
# 1250                    16          07/12/1981                CC      43.0
# 1273                    16          02/10/1985                CC      39.0
# 1281                    16          26/08/1965                CC      59.0
# 1289                    16          30/06/1981                CC      43.0
#
#      Edad en meses GRUPO DE EDAD
# 24             NaN   4. JUVENTUD
# 38             NaN   4. JUVENTUD
# 94             NaN   4. JUVENTUD
# 122            NaN   4. JUVENTUD
# 132            NaN   2. INFANCIA
# ...            ...           ...
# 1248           NaN    5. ADULTEZ
# 1250           NaN    5. ADULTEZ
# 1273           NaN    5. ADULTEZ
# 1281           NaN    5. ADULTEZ
# 1289           NaN    5. ADULTEZ
#
# [101 rows x 30 columns]

# %% [markdown]
# ### Sexo: Generar Mujer o Hombre, ya que en las bases aparece FEMENINO/MASCULINO o F/M.

# %%
df_sin_duplicados_columnas["SEXO"]
# Out:
# 24      F
# 38      M
# 94      M
# 122     F
# 132     M
#        ..
# 1248    M
# 1250    M
# 1273    M
# 1281    M
# 1289    M
# Name: SEXO, Length: 101, dtype: object

# %%
# Suponiendo que df_sin_duplicados_columnas es el DataFrame original
df_sin_duplicados_columnas["Sexo"] = df_sin_duplicados_columnas["SEXO"].replace({
    "FEMENINO": "MUJER",
    "MASCULINO": "HOMBRE",
    "F": "MUJER",
    "M": "HOMBRE"
})

# %%
df_sin_duplicados_columnas
# Out:
#       NUMERO_INGRESO FECHA_HORA_INGRESO_DEL_EVENTO TIPO DOCUMENTO PACIENTE  \
# 24          12676309       2025-04-16 13:03:06.310                      CC
# 38          12678052       2025-04-17 13:42:00.043                      CC
# 94          12661981       2025-04-14 09:28:44.677                      CC
# 122         12675273       2025-04-16 10:44:54.447                      CC
# 132         12669437       2025-04-15 10:54:29.553                      TI
# ...              ...                           ...                     ...
# 1248        12662053       2025-04-14 09:35:25.887                      CC
# 1250        12677765       2025-04-17 07:02:17.440                      CC
# 1273        12673353       2025-04-16 07:43:30.090                      CC
# 1281        12663947       2025-04-14 12:44:41.003                      CC
# 1289        12658803       2025-04-13 07:42:58.033                      CC
#
#      NUMERO_DE_IDENTIFICACION             NOMBRE_COMPLETO_PACIENTE  \
# 24                 1000938874      LAURA VALENTINA RINCON GONZALEZ
# 38                 1001219260              JUAN JOSE URREA ARCHILA
# 94                 1006385628             MARICELA  HINOJOSA RIVAS
# 122                1007851688       LEIDY KATERINE MONSALVE ZAPATA
# 132                1010844997        JUAN DAVID RODRIGUEZ MENDIETA
# ...                       ...                                  ...
# 1248                 80357279          VICTOR JULIO GARCIA RAMIREZ
# 1250                 80731245           WILLIAN  PALENCIA PALENCIA
# 1273                 80920668  JAIRO MIGUEL ALEXANDER MUÑOZ SOLANO
# 1281                 85433904       JAVIER ENRIQUE OSPINA MARTINEZ
# 1289                 88258409                 ANGEL TRUJILLO GOMEZ
#
#             FECHA_NACIMIENTO  EDAD SEXO  \
# 24   2003-06-23 00:00:00.000    22    F
# 38   2002-11-27 00:00:00.000    23    M
# 94   1997-10-21 09:27:59.623    28    M
# 122  2000-07-15 00:00:00.000    25    F
# 132  2014-08-05 10:52:46.937    11    M
# ...                      ...   ...  ...
# 1248 1980-09-10 09:34:43.667    45    M
# 1250 1981-12-07 00:00:00.000    44    M
# 1273 1985-10-02 00:00:00.000    40    M
# 1281 1965-08-26 00:00:00.000    60    M
# 1289 1981-06-30 08:04:45.050    44    M
#
#                                                  EAPB REGIMEN_AFILIADO  ...  \
# 24    EPS Y MEDICINA PREPAGADA SURAMERICANA S.A. - CM       SUBSIDIADO  ...
# 38                                      CAPITAL SALUD       SUBSIDIADO  ...
# 94                                      CAPITAL SALUD       SUBSIDIADO  ...
# 122                                   EPS-S NUEVA EPS       SUBSIDIADO  ...
# 132                                     EPS FAMISANAR     CONTRIBUTIVO  ...
# ...                                               ...              ...  ...
# 1248                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1250                                    EPS FAMISANAR     CONTRIBUTIVO  ...
# 1273                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1281                                    CAPITAL SALUD       SUBSIDIADO  ...
# 1289                                  EPS-S NUEVA EPS       SUBSIDIADO  ...
#
#      Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 24                   8. KENNEDY   4     16/04/2025                    16
# 38                   8. KENNEDY   4     17/04/2025                    16
# 94                   8. KENNEDY   4     14/04/2025                    16
# 122                  8. KENNEDY   4     16/04/2025                    16
# 132                  8. KENNEDY   4     15/04/2025                    16
# ...                         ...  ..            ...                   ...
# 1248                 8. KENNEDY   4     14/04/2025                    16
# 1250                 8. KENNEDY   4     17/04/2025                    16
# 1273                 8. KENNEDY   4     16/04/2025                    16
# 1281                 8. KENNEDY   4     14/04/2025                    16
# 1289                 8. KENNEDY   4     13/04/2025                    16
#
#      Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 24            23/06/2003                CC      21.0           NaN
# 38            27/11/2002                CC      22.0           NaN
# 94            21/10/1997                CC      27.0           NaN
# 122           15/07/2000                CC      24.0           NaN
# 132           05/08/2014                TI      10.0           NaN
# ...                  ...               ...       ...           ...
# 1248          10/09/1980                CC      44.0           NaN
# 1250          07/12/1981                CC      43.0           NaN
# 1273          02/10/1985                CC      39.0           NaN
# 1281          26/08/1965                CC      59.0           NaN
# 1289          30/06/1981                CC      43.0           NaN
#
#      GRUPO DE EDAD    Sexo
# 24     4. JUVENTUD   MUJER
# 38     4. JUVENTUD  HOMBRE
# 94     4. JUVENTUD  HOMBRE
# 122    4. JUVENTUD   MUJER
# 132    2. INFANCIA  HOMBRE
# ...            ...     ...
# 1248    5. ADULTEZ  HOMBRE
# 1250    5. ADULTEZ  HOMBRE
# 1273    5. ADULTEZ  HOMBRE
# 1281    5. ADULTEZ  HOMBRE
# 1289    5. ADULTEZ  HOMBRE
#
# [101 rows x 31 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'REGIMEN_AFILIADO', 'DIRECCION', 'BARRIO', 'LOCALIDAD', 'CIE10_INGRESO',
#        'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO',
#        'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.rename(columns={'REGIMEN_AFILIADO': "Regimen SGSS"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={'DIRECCION': "Dirección"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={'LOCALIDAD': "Localidad de residencia base"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'Regimen SGSS', 'Dirección', 'BARRIO', 'Localidad de residencia base',
#        'CIE10_INGRESO', 'NOMBRE_CIE10_INGRESO', 'CODIGO_CIE10_EGRESO',
#        'NOMBRE_CIE10_EGRESO', 'DESTINO_EGRESO', 'NOMBRE HC', 'VALIDACION',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses', 'GRUPO DE EDAD',
#        'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.rename(columns={'CIE10_INGRESO': "Diagnóstico de ingreso"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={'NOMBRE_CIE10_INGRESO': "Nombre del diagnóstico de ingreso"}, inplace=True)

# %%
def asignar_tipo_dx(diagnostico):
    """
    Si el diagnóstco empieza con 'I', devolvemos 'CARDIO'.
    Si empieza con 'J', devolvemos 'RESPIRATORIO'.
    En otros casos, devolvemos vacío o lo que prefieras.
    """
    if str(diagnostico).startswith('I'):
        return 'CARDIO'
    elif str(diagnostico).startswith('J'):
        return 'RESPIRATORIO'
    else:
        return ''  # puedes poner OTRO si deseas

# %%
# Creamos la nueva columna TIPO_DX
df_sin_duplicados_columnas['TIPO_DX'] = df_sin_duplicados_columnas['Diagnóstico de ingreso'].apply(asignar_tipo_dx)

# %%
import pandas as pd

# Códigos por grupo
EIC = {'I200', 'I201', 'I208', 'I209', 'I210', 'I211', 'I212', 'I213', 'I214', 'I219',
       'I220', 'I221', 'I228', 'I229', 'I230', 'I231', 'I232', 'I233', 'I234', 'I235',
       'I236', 'I237', 'I238', 'I240', 'I241', 'I248', 'I249', 'I250', 'I251', 'I252',
       'I253', 'I254', 'I255', 'I256', 'I257', 'I258', 'I259'}

ECV = {'I600', 'I601', 'I602', 'I603', 'I604', 'I605', 'I606', 'I607', 'I608', 'I609',
       'I610', 'I611', 'I612', 'I613', 'I614', 'I615', 'I616', 'I617', 'I618', 'I619',
       'I620', 'I621', 'I629', 'I630', 'I631', 'I632', 'I633', 'I634', 'I635', 'I636',
       'I637', 'I638', 'I639', 'I64X', 'I650', 'I651', 'I652', 'I653', 'I658', 'I659',
       'I660', 'I661', 'I662', 'I663', 'I664', 'I668', 'I669', 'I670', 'I671', 'I672',
       'I673', 'I674', 'I675', 'I676', 'I677', 'I678', 'I679', 'I680', 'I681', 'I682', 'I688',
       'I690', 'I691', 'I692', 'I693', 'I694', 'I698'}

IRA = {'J00X', 'J09X', 'J13X', 'J14X', 'J22X',
       'J010', 'J011', 'J012', 'J013', 'J014', 'J015', 'J016', 'J017', 'J018', 'J019',
       'J020', 'J028', 'J029', 'J030', 'J038', 'J039', 'J040', 'J041', 'J042', 'J050', 'J051',
       'J060', 'J068', 'J069', 'J100', 'J101', 'J108', 'J110', 'J111', 'J118', 'J120', 'J121',
       'J122', 'J123', 'J128', 'J129', 'J150', 'J151', 'J152', 'J153', 'J154', 'J155', 'J156',
       'J157', 'J158', 'J159', 'J160', 'J168', 'J170', 'J171', 'J172', 'J173', 'J178',
       'J180', 'J181', 'J182', 'J188', 'J189', 'J200', 'J201', 'J202', 'J203', 'J204', 'J205',
       'J206', 'J207', 'J208', 'J209', 'J210', 'J211', 'J218', 'J219'}

EPOC = {'J40X', 'J410', 'J411', 'J418', 'J42X', 'J430',
        'J431', 'J432', 'J438', 'J439', 'J440', 'J441', 'J448', 'J449', 'J47X'}

ASMA = {'J450', 'J451', 'J458', 'J459', 'J46X'}

# %%
# Función de clasificación
def clasificar_diagnostico(codigo):
    if pd.isna(codigo):
        return None
    codigo = str(codigo).strip().upper()
    if codigo in EIC:
        return "EIC"
    elif codigo in ECV:
        return "ECV"
    elif codigo.startswith('I'):
        return "Otras cardiovasculares"
    elif codigo in IRA:
        return "Infecciones respiratorias agudas"
    elif codigo in EPOC:
        return "EPOC"
    elif codigo in ASMA:
        return "Asma"
    elif codigo.startswith('J'):
        return "Otras respiratorias"
    else:
        return None


df_sin_duplicados_columnas['SUBDX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(clasificar_diagnostico)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'NUMERO_DE_IDENTIFICACION',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'Regimen SGSS', 'Dirección', 'BARRIO', 'Localidad de residencia base',
#        'Diagnóstico de ingreso', 'Nombre del diagnóstico de ingreso',
#        'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO', 'DESTINO_EGRESO',
#        'NOMBRE HC', 'VALIDACION', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo', 'TIPO_DX',
#        'SUBDX'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.rename(columns={'NUMERO_DE_IDENTIFICACION': "No de documento"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={ 'EAPB': "EAPB"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['NUMERO_INGRESO', 'FECHA_HORA_INGRESO_DEL_EVENTO',
#        'TIPO DOCUMENTO PACIENTE', 'No de documento',
#        'NOMBRE_COMPLETO_PACIENTE', 'FECHA_NACIMIENTO', 'EDAD', 'SEXO', 'EAPB',
#        'Regimen SGSS', 'Dirección', 'BARRIO', 'Localidad de residencia base',
#        'Diagnóstico de ingreso', 'Nombre del diagnóstico de ingreso',
#        'CODIGO_CIE10_EGRESO', 'NOMBRE_CIE10_EGRESO', 'DESTINO_EGRESO',
#        'NOMBRE HC', 'VALIDACION', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo', 'TIPO_DX',
#        'SUBDX'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas.rename(columns={'CODIGO_CIE10_EGRESO': "Diagnóstico de egreso",  'NOMBRE_CIE10_EGRESO': "Nombre del diagnóstico de egreso"}, inplace=True)

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].replace('',"999", inplace=True)
# Out:
# <ipython-input-96-8f51a3f2211d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)
# Out:
# <ipython-input-97-aa0c04562abd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Fecha egreso"]="999"

# %%
variables_def=['Unidad centinela',  'Localidad unidad centinela', 'MES', 'Fecha consulta',
       'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento', 'No de documento', 'Edad en meses',
 'Edad años','GRUPO DE EDAD', 'Sexo', 'EAPB', 'Regimen SGSS', 'Dirección',
       'Localidad de residencia base', 'Diagnóstico de ingreso',
       'Nombre del diagnóstico de ingreso', 'TIPO_DX', 'SUBDX', "Diagnóstico secundario", "Nombre del diagnóstico secundario", "Diagnóstico secundario", "Nombre del diagnóstico secundario",
        "Diagnóstico de egreso",   "Nombre del diagnóstico de egreso"  , "Fecha egreso"  ]

# %%
df_sin_duplicados_columnas_filtrada=df_sin_duplicados_columnas[variables_def]

# %%
df_sin_duplicados_columnas_filtrada.to_excel("Base_Kennedy_2.xlsx",index=False)
