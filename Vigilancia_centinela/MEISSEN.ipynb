# %% [markdown]
# </center>
#
# ---
# # MEISSEN
# ---

# %% [markdown]
# ## Identificación, Filtrado y Exportación de Registros Duplicados en un DataFrame

# %% [markdown]
#  estas dos líneas de código preparan tu entorno para trabajar con datos cargando las herramientas necesarias (pandas y numpy) y proporcionando nombres abreviados convenientes para ellos (pd y np).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Las siguientes dos líneas de código hacen lo siguiente:
#
# - Leen un archivo de Excel ubicado en una ruta específica.
# - Ignoran las primeras 5 filas del archivo.
# - Crean un DataFrame llamado df con los datos del archivo.
# - Muestran el DataFrame df

# %% [markdown]
# Reemplazar la ruta del archivo

# %%
df=pd.read_excel("/content/DGReport_SEMANA20_USS_MEISSEN.xlsx", skiprows=0)
df
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0            ME  HOSPITAL MEISSEN  HCW068
# 1            ME  HOSPITAL MEISSEN  HCW067
# 2            ME  HOSPITAL MEISSEN  HCW068
# 3            ME  HOSPITAL MEISSEN   HC210
# 4            ME  HOSPITAL MEISSEN  HCW210
# ...         ...               ...     ...
# 1911         ME  HOSPITAL MEISSEN  HCW067
# 1912         ME  HOSPITAL MEISSEN  HCW089
# 1913         ME  HOSPITAL MEISSEN  HCW089
# 1914         ME  HOSPITAL MEISSEN  HCW068
# 1915         ME  HOSPITAL MEISSEN  HCW067
#
#                                           NOMBRE_TIPOHC   INGRESO  \
# 0                        CONSULTA  INICIAL DE URGENCIAS  16136461
# 1                                EVOLUCION DE URGENCIAS  16136461
# 2                        CONSULTA  INICIAL DE URGENCIAS  16136464
# 3     NOTA CLINICA SOLICITUD APOYO DIAGNOSTICO Y/O F...  16136464
# 4     NOTA CLINICA SOLICITUD APOYO DIAGNOSTICO Y/O F...  16136464
# ...                                                 ...       ...
# 1911                             EVOLUCION DE URGENCIAS  16152797
# 1912          CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152823
# 1913          CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
# 1914                     CONSULTA  INICIAL DE URGENCIAS  16152874
# 1915                             EVOLUCION DE URGENCIAS  16152874
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 1    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 2    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 3    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 4    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-14  B02ME
# ...                      ...           ...         ...            ...    ...
# 1911 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B02ME
# 1912 2025-04-19 23:15:37.507   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
# 1914 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1915 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B02ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 0     ...        FES03414  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 1     ...        FES03414  1018469362     CACERES CABALLERO PAOLA ANDREA
# 2     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 3     ...          S07101  1110451432          MOYA BERNAL CINDY MAYERLY
# 4     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# ...   ...             ...         ...                                 ...
# 1911  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1912  ...          EPSS08  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1914  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1915  ...        FES03414      479471      ALVAREZ ROMERO OSMAN HUMBERTO
#
#                           ESPECIALIDAD DIAGNOSTICO  \
# 0                     MEDICINA GENERAL        S212
# 1                     MEDICINA GENERAL        S212
# 2                     MEDICINA GENERAL        S510
# 3     MEDICINA GENERAL OTROS PAGADORES        S510
# 4                     MEDICINA GENERAL        S520
# ...                                ...         ...
# 1911                  MEDICINA GENERAL        J441
# 1912      MEDICINA GENERAL - PROGRAMAS        G473
# 1913      MEDICINA GENERAL - PROGRAMAS        J459
# 1914                  MEDICINA GENERAL        R104
# 1915                  MEDICINA GENERAL        N300
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 1     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 2     HERIDA DEL CODO                               ...  PRINCIPAL
# 3     HERIDA DEL CODO                               ...  PRINCIPAL
# 4     FRACTURA DE LA EPIFISIS SUPERIOR DEL CUBITO   ...  PRINCIPAL
# ...                                                 ...        ...
# 1911  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1912  APNEA DEL SUEÑO                               ...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# 1914  OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...  PRINCIPAL
# 1915  CISTITIS AGUDAS                               ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 0                NaN                 NaN       NaN
# 1                NaN                 NaN       NaN
# 2                NaN                 NaN       NaN
# 3                NaN                 NaN       NaN
# 4                NaN                 NaN       NaN
# ...              ...                 ...       ...
# 1911             NaN                 NaN       NaN
# 1912             NaN                 NaN       NaN
# 1913             NaN                 NaN       NaN
# 1914             NaN                 NaN       NaN
# 1915             NaN                 NaN       NaN
#
# [1916 rows x 43 columns]

# %% [markdown]
# Esta línea es la encargada de mostrar las dimensiones (número de filas y columnas) del DataFrame llamado df

# %%
print(f"La base tiene {df.shape[0]} filas y {df.shape[1]} columnas  ")
# Out:
# La base tiene 1916 filas y 43 columnas

# %% [markdown]
# Este apartado identifica y elimina las opciones diferentes a "CONSULTA INICIAL DE URGENCIAS" y "CONSULTA INICIAL DE URGENCIAS PEDIATRICA" en la columna "NOMBRE_TIPOHC"

# %%
df.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %% [markdown]
# - filtrar la base por  ['NOMBRE_TIPOHC']=='CONSULTA  INICIAL DE URGENCIAS') ['NOMBRE_TIPOHC']=='CONSULTA INICIAL DE URGENCIAS  PEDIATRICA')

# %%
df['NOMBRE_TIPOHC'].unique()
# Out:
# array([' CONSULTA  INICIAL DE URGENCIAS', 'EVOLUCION DE URGENCIAS',
#        'NOTA CLINICA SOLICITUD APOYO DIAGNOSTICO Y/O FORMULACION',
#        'NOTA CLINICA WEB', 'CONSULTA INICIAL DE URGENCIAS  PEDIATRICA',
#        'INTERPRETACION DE APOYO DIAGNOSTICOS', 'NOTA CONSULTA EXTERNA',
#        'SOLICITUD DE HEMOCOMPONENTES PARA TRANSFUNDIR',
#        'RESERVA DE HEMOCOMPONENTES PARA TRANSFUNDIR',
#        'HISTORIA DE URGENCIAS OBSTETRICIA',
#        'HISTORIA URGENCIAS GINECOLOGIA', 'RESPUESTA A INTERCONSULTA',
#        'NOTA ACLARATORIA HC'], dtype=object)

# %%
df
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0            ME  HOSPITAL MEISSEN  HCW068
# 1            ME  HOSPITAL MEISSEN  HCW067
# 2            ME  HOSPITAL MEISSEN  HCW068
# 3            ME  HOSPITAL MEISSEN   HC210
# 4            ME  HOSPITAL MEISSEN  HCW210
# ...         ...               ...     ...
# 1911         ME  HOSPITAL MEISSEN  HCW067
# 1912         ME  HOSPITAL MEISSEN  HCW089
# 1913         ME  HOSPITAL MEISSEN  HCW089
# 1914         ME  HOSPITAL MEISSEN  HCW068
# 1915         ME  HOSPITAL MEISSEN  HCW067
#
#                                           NOMBRE_TIPOHC   INGRESO  \
# 0                        CONSULTA  INICIAL DE URGENCIAS  16136461
# 1                                EVOLUCION DE URGENCIAS  16136461
# 2                        CONSULTA  INICIAL DE URGENCIAS  16136464
# 3     NOTA CLINICA SOLICITUD APOYO DIAGNOSTICO Y/O F...  16136464
# 4     NOTA CLINICA SOLICITUD APOYO DIAGNOSTICO Y/O F...  16136464
# ...                                                 ...       ...
# 1911                             EVOLUCION DE URGENCIAS  16152797
# 1912          CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152823
# 1913          CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
# 1914                     CONSULTA  INICIAL DE URGENCIAS  16152874
# 1915                             EVOLUCION DE URGENCIAS  16152874
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 1    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 2    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 3    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 4    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-14  B02ME
# ...                      ...           ...         ...            ...    ...
# 1911 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B02ME
# 1912 2025-04-19 23:15:37.507   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
# 1914 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1915 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B02ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 0     ...        FES03414  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 1     ...        FES03414  1018469362     CACERES CABALLERO PAOLA ANDREA
# 2     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 3     ...          S07101  1110451432          MOYA BERNAL CINDY MAYERLY
# 4     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# ...   ...             ...         ...                                 ...
# 1911  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1912  ...          EPSS08  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1914  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1915  ...        FES03414      479471      ALVAREZ ROMERO OSMAN HUMBERTO
#
#                           ESPECIALIDAD DIAGNOSTICO  \
# 0                     MEDICINA GENERAL        S212
# 1                     MEDICINA GENERAL        S212
# 2                     MEDICINA GENERAL        S510
# 3     MEDICINA GENERAL OTROS PAGADORES        S510
# 4                     MEDICINA GENERAL        S520
# ...                                ...         ...
# 1911                  MEDICINA GENERAL        J441
# 1912      MEDICINA GENERAL - PROGRAMAS        G473
# 1913      MEDICINA GENERAL - PROGRAMAS        J459
# 1914                  MEDICINA GENERAL        R104
# 1915                  MEDICINA GENERAL        N300
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 1     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 2     HERIDA DEL CODO                               ...  PRINCIPAL
# 3     HERIDA DEL CODO                               ...  PRINCIPAL
# 4     FRACTURA DE LA EPIFISIS SUPERIOR DEL CUBITO   ...  PRINCIPAL
# ...                                                 ...        ...
# 1911  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1912  APNEA DEL SUEÑO                               ...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# 1914  OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...  PRINCIPAL
# 1915  CISTITIS AGUDAS                               ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 0                NaN                 NaN       NaN
# 1                NaN                 NaN       NaN
# 2                NaN                 NaN       NaN
# 3                NaN                 NaN       NaN
# 4                NaN                 NaN       NaN
# ...              ...                 ...       ...
# 1911             NaN                 NaN       NaN
# 1912             NaN                 NaN       NaN
# 1913             NaN                 NaN       NaN
# 1914             NaN                 NaN       NaN
# 1915             NaN                 NaN       NaN
#
# [1916 rows x 43 columns]

# %%
df=df[(df['NOMBRE_TIPOHC']==' CONSULTA  INICIAL DE URGENCIAS') | (df['NOMBRE_TIPOHC']=='CONSULTA INICIAL DE URGENCIAS  PEDIATRICA') |(df['NOMBRE_TIPOHC']=='CONSULTA  INICIAL DE URGENCIAS')]

# %%
df
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0            ME  HOSPITAL MEISSEN  HCW068
# 2            ME  HOSPITAL MEISSEN  HCW068
# 7            ME  HOSPITAL MEISSEN  HCW068
# 19           ME  HOSPITAL MEISSEN  HCW089
# 21           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1912         ME  HOSPITAL MEISSEN  HCW089
# 1913         ME  HOSPITAL MEISSEN  HCW089
# 1914         ME  HOSPITAL MEISSEN  HCW068
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 0                CONSULTA  INICIAL DE URGENCIAS  16136461
# 2                CONSULTA  INICIAL DE URGENCIAS  16136464
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 19    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136474
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# ...                                         ...       ...
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1912  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152823
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
# 1914             CONSULTA  INICIAL DE URGENCIAS  16152874
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 2    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 19   2025-04-13 01:54:11.537   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1912 2025-04-19 23:15:37.507   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
# 1914 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 0     ...        FES03414  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 2     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 19    ...          C06902  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# ...   ...             ...         ...                                 ...
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1912  ...          EPSS08  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1914  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 0                 MEDICINA GENERAL        S212
# 2                 MEDICINA GENERAL        S510
# 7           MEDICINA GENERAL MIXTA        J989
# 19          MEDICINA GENERAL MIXTA        R509
# 21          MEDICINA GENERAL MIXTA        J050
# ...                            ...         ...
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1912  MEDICINA GENERAL - PROGRAMAS        G473
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
# 1914              MEDICINA GENERAL        R104
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 2     HERIDA DEL CODO                               ...  PRINCIPAL
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 19    FIEBRE NO ESPECIFICADA                        ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# ...                                                 ...        ...
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1912  APNEA DEL SUEÑO                               ...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# 1914  OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 0                NaN                 NaN       NaN
# 2                NaN                 NaN       NaN
# 7                NaN                 NaN       NaN
# 19               NaN                 NaN       NaN
# 21               NaN                 NaN       NaN
# ...              ...                 ...       ...
# 1908             NaN                 NaN       NaN
# 1910             NaN                 NaN       NaN
# 1912             NaN                 NaN       NaN
# 1913             NaN                 NaN       NaN
# 1914             NaN                 NaN       NaN
#
# [870 rows x 43 columns]

# %%
df['DIASGNOSTICO_EGRESO'].isna().sum()
# Out:
# np.int64(796)

# %%
# Identificar filas duplicadas
duplicados = df[df.duplicated(keep=False)]

# Mostrar filas duplicadas
print(f"Filas duplicadas:{duplicados}")

# Contar cuántas filas duplicadas hay
num_duplicados = len(duplicados)
print(f"Número de filas duplicadas: {num_duplicados}\n")
# Out:
# Filas duplicadas:     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 532          ME  HOSPITAL MEISSEN  HCW089
# 533          ME  HOSPITAL MEISSEN  HCW089
# 1473         ME  HOSPITAL MEISSEN  HCW068
# 1474         ME  HOSPITAL MEISSEN  HCW068
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 532   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16141061
# 533   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16141061
# 1473             CONSULTA  INICIAL DE URGENCIAS  16151416
# 1474             CONSULTA  INICIAL DE URGENCIAS  16151416
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 532  2025-04-14 15:32:03.803  HOSPITALARIO   URGENCIAS     2025-04-14  B01TN
# 533  2025-04-14 15:32:03.803  HOSPITALARIO   URGENCIAS     2025-04-14  B01TN
# 1473 2025-04-17 23:27:17.377  HOSPITALARIO   URGENCIAS     2025-04-18  B01VB
# 1474 2025-04-17 23:27:17.377  HOSPITALARIO   URGENCIAS     2025-04-18  B01VB
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 532   ...        FES03414  1001064410  AMARILLO VILLAMARIN HEIDI TATIANA
# 533   ...        FES03414  1001064410  AMARILLO VILLAMARIN HEIDI TATIANA
# 1473  ...        FES03414  1026550900         CEPEDA MURCIA JUAN GABRIEL
# 1474  ...        FES03414  1026550900         CEPEDA MURCIA JUAN GABRIEL
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 532   MEDICINA GENERAL - PROGRAMAS        J00X
# 533   MEDICINA GENERAL - PROGRAMAS        J00X
# 1473              MEDICINA GENERAL        O470
# 1474              MEDICINA GENERAL        O470
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 532   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 533   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1473  FALSO TRABAJO DE PARTO ANTES DE LA 37 SEMANAS ...  PRINCIPAL
# 1474  FALSO TRABAJO DE PARTO ANTES DE LA 37 SEMANAS ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO  DX_EGRESO
# 532         425199.0                J121  DX_EGRESO
# 533         425199.0                J121  DX_EGRESO
# 1473        425207.0                O470  DX_EGRESO
# 1474        425207.0                O470  DX_EGRESO
#
# [4 rows x 43 columns]
# Número de filas duplicadas: 4

# %% [markdown]
# # Paso 2: Eliminar todas las filas duplicadas (considerando todas las columnas)

# %% [markdown]
# sirve para eliminar filas duplicadas de un conjunto de datos (DataFrame) en Python. Esto significa que, si hay dos o más filas con exactamente la misma información en todas las columnas, solo se conservará una de ellas, eliminando las demás.
#
# El resultado se guarda en una nueva variable (df_sin_duplicados), dejando el DataFrame original (df) sin cambios.

# %%
df_sin_duplicados = df.drop_duplicates()
df_sin_duplicados
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0            ME  HOSPITAL MEISSEN  HCW068
# 2            ME  HOSPITAL MEISSEN  HCW068
# 7            ME  HOSPITAL MEISSEN  HCW068
# 19           ME  HOSPITAL MEISSEN  HCW089
# 21           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1912         ME  HOSPITAL MEISSEN  HCW089
# 1913         ME  HOSPITAL MEISSEN  HCW089
# 1914         ME  HOSPITAL MEISSEN  HCW068
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 0                CONSULTA  INICIAL DE URGENCIAS  16136461
# 2                CONSULTA  INICIAL DE URGENCIAS  16136464
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 19    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136474
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# ...                                         ...       ...
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1912  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152823
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
# 1914             CONSULTA  INICIAL DE URGENCIAS  16152874
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0    2025-04-13 00:43:41.720   AMBULATORIO   URGENCIAS     2025-04-13  B02ME
# 2    2025-04-13 00:52:26.050  HOSPITALARIO   URGENCIAS     2025-04-13  B02ME
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 19   2025-04-13 01:54:11.537   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1912 2025-04-19 23:15:37.507   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
# 1914 2025-04-19 23:43:25.380   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 0     ...        FES03414  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 2     ...          S07101  1052397015  MANOSALVA TORRES ANGELA DEL PILAR
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 19    ...          C06902  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# ...   ...             ...         ...                                 ...
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1912  ...          EPSS08  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1914  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 0                 MEDICINA GENERAL        S212
# 2                 MEDICINA GENERAL        S510
# 7           MEDICINA GENERAL MIXTA        J989
# 19          MEDICINA GENERAL MIXTA        R509
# 21          MEDICINA GENERAL MIXTA        J050
# ...                            ...         ...
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1912  MEDICINA GENERAL - PROGRAMAS        G473
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
# 1914              MEDICINA GENERAL        R104
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0     HERIDA DE LA PARED POSTERIOR DEL TORAX        ...  PRINCIPAL
# 2     HERIDA DEL CODO                               ...  PRINCIPAL
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 19    FIEBRE NO ESPECIFICADA                        ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# ...                                                 ...        ...
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1912  APNEA DEL SUEÑO                               ...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# 1914  OTROS DOLORES ABDOMINALES Y LOS NO ESPECIFICAD...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 0                NaN                 NaN       NaN
# 2                NaN                 NaN       NaN
# 7                NaN                 NaN       NaN
# 19               NaN                 NaN       NaN
# 21               NaN                 NaN       NaN
# ...              ...                 ...       ...
# 1908             NaN                 NaN       NaN
# 1910             NaN                 NaN       NaN
# 1912             NaN                 NaN       NaN
# 1913             NaN                 NaN       NaN
# 1914             NaN                 NaN       NaN
#
# [868 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO'],
#       dtype='object')

# %%
df_sin_duplicados['DIASGNOSTICO_EGRESO'].isna().sum()
# Out:
# np.int64(796)

# %% [markdown]
# Este codigo filtra los CIE 10 en diagnosticos de ingreso y diagnostico de egreso que pertenezcan a la vigilancia

# %%
# Las columnas son de tipo string
df_sin_duplicados['DIAGNOSTICO'] = df_sin_duplicados['DIAGNOSTICO'].astype(str)
df_sin_duplicados['DIASGNOSTICO_EGRESO'] = df_sin_duplicados['DIASGNOSTICO_EGRESO'].astype(str)
df_sin_duplicados['DIASGNOSTICO_EGRESO'] = df_sin_duplicados['DIASGNOSTICO_EGRESO'].astype(str).replace('nan', '')

# Crear condiciones de filtrado
condicion_ingreso = df_sin_duplicados['DIAGNOSTICO'].str.startswith(('I', 'J'))
condicion_egreso = df_sin_duplicados['DIASGNOSTICO_EGRESO'].str.startswith(('I', 'J', ))
# Out:
# <ipython-input-15-405e01d518c6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['DIAGNOSTICO'] = df_sin_duplicados['DIAGNOSTICO'].astype(str)
# <ipython-input-15-405e01d518c6>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['DIASGNOSTICO_EGRESO'] = df_sin_duplicados['DIASGNOSTICO_EGRESO'].astype(str)
# <ipython-input-15-405e01d518c6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['DIASGNOSTICO_EGRESO'] = df_sin_duplicados['DIASGNOSTICO_EGRESO'].astype(str).replace('nan', '')

# %% [markdown]
# El siguiente codigo permite anexar los diagnosticos ajenos a las j y a las i que pertenecen a la vigilancia centinela

# %%
# Lista de códigos específicos de egreso adicionales
codigos_adicionales = ["A419","C340","C341","C349","C450","C716","D022","D381","D386","D430",
                       "G468","R001","R092","R570","R571","R572","R579","R960","R961","R98X","Z515"]  #

#  condición para incluir los códigos específicos adicionales
condicion_codigos_adicionales = (df_sin_duplicados['DIASGNOSTICO_EGRESO'].isin(codigos_adicionales)) & condicion_ingreso

condicion_vacios=  (df_sin_duplicados['DIASGNOSTICO_EGRESO'] == '') & condicion_ingreso

# Combinar todas las condiciones
condicion_total = condicion_ingreso | condicion_egreso | condicion_codigos_adicionales| condicion_vacios

# Filtrar el DataFrame
df_sin_duplicados = df_sin_duplicados[condicion_total]

# %%
#df_sin_duplicados.to_excel("prueba.xlsx")

# %%
df_sin_duplicados
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 7            ME  HOSPITAL MEISSEN  HCW068
# 21           ME  HOSPITAL MEISSEN  HCW089
# 23           ME  HOSPITAL MEISSEN  HCW089
# 37           ME  HOSPITAL MEISSEN  HCW068
# 62           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1901         ME  HOSPITAL MEISSEN  HCW089
# 1905         ME  HOSPITAL MEISSEN  HCW089
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1913         ME  HOSPITAL MEISSEN  HCW089
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 23    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 37               CONSULTA  INICIAL DE URGENCIAS  16136504
# 62    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ...                                         ...       ...
# 1901  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 1905  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 23   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 37   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 62   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1901 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1905 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 23    ...          S06902  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 37    ...        FES03414  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 62    ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ...   ...             ...         ...                                 ...
# 1901  ...          C01705  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1905  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 7           MEDICINA GENERAL MIXTA        J989
# 21          MEDICINA GENERAL MIXTA        J050
# 23          MEDICINA GENERAL MIXTA        J219
# 37                MEDICINA GENERAL        J441
# 62                MEDICINA GENERAL        J459
# ...                            ...         ...
# 1901  MEDICINA GENERAL - PROGRAMAS        J00X
# 1905  MEDICINA GENERAL - PROGRAMAS        J00X
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 23    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 37    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 62    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ...                                                 ...        ...
# 1901  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1905  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 7                NaN                           NaN
# 21               NaN                           NaN
# 23               NaN                           NaN
# 37               NaN                           NaN
# 62               NaN                           NaN
# ...              ...                 ...       ...
# 1901             NaN                           NaN
# 1905             NaN                           NaN
# 1908             NaN                           NaN
# 1910             NaN                           NaN
# 1913             NaN                           NaN
#
# [230 rows x 43 columns]

# %%
df_sin_duplicados['DIASGNOSTICO_EGRESO'].unique()
# Out:
# array(['', 'G402', 'J209', 'J159', 'J46X', 'J121', 'J219', 'J039', 'J410',
#        'J459', 'J980', 'J122'], dtype=object)

# %%
# Eliminar registros donde 'CODIGO_CIE10_EGRESO' no cumpla las condiciones
condicion_egreso_final = df_sin_duplicados['DIASGNOSTICO_EGRESO'].str.startswith(('I', 'J')) | df_sin_duplicados['DIASGNOSTICO_EGRESO'].isin(codigos_adicionales) | (df_sin_duplicados['DIASGNOSTICO_EGRESO'] == '')
df_sin_duplicados = df_sin_duplicados[condicion_egreso_final]

# %%
df_sin_duplicados
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 7            ME  HOSPITAL MEISSEN  HCW068
# 21           ME  HOSPITAL MEISSEN  HCW089
# 23           ME  HOSPITAL MEISSEN  HCW089
# 37           ME  HOSPITAL MEISSEN  HCW068
# 62           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1901         ME  HOSPITAL MEISSEN  HCW089
# 1905         ME  HOSPITAL MEISSEN  HCW089
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1913         ME  HOSPITAL MEISSEN  HCW089
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 23    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 37               CONSULTA  INICIAL DE URGENCIAS  16136504
# 62    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ...                                         ...       ...
# 1901  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 1905  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 23   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 37   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 62   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1901 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1905 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 23    ...          S06902  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 37    ...        FES03414  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 62    ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ...   ...             ...         ...                                 ...
# 1901  ...          C01705  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1905  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 7           MEDICINA GENERAL MIXTA        J989
# 21          MEDICINA GENERAL MIXTA        J050
# 23          MEDICINA GENERAL MIXTA        J219
# 37                MEDICINA GENERAL        J441
# 62                MEDICINA GENERAL        J459
# ...                            ...         ...
# 1901  MEDICINA GENERAL - PROGRAMAS        J00X
# 1905  MEDICINA GENERAL - PROGRAMAS        J00X
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 23    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 37    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 62    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ...                                                 ...        ...
# 1901  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1905  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 7                NaN                           NaN
# 21               NaN                           NaN
# 23               NaN                           NaN
# 37               NaN                           NaN
# 62               NaN                           NaN
# ...              ...                 ...       ...
# 1901             NaN                           NaN
# 1905             NaN                           NaN
# 1908             NaN                           NaN
# 1910             NaN                           NaN
# 1913             NaN                           NaN
#
# [229 rows x 43 columns]

# %%
df_sin_duplicados['DIASGNOSTICO_EGRESO'].isna().sum()
# Out:
# np.int64(0)

# %%
#df_sin_duplicados.to_excel("Base_prueba.xlsx",index=False)

# %% [markdown]
# # Paso 3: Identificar duplicados basados en ciertas columnas ('Documento', "Fecha Ingreso", "Codigo CIE10")

# %% [markdown]
# Resumen general del código:
# - Busca filas duplicadas basándose solo en las columnas especificadas ('Documento', 'Fecha Ingreso', 'Codigo CIE10').
# - Guarda las filas duplicadas en un nuevo DataFrame (duplicados_columnas).
# - Cuenta cuántas filas duplicadas hay en total (num_duplicados_columnas).

# %%
df_sin_duplicados.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO'],
#       dtype='object')

# %%
duplicados_columnas = df_sin_duplicados[df_sin_duplicados.duplicated(subset=['DOCUMENTO', 'FECHA_INGRESO'], keep=False)]
num_duplicados_columnas = len(duplicados_columnas)

# %%
duplicados_columnas
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 197          ME  HOSPITAL MEISSEN  HCW089
# 198          ME  HOSPITAL MEISSEN  HCW089
# 484          ME  HOSPITAL MEISSEN  HCW089
# 490          ME  HOSPITAL MEISSEN  HCW089
# 949          ME  HOSPITAL MEISSEN  HCW089
# 950          ME  HOSPITAL MEISSEN  HCW089
# 1233         ME  HOSPITAL MEISSEN  HCW089
# 1234         ME  HOSPITAL MEISSEN  HCW089
# 1409         ME  HOSPITAL MEISSEN  HCW089
# 1410         ME  HOSPITAL MEISSEN  HCW089
# 1807         ME  HOSPITAL MEISSEN  HCW089
# 1809         ME  HOSPITAL MEISSEN  HCW089
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 197   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16137004
# 198   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16137004
# 484   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16140423
# 490   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16140423
# 949   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16148005
# 950   CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16148005
# 1233  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16151090
# 1234  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16151090
# 1409  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16151328
# 1410  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16151328
# 1807  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152162
# 1809  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152162
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 197  2025-04-13 17:08:34.433   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 198  2025-04-13 17:08:34.433   AMBULATORIO   URGENCIAS     2025-04-15  B01ME
# 484  2025-04-14 13:01:56.677  HOSPITALARIO   URGENCIAS     2025-04-14  B01TN
# 490  2025-04-14 13:01:56.677  HOSPITALARIO   URGENCIAS     2025-04-14  B01ME
# 949  2025-04-16 02:50:44.933   AMBULATORIO   URGENCIAS     2025-04-16  B05ME
# 950  2025-04-16 02:50:44.933   AMBULATORIO   URGENCIAS     2025-04-16  B05ME
# 1233 2025-04-17 01:10:55.340   AMBULATORIO   URGENCIAS     2025-04-17  B05ME
# 1234 2025-04-17 01:10:55.340   AMBULATORIO   URGENCIAS     2025-04-18  B01ME
# 1409 2025-04-17 16:54:25.170   AMBULATORIO   URGENCIAS     2025-04-17  B05ME
# 1410 2025-04-17 16:54:25.170   AMBULATORIO   URGENCIAS     2025-04-17  B05ME
# 1807 2025-04-19 14:06:10.967   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1809 2025-04-19 14:06:10.967   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 197   ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# 198   ...        FES03414  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 484   ...        FES03414  1007648257   VILLALOBOS ORTIZ MARIA ALEJANDRA
# 490   ...        FES03414  1001199647       CACERES LINCE LAURA PATRICIA
# 949   ...          S00511  1033789446              MERCHAN ANGULO RAFAEL
# 950   ...          S00511  1033789446              MERCHAN ANGULO RAFAEL
# 1233  ...      FET00165IR  1018472870         URIBE PRADA DANIEL RICARDO
# 1234  ...      FET00165IR  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1409  ...        FES03414  1039695333       SANCHEZ ROJAS KEVIN LEONARDO
# 1410  ...        FES03414  1039695333       SANCHEZ ROJAS KEVIN LEONARDO
# 1807  ...      FET00165IR    80028059       MUÑOZ BUENO YAITHER GILBERTO
# 1809  ...      FET00165IR    80028059       MUÑOZ BUENO YAITHER GILBERTO
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 197               MEDICINA GENERAL        J00X
# 198         MEDICINA GENERAL MIXTA        J209
# 484   MEDICINA GENERAL - PROGRAMAS        M545
# 490         MEDICINA GENERAL MIXTA        R529
# 949         MEDICINA GENERAL MIXTA        J00X
# 950         MEDICINA GENERAL MIXTA        J00X
# 1233              MEDICINA GENERAL        J039
# 1234  MEDICINA GENERAL - PROGRAMAS        J039
# 1409              MEDICINA GENERAL        J00X
# 1410              MEDICINA GENERAL        J00X
# 1807              MEDICINA GENERAL        J00X
# 1809              MEDICINA GENERAL        J050
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 197   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 198   BRONQUITIS AGUDA, NO ESPECIFICADA             ...  PRINCIPAL
# 484   LUMBAGO NO ESPECIFICADO                       ...  PRINCIPAL
# 490   DOLOR, NO ESPECIFICADO                        ...  PRINCIPAL
# 949   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 950   RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1233  AMIGDALITIS AGUDA, NO ESPECIFICADA            ...  PRINCIPAL
# 1234  AMIGDALITIS AGUDA, NO ESPECIFICADA            ...  PRINCIPAL
# 1409  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1410  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1807  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1809  LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO  DX_EGRESO
# 197              NaN                            NaN
# 198              NaN                            NaN
# 484         425261.0                J209  DX_EGRESO
# 490         425261.0                J209  DX_EGRESO
# 949              NaN                            NaN
# 950              NaN                            NaN
# 1233             NaN                            NaN
# 1234             NaN                            NaN
# 1409             NaN                            NaN
# 1410             NaN                            NaN
# 1807             NaN                            NaN
# 1809             NaN                            NaN
#
# [12 rows x 43 columns]

# %%
print(f"Número de filas duplicadas basadas :en las columnas: {num_duplicados_columnas}\n")
# Out:
# Número de filas duplicadas basadas :en las columnas: 12

# %% [markdown]
# # Paso 4: Eliminar duplicados basados en ciertas columnas ('col1', 'col2')

# %% [markdown]
# - Identifica duplicados considerando únicamente las columnas 'Documento', 'Fecha Ingreso', y 'Codigo CIE10'.
# - En cada grupo de duplicados, elimina todas las filas excepto la última.
# - Devuelve un nuevo DataFrame sin duplicados llamado df_sin_duplicados_columnas.

# %%
df_sin_duplicados_columnas = df_sin_duplicados.drop_duplicates(subset=['DOCUMENTO', 'FECHA_INGRESO'], keep='last')
df_sin_duplicados_columnas
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 7            ME  HOSPITAL MEISSEN  HCW068
# 21           ME  HOSPITAL MEISSEN  HCW089
# 23           ME  HOSPITAL MEISSEN  HCW089
# 37           ME  HOSPITAL MEISSEN  HCW068
# 62           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1901         ME  HOSPITAL MEISSEN  HCW089
# 1905         ME  HOSPITAL MEISSEN  HCW089
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1913         ME  HOSPITAL MEISSEN  HCW089
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 23    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 37               CONSULTA  INICIAL DE URGENCIAS  16136504
# 62    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ...                                         ...       ...
# 1901  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 1905  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 23   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 37   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 62   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1901 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1905 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 23    ...          S06902  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 37    ...        FES03414  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 62    ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ...   ...             ...         ...                                 ...
# 1901  ...          C01705  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1905  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 7           MEDICINA GENERAL MIXTA        J989
# 21          MEDICINA GENERAL MIXTA        J050
# 23          MEDICINA GENERAL MIXTA        J219
# 37                MEDICINA GENERAL        J441
# 62                MEDICINA GENERAL        J459
# ...                            ...         ...
# 1901  MEDICINA GENERAL - PROGRAMAS        J00X
# 1905  MEDICINA GENERAL - PROGRAMAS        J00X
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 23    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 37    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 62    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ...                                                 ...        ...
# 1901  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1905  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 7                NaN                           NaN
# 21               NaN                           NaN
# 23               NaN                           NaN
# 37               NaN                           NaN
# 62               NaN                           NaN
# ...              ...                 ...       ...
# 1901             NaN                           NaN
# 1905             NaN                           NaN
# 1908             NaN                           NaN
# 1910             NaN                           NaN
# 1913             NaN                           NaN
#
# [223 rows x 43 columns]

# %% [markdown]
# Guarda el DataFrame df_sin_duplicados_columnas en un archivo Excel llamado Base.xlsx.
#
# index=False: Evita incluir la columna de índices del DataFrame en el archivo.

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO'],
#       dtype='object')

# %%
df_sin_duplicados_columnas
# Out:
#      CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 7            ME  HOSPITAL MEISSEN  HCW068
# 21           ME  HOSPITAL MEISSEN  HCW089
# 23           ME  HOSPITAL MEISSEN  HCW089
# 37           ME  HOSPITAL MEISSEN  HCW068
# 62           ME  HOSPITAL MEISSEN  HCW089
# ...         ...               ...     ...
# 1901         ME  HOSPITAL MEISSEN  HCW089
# 1905         ME  HOSPITAL MEISSEN  HCW089
# 1908         ME  HOSPITAL MEISSEN  HCW068
# 1910         ME  HOSPITAL MEISSEN  HCW068
# 1913         ME  HOSPITAL MEISSEN  HCW089
#
#                                   NOMBRE_TIPOHC   INGRESO  \
# 7                CONSULTA  INICIAL DE URGENCIAS  16136467
# 21    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 23    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 37               CONSULTA  INICIAL DE URGENCIAS  16136504
# 62    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ...                                         ...       ...
# 1901  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 1905  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 1908             CONSULTA  INICIAL DE URGENCIAS  16152759
# 1910             CONSULTA  INICIAL DE URGENCIAS  16152797
# 1913  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#                FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 7    2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 21   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 23   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 37   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 62   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ...                      ...           ...         ...            ...    ...
# 1901 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1905 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1908 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 1910 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 1913 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#       ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 7     ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 21    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 23    ...          S06902  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 37    ...        FES03414  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 62    ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ...   ...             ...         ...                                 ...
# 1901  ...          C01705  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1905  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 1908  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1910  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 1913  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                       ESPECIALIDAD DIAGNOSTICO  \
# 7           MEDICINA GENERAL MIXTA        J989
# 21          MEDICINA GENERAL MIXTA        J050
# 23          MEDICINA GENERAL MIXTA        J219
# 37                MEDICINA GENERAL        J441
# 62                MEDICINA GENERAL        J459
# ...                            ...         ...
# 1901  MEDICINA GENERAL - PROGRAMAS        J00X
# 1905  MEDICINA GENERAL - PROGRAMAS        J00X
# 1908              MEDICINA GENERAL        J399
# 1910              MEDICINA GENERAL        J441
# 1913  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                      NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 7     TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 21    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 23    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 37    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 62    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ...                                                 ...        ...
# 1901  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1905  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 1908  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 1910  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 1913  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#      REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 7                NaN                           NaN
# 21               NaN                           NaN
# 23               NaN                           NaN
# 37               NaN                           NaN
# 62               NaN                           NaN
# ...              ...                 ...       ...
# 1901             NaN                           NaN
# 1905             NaN                           NaN
# 1908             NaN                           NaN
# 1910             NaN                           NaN
# 1913             NaN                           NaN
#
# [223 rows x 43 columns]

# %% [markdown]
# #Cargue de la tabla con codigo  clasificación CIE 10

# %%
CIE10_EGRESO = pd.read_excel("https://github.com/Wilsonsr/ARREM/raw/main/Tabla-CIE-10-2018_08022021%20sin%20restricciones.xlsx", skiprows=8)
CIE10_EGRESO.head(5)
# Out:
#    Capitulo                                    Nombre Capitulo  \
# 0         1  Ciertas enfermedades infecciosas y parasitaria...
# 1         1  Ciertas enfermedades infecciosas y parasitaria...
# 2         1  Ciertas enfermedades infecciosas y parasitaria...
# 3         1  Ciertas enfermedades infecciosas y parasitaria...
# 4         1  Ciertas enfermedades infecciosas y parasitaria...
#
#   Código de la CIE-10 tres caracteres  \
# 0                                 A00
# 1                                 A00
# 2                                 A00
# 3                                 A01
# 4                                 A01
#
#   Descripcion  de codigos a tres caracteres  \
# 0                                    Colera
# 1                                    Colera
# 2                                    Colera
# 3           Fiebres Tifoidea Y Paratifoidea
# 4           Fiebres Tifoidea Y Paratifoidea
#
#   Código de la CIE-10 cuatro caracteres  \
# 0                                  A000
# 1                                  A001
# 2                                  A009
# 3                                  A010
# 4                                  A011
#
#          Descripcion  de códigos a cuatro caracteres
# 0  Colera debido a Vibrio cholerae 01, biotipo ch...
# 1  Colera debido a Vibrio cholerae 01, biotipo el...
# 2                            Colera, no especificado
# 3                                    Fiebre tifoidea
# 4                              Fiebre paratifoidea A

# %%
df_sin_duplicados_columnas=pd.merge(df_sin_duplicados_columnas,  CIE10_EGRESO[['Código de la CIE-10 cuatro caracteres',
       'Descripcion  de códigos a cuatro caracteres']], left_on='DIASGNOSTICO_EGRESO', right_on="Código de la CIE-10 cuatro caracteres", how='left').drop(columns=['Código de la CIE-10 cuatro caracteres', 'DX_EGRESO'])
df_sin_duplicados_columnas.rename(columns={'Descripcion  de códigos a cuatro caracteres': 'DX_EGRESO'}, inplace=True)

# %% [markdown]
# # primera base

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... PLAN_BENEFICIOS   ID_MEDICO                       NOMBRE_MEDICO  \
# 0    ...          C00511  1010067295           AVELLANEDA PINZON XIMENA
# 1    ...          C00601  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 2    ...          S06902  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 3    ...        FES03414  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 4    ...        FES03414    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ..   ...             ...         ...                                 ...
# 218  ...          C01705  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 219  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 220  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 221  ...        FES03414    93390482        BAUTISTA GARCIA JOSE LEONEL
# 222  ...        FES03414  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                      ESPECIALIDAD DIAGNOSTICO  \
# 0          MEDICINA GENERAL MIXTA        J989
# 1          MEDICINA GENERAL MIXTA        J050
# 2          MEDICINA GENERAL MIXTA        J219
# 3                MEDICINA GENERAL        J441
# 4                MEDICINA GENERAL        J459
# ..                            ...         ...
# 218  MEDICINA GENERAL - PROGRAMAS        J00X
# 219  MEDICINA GENERAL - PROGRAMAS        J00X
# 220              MEDICINA GENERAL        J399
# 221              MEDICINA GENERAL        J441
# 222  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                     NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0    TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 1    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 2    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 3    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 4    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ..                                                 ...        ...
# 218  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 219  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 220  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 221  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 222  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#     REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
# ..              ...                 ...       ...
# 218             NaN                           NaN
# 219             NaN                           NaN
# 220             NaN                           NaN
# 221             NaN                           NaN
# 222             NaN                           NaN
#
# [223 rows x 43 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO'],
#       dtype='object')

# %%
import pandas as pd

def reemplazar_ingreso_por_egreso(row):
    ingreso = str(row['DIAGNOSTICO']).strip().upper()
    egreso = str(row['DIASGNOSTICO_EGRESO']).strip().upper()

    # Si son iguales, no hacer nada
    if ingreso == egreso:
        return row

     # Si ingreso empieza por I o J y egreso por otra letra → no se hace nada
    if ingreso.startswith(('I', 'J')) and not egreso.startswith(('I', 'J')):
        return row


    # Si ingreso no empieza por I o J y egreso sí → se reemplaza ingreso
    if not ingreso.startswith(('I', 'J')) and egreso.startswith(('I', 'J')):
        row['DIAGNOSTICO'] = egreso
        row['NOMBRE_DIAGNOSTICO'] = row['DX_EGRESO']

    # En los demás casos, no se hace nada
    return row

# %%
# Aplicar la función fila por fila
df_sin_duplicados_columnas = df_sin_duplicados_columnas.apply(reemplazar_ingreso_por_egreso, axis=1)

# %%
excluir_codigos=["I770", "I952", "I970", "I971", "I972", "I978", "I979", "J341", "J342", "J380", "J386", "J690", "J691", "J698", "J700", "J701", "J702", "J703", "J704", "J708", "J709", "J940", "J941", "J942", "J950", "J951", "J952", "J953", "J954", "J955", "J958", "J959", "J986" ]

# %% [markdown]
# Este código elimina del DataFrame las filas donde el diagnóstico o el diagnóstico de egreso estén dentro de una lista de códigos a excluir.

# %% [markdown]
# ### Construir aquí la funcion

# %%
df_sin_duplicados_columnas = df_sin_duplicados_columnas[
    ~df_sin_duplicados_columnas["DIAGNOSTICO"].isin(excluir_codigos) &
    ~df_sin_duplicados_columnas["DIASGNOSTICO_EGRESO"].isin(excluir_codigos)
]

# %%
df_sin_duplicados_columnas.to_excel("Base_Meissen_primera_base.xlsx",index=False)

# %% [markdown]
# # parte 2

# %% [markdown]
# 1.	Unidad centinela: En la base se registra la unidad centinela correspondiente:
# - CAPS CHAPINERO
# - HOSPITAL UNIVERSITARIO CLINICA SAN RAFAEL
# - USS MEISSEN
# - USS KENNEDY

# %%
df_sin_duplicados_columnas["Unidad centinela"]="USS MEISSEN"

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ...   ID_MEDICO                       NOMBRE_MEDICO  \
# 0    ...  1010067295           AVELLANEDA PINZON XIMENA
# 1    ...  1000159382      ROMERO TRIANA ANDERSON CAMILO
# 2    ...  1007161544    RUIZ HERNANDEZ JEISON ALEJANDRO
# 3    ...  1091811125     GUERRERO ARAQUE LEANDRO JAVIER
# 4    ...    52384021  AREVALO VILLAMARIN INGRID TATIANA
# ..   ...         ...                                 ...
# 218  ...  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 219  ...  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
# 220  ...    93390482        BAUTISTA GARCIA JOSE LEONEL
# 221  ...    93390482        BAUTISTA GARCIA JOSE LEONEL
# 222  ...  1033798506    ZAPATA RODRIGUEZ JUAN SEBASTIAN
#
#                      ESPECIALIDAD  DIAGNOSTICO  \
# 0          MEDICINA GENERAL MIXTA         J989
# 1          MEDICINA GENERAL MIXTA         J050
# 2          MEDICINA GENERAL MIXTA         J219
# 3                MEDICINA GENERAL         J441
# 4                MEDICINA GENERAL         J459
# ..                            ...          ...
# 218  MEDICINA GENERAL - PROGRAMAS         J00X
# 219  MEDICINA GENERAL - PROGRAMAS         J00X
# 220              MEDICINA GENERAL         J399
# 221              MEDICINA GENERAL         J441
# 222  MEDICINA GENERAL - PROGRAMAS         J459
#
#                                     NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0    TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 1    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 2    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 3    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 4    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ..                                                 ...        ...
# 218  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 219  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 220  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 221  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 222  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#     REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO Unidad centinela
# 0               NaN                           NaN      USS MEISSEN
# 1               NaN                           NaN      USS MEISSEN
# 2               NaN                           NaN      USS MEISSEN
# 3               NaN                           NaN      USS MEISSEN
# 4               NaN                           NaN      USS MEISSEN
# ..              ...                 ...       ...              ...
# 218             NaN                           NaN      USS MEISSEN
# 219             NaN                           NaN      USS MEISSEN
# 220             NaN                           NaN      USS MEISSEN
# 221             NaN                           NaN      USS MEISSEN
# 222             NaN                           NaN      USS MEISSEN
#
# [223 rows x 44 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO',
#        'Unidad centinela'],
#       dtype='object')

# %%
df_sin_duplicados_columnas['LOCALIDAD'].unique()
# Out:
# array([ 6, 19,  5, 10, 18,  8, 15, 99,  1,  7,  3,  9,  4, 17, 20, 16, 11,
#        14])

# %% [markdown]
# ### 	Localidad unidad centinela: Se diligencia la localidad en número y letra:

# %%
# Crear el diccionario con el formato requerido
mapeo_localidades = {
    "CAPS CHAPINERO" : "12. BARRIOS UNIDOS",
    "HOSPITAL UNIVERSITARIO CLINICA SANA RAFAEL": "4. SAN CRISTOBAL",
    "USS MEISSEN" : "19. CIUDAD BOLIVAR",
    "USS KENNEDY" : "8. KENNEDY"
}

# %%
df_sin_duplicados_columnas["Localidad unidad centinela"] = df_sin_duplicados_columnas["Unidad centinela"].map(mapeo_localidades)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ...                       NOMBRE_MEDICO                  ESPECIALIDAD  \
# 0    ...           AVELLANEDA PINZON XIMENA         MEDICINA GENERAL MIXTA
# 1    ...      ROMERO TRIANA ANDERSON CAMILO         MEDICINA GENERAL MIXTA
# 2    ...    RUIZ HERNANDEZ JEISON ALEJANDRO         MEDICINA GENERAL MIXTA
# 3    ...     GUERRERO ARAQUE LEANDRO JAVIER               MEDICINA GENERAL
# 4    ...  AREVALO VILLAMARIN INGRID TATIANA               MEDICINA GENERAL
# ..   ...                                 ...                           ...
# 218  ...    ZAPATA RODRIGUEZ JUAN SEBASTIAN   MEDICINA GENERAL - PROGRAMAS
# 219  ...    ZAPATA RODRIGUEZ JUAN SEBASTIAN   MEDICINA GENERAL - PROGRAMAS
# 220  ...        BAUTISTA GARCIA JOSE LEONEL               MEDICINA GENERAL
# 221  ...        BAUTISTA GARCIA JOSE LEONEL               MEDICINA GENERAL
# 222  ...    ZAPATA RODRIGUEZ JUAN SEBASTIAN   MEDICINA GENERAL - PROGRAMAS
#
#     DIAGNOSTICO                                 NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0          J989  TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 1          J050  LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 2          J219  BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 3          J441  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 4          J459  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ..          ...                                                ...        ...
# 218        J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 219        J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 220        J399  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 221        J441  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 222        J459  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#     REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO Unidad centinela  \
# 0               NaN                           NaN      USS MEISSEN
# 1               NaN                           NaN      USS MEISSEN
# 2               NaN                           NaN      USS MEISSEN
# 3               NaN                           NaN      USS MEISSEN
# 4               NaN                           NaN      USS MEISSEN
# ..              ...                 ...       ...              ...
# 218             NaN                           NaN      USS MEISSEN
# 219             NaN                           NaN      USS MEISSEN
# 220             NaN                           NaN      USS MEISSEN
# 221             NaN                           NaN      USS MEISSEN
# 222             NaN                           NaN      USS MEISSEN
#
#     Localidad unidad centinela
# 0           19. CIUDAD BOLIVAR
# 1           19. CIUDAD BOLIVAR
# 2           19. CIUDAD BOLIVAR
# 3           19. CIUDAD BOLIVAR
# 4           19. CIUDAD BOLIVAR
# ..                         ...
# 218         19. CIUDAD BOLIVAR
# 219         19. CIUDAD BOLIVAR
# 220         19. CIUDAD BOLIVAR
# 221         19. CIUDAD BOLIVAR
# 222         19. CIUDAD BOLIVAR
#
# [223 rows x 45 columns]

# %% [markdown]
# ### MES: En número

# %%
# Convertir a tipo datetime
df_sin_duplicados_columnas['FECHA_INGRESO'] = pd.to_datetime(df_sin_duplicados_columnas['FECHA_INGRESO'])

# Extraer el número del mes
df_sin_duplicados_columnas['MES'] = df_sin_duplicados_columnas['FECHA_INGRESO'].dt.month

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ...                  ESPECIALIDAD DIAGNOSTICO  \
# 0    ...        MEDICINA GENERAL MIXTA        J989
# 1    ...        MEDICINA GENERAL MIXTA        J050
# 2    ...        MEDICINA GENERAL MIXTA        J219
# 3    ...              MEDICINA GENERAL        J441
# 4    ...              MEDICINA GENERAL        J459
# ..   ...                           ...         ...
# 218  ...  MEDICINA GENERAL - PROGRAMAS        J00X
# 219  ...  MEDICINA GENERAL - PROGRAMAS        J00X
# 220  ...              MEDICINA GENERAL        J399
# 221  ...              MEDICINA GENERAL        J441
# 222  ...  MEDICINA GENERAL - PROGRAMAS        J459
#
#                                     NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0    TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 1    LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 2    BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 3    ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 4    ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ..                                                 ...        ...
# 218  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 219  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 220  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 221  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 222  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#     REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO Unidad centinela  \
# 0               NaN                           NaN      USS MEISSEN
# 1               NaN                           NaN      USS MEISSEN
# 2               NaN                           NaN      USS MEISSEN
# 3               NaN                           NaN      USS MEISSEN
# 4               NaN                           NaN      USS MEISSEN
# ..              ...                 ...       ...              ...
# 218             NaN                           NaN      USS MEISSEN
# 219             NaN                           NaN      USS MEISSEN
# 220             NaN                           NaN      USS MEISSEN
# 221             NaN                           NaN      USS MEISSEN
# 222             NaN                           NaN      USS MEISSEN
#
#     Localidad unidad centinela MES
# 0           19. CIUDAD BOLIVAR   4
# 1           19. CIUDAD BOLIVAR   4
# 2           19. CIUDAD BOLIVAR   4
# 3           19. CIUDAD BOLIVAR   4
# 4           19. CIUDAD BOLIVAR   4
# ..                         ...  ..
# 218         19. CIUDAD BOLIVAR   4
# 219         19. CIUDAD BOLIVAR   4
# 220         19. CIUDAD BOLIVAR   4
# 221         19. CIUDAD BOLIVAR   4
# 222         19. CIUDAD BOLIVAR   4
#
# [223 rows x 46 columns]

# %% [markdown]
# ### Fecha consulta: Que quede registro de formato fecha dd/mm/aaaa

# %%
df_sin_duplicados_columnas['Fecha consulta'] = df_sin_duplicados_columnas['FECHA_INGRESO'].dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... DIAGNOSTICO                                 NOMBRE_DIAGNOSTICO  \
# 0    ...        J989  TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...
# 1    ...        J050  LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...
# 2    ...        J219  BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...
# 3    ...        J441  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...
# 4    ...        J459  ASMA, NO ESPECIFICADA                         ...
# ..   ...         ...                                                ...
# 218  ...        J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 219  ...        J00X  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...
# 220  ...        J399  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...
# 221  ...        J441  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...
# 222  ...        J459  ASMA, NO ESPECIFICADA                         ...
#
#        TIPO_DX  REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO  \
# 0    PRINCIPAL              NaN                           NaN
# 1    PRINCIPAL              NaN                           NaN
# 2    PRINCIPAL              NaN                           NaN
# 3    PRINCIPAL              NaN                           NaN
# 4    PRINCIPAL              NaN                           NaN
# ..         ...              ...                 ...       ...
# 218  PRINCIPAL              NaN                           NaN
# 219  PRINCIPAL              NaN                           NaN
# 220  PRINCIPAL              NaN                           NaN
# 221  PRINCIPAL              NaN                           NaN
# 222  PRINCIPAL              NaN                           NaN
#
#     Unidad centinela Localidad unidad centinela MES Fecha consulta
# 0        USS MEISSEN         19. CIUDAD BOLIVAR   4     13/04/2025
# 1        USS MEISSEN         19. CIUDAD BOLIVAR   4     13/04/2025
# 2        USS MEISSEN         19. CIUDAD BOLIVAR   4     13/04/2025
# 3        USS MEISSEN         19. CIUDAD BOLIVAR   4     13/04/2025
# 4        USS MEISSEN         19. CIUDAD BOLIVAR   4     13/04/2025
# ..               ...                        ...  ..            ...
# 218      USS MEISSEN         19. CIUDAD BOLIVAR   4     19/04/2025
# 219      USS MEISSEN         19. CIUDAD BOLIVAR   4     19/04/2025
# 220      USS MEISSEN         19. CIUDAD BOLIVAR   4     19/04/2025
# 221      USS MEISSEN         19. CIUDAD BOLIVAR   4     19/04/2025
# 222      USS MEISSEN         19. CIUDAD BOLIVAR   4     19/04/2025
#
# [223 rows x 47 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta'],
#       dtype='object')

# %% [markdown]
# #### Semana epidemiológica: De acuerdo a la semana epidemiológica correspondiente, pero si ya quedó ese código en la otra base, no se si en esta base sea necesario.

# %%
semanas_2025 = {
    1: ("2024-12-29", "2025-01-04"),
    2: ("2025-01-05", "2025-01-11"),
    3: ("2025-01-12", "2025-01-18"),
    4: ("2025-01-19", "2025-01-25"),
    5: ("2025-01-26", "2025-02-01"),
    6: ("2025-02-02", "2025-02-08"),
    7: ("2025-02-09", "2025-02-15"),
    8: ("2025-02-16", "2025-02-22"),
    9: ("2025-02-23", "2025-03-01"),
    10: ("2025-03-02", "2025-03-08"),
    11: ("2025-03-09", "2025-03-15"),
    12: ("2025-03-16", "2025-03-22"),
    13: ("2025-03-23", "2025-03-29"),
    14: ("2025-03-30", "2025-04-05"),
    15: ("2025-04-06", "2025-04-12"),
    16: ("2025-04-13", "2025-04-19"),
    17: ("2025-04-20", "2025-04-26"),
    18: ("2025-04-27", "2025-05-03"),
    19: ("2025-05-04", "2025-05-10"),
    20: ("2025-05-11", "2025-05-17"),
    21: ("2025-05-18", "2025-05-24"),
    22: ("2025-05-25", "2025-05-31"),
    23: ("2025-06-01", "2025-06-07"),
    24: ("2025-06-08", "2025-06-14"),
    25: ("2025-06-15", "2025-06-21"),
    26: ("2025-06-22", "2025-06-28"),
    27: ("2025-06-29", "2025-07-05"),
    28: ("2025-07-06", "2025-07-12"),
    29: ("2025-07-13", "2025-07-19"),
    30: ("2025-07-20", "2025-07-26"),
    31: ("2025-07-27", "2025-08-02"),
    32: ("2025-08-03", "2025-08-09"),
    33: ("2025-08-10", "2025-08-16"),
    34: ("2025-08-17", "2025-08-23"),
    35: ("2025-08-24", "2025-08-30"),
    36: ("2025-08-31", "2025-09-06"),
    37: ("2025-09-07", "2025-09-13"),
    38: ("2025-09-14", "2025-09-20"),
    39: ("2025-09-21", "2025-09-27"),
    40: ("2025-09-28", "2025-10-04"),
    41: ("2025-10-05", "2025-10-11"),
    42: ("2025-10-12", "2025-10-18"),
    43: ("2025-10-19", "2025-10-25"),
    44: ("2025-10-26", "2025-11-01"),
    45: ("2025-11-02", "2025-11-08"),
    46: ("2025-11-09", "2025-11-15"),
    47: ("2025-11-16", "2025-11-22"),
    48: ("2025-11-23", "2025-11-29"),
    49: ("2025-11-30", "2025-12-06"),
    50: ("2025-12-07", "2025-12-13"),
    51: ("2025-12-14", "2025-12-20"),
    52: ("2025-12-21", "2025-12-27"),
    53: ("2025-12-28", "2026-01-03"),
}

# %%
df_sin_duplicados_columnas["Fecha consulta"] = pd.to_datetime(
    df_sin_duplicados_columnas["Fecha consulta"],
    format="%d/%m/%Y"   # Ajusta según tu necesidad real
)

#

# %%
import pandas as pd

semanas_ordenadas = sorted(semanas_2025.keys())
bins = []

for i in semanas_ordenadas:
    # Inicio exacto tal como está en el diccionario
    inicio = pd.to_datetime(semanas_2025[i][0])
    # Para que 'fin' quede incluido, le sumamos 1 día y usamos el bin abierto
    # a la derecha => [inicio, fin+1)
    bins.append(inicio)

# El "cierre" del último bin será la fecha final de la última semana + 1 día
fin_ultima_sem = pd.to_datetime(semanas_2025[semanas_ordenadas[-1]][1])
bins.append(fin_ultima_sem + pd.Timedelta(days=1))

# Etiquetas
labels = [f"{i}" for i in semanas_ordenadas]

df_sin_duplicados_columnas["Semana epidemiologica"] = pd.cut(
    df_sin_duplicados_columnas["Fecha consulta"],
    bins=bins,
    labels=labels,
    right=False  # ¡Cerramos por la izquierda [inicio, fin)!
)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ...                                 NOMBRE_DIAGNOSTICO    TIPO_DX  \
# 0    ...  TRASTORNO RESPIRATORIO, NO ESPECIFICADO       ...  PRINCIPAL
# 1    ...  LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]          ...  PRINCIPAL
# 2    ...  BRONQUIOLITIS AGUDA, NO ESPECIFICADA          ...  PRINCIPAL
# 3    ...  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 4    ...  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
# ..   ...                                                ...        ...
# 218  ...  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 219  ...  RINOFARINGITIS AGUDA (RESFRIADO COMUN)        ...  PRINCIPAL
# 220  ...  ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORE...  PRINCIPAL
# 221  ...  ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EX...  PRINCIPAL
# 222  ...  ASMA, NO ESPECIFICADA                         ...  PRINCIPAL
#
#     REGISTRO_EGRESO  DIASGNOSTICO_EGRESO DX_EGRESO Unidad centinela  \
# 0               NaN                            NaN      USS MEISSEN
# 1               NaN                            NaN      USS MEISSEN
# 2               NaN                            NaN      USS MEISSEN
# 3               NaN                            NaN      USS MEISSEN
# 4               NaN                            NaN      USS MEISSEN
# ..              ...                  ...       ...              ...
# 218             NaN                            NaN      USS MEISSEN
# 219             NaN                            NaN      USS MEISSEN
# 220             NaN                            NaN      USS MEISSEN
# 221             NaN                            NaN      USS MEISSEN
# 222             NaN                            NaN      USS MEISSEN
#
#     Localidad unidad centinela MES Fecha consulta Semana epidemiologica
# 0           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 1           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 2           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 3           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 4           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# ..                         ...  ..            ...                   ...
# 218         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 219         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 220         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 221         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 222         19. CIUDAD BOLIVAR   4     2025-04-19                    16
#
# [223 rows x 48 columns]

# %% [markdown]
# #### Fecha de nacimiento

# %%
df_sin_duplicados_columnas['FECHA_NACIMIENTO']
# Out:
# 0     1975-10-11
# 1     2021-08-21
# 2     2022-11-02
# 3     1949-07-14
# 4     2017-09-21
#          ...
# 218   2011-12-16
# 219   2022-05-25
# 220   1948-11-12
# 221   1948-06-05
# 222   2020-04-09
# Name: FECHA_NACIMIENTO, Length: 223, dtype: datetime64[ns]

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['FECHA_NACIMIENTO'], format='%d/%m/%Y', errors='coerce').dt.strftime('%d/%m/%Y')

# %%
  df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ...    TIPO_DX REGISTRO_EGRESO DIASGNOSTICO_EGRESO  DX_EGRESO  \
# 0    ...  PRINCIPAL             NaN                            NaN
# 1    ...  PRINCIPAL             NaN                            NaN
# 2    ...  PRINCIPAL             NaN                            NaN
# 3    ...  PRINCIPAL             NaN                            NaN
# 4    ...  PRINCIPAL             NaN                            NaN
# ..   ...        ...             ...                 ...        ...
# 218  ...  PRINCIPAL             NaN                            NaN
# 219  ...  PRINCIPAL             NaN                            NaN
# 220  ...  PRINCIPAL             NaN                            NaN
# 221  ...  PRINCIPAL             NaN                            NaN
# 222  ...  PRINCIPAL             NaN                            NaN
#
#     Unidad centinela Localidad unidad centinela MES Fecha consulta  \
# 0        USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-13
# 1        USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-13
# 2        USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-13
# 3        USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-13
# 4        USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-13
# ..               ...                        ...  ..            ...
# 218      USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-19
# 219      USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-19
# 220      USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-19
# 221      USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-19
# 222      USS MEISSEN         19. CIUDAD BOLIVAR   4     2025-04-19
#
#     Semana epidemiologica Fecha de nacimiento
# 0                      16          11/10/1975
# 1                      16          21/08/2021
# 2                      16          02/11/2022
# 3                      16          14/07/1949
# 4                      16          21/09/2017
# ..                    ...                 ...
# 218                    16          16/12/2011
# 219                    16          25/05/2022
# 220                    16          12/11/1948
# 221                    16          05/06/1948
# 222                    16          09/04/2020
#
# [223 rows x 49 columns]

# %% [markdown]
# #### Tipo de documento: En caso de que el espacio se encuentre en blanco o con raya al piso, generar en ese espacio 999

# %%
df_sin_duplicados_columnas["TIPO_ID"].unique()
# Out:
# array(['CC', 'RC', 'PT', 'TI', 'DE', 'CE'], dtype=object)

# %%
# Reemplazar espacios en blanco o rayas al piso por "999"
df_sin_duplicados_columnas['Tipo de documento'] = df_sin_duplicados_columnas['TIPO_ID'].replace(["", "_"], "999")

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... REGISTRO_EGRESO DIASGNOSTICO_EGRESO DX_EGRESO  Unidad centinela  \
# 0    ...             NaN                           NaN       USS MEISSEN
# 1    ...             NaN                           NaN       USS MEISSEN
# 2    ...             NaN                           NaN       USS MEISSEN
# 3    ...             NaN                           NaN       USS MEISSEN
# 4    ...             NaN                           NaN       USS MEISSEN
# ..   ...             ...                 ...       ...               ...
# 218  ...             NaN                           NaN       USS MEISSEN
# 219  ...             NaN                           NaN       USS MEISSEN
# 220  ...             NaN                           NaN       USS MEISSEN
# 221  ...             NaN                           NaN       USS MEISSEN
# 222  ...             NaN                           NaN       USS MEISSEN
#
#     Localidad unidad centinela MES Fecha consulta Semana epidemiologica  \
# 0           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 1           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 2           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 3           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# 4           19. CIUDAD BOLIVAR   4     2025-04-13                    16
# ..                         ...  ..            ...                   ...
# 218         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 219         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 220         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 221         19. CIUDAD BOLIVAR   4     2025-04-19                    16
# 222         19. CIUDAD BOLIVAR   4     2025-04-19                    16
#
#     Fecha de nacimiento Tipo de documento
# 0            11/10/1975                CC
# 1            21/08/2021                RC
# 2            02/11/2022                RC
# 3            14/07/1949                CC
# 4            21/09/2017                PT
# ..                  ...               ...
# 218          16/12/2011                TI
# 219          25/05/2022                RC
# 220          12/11/1948                CC
# 221          05/06/1948                CC
# 222          09/04/2020                RC
#
# [223 rows x 50 columns]

# %%
df_sin_duplicados_columnas["Tipo de documento"].unique()
# Out:
# array(['CC', 'RC', 'PT', 'TI', 'DE', 'CE'], dtype=object)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento'],
#       dtype='object')

# %% [markdown]
# ####	Edad en meses: Calcular en caso de que la edad en años sea cero 0.
# #### Edad años: Calcular de acuerdo a las variables fecha de nacimiento y fecha consulta.

# %%
import pandas as pd
from dateutil.relativedelta import relativedelta

# Convertir las columnas a tipo datetime
df_sin_duplicados_columnas["Fecha de nacimiento"] = pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento'], format='%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta'], format='%d/%m/%Y')

# Función para calcular años y meses
def calcular_edad(row):
    nacimiento = row['Fecha de nacimiento']
    consulta = row['Fecha consulta']

    # Calcular la diferencia con relativedelta (maneja días/meses/años)
    delta = relativedelta(consulta, nacimiento)

    # Si hay al menos 1 año completo
    if delta.years >= 1:
        return pd.Series([delta.years, np.nan])
    else:
        # Calcular meses totales (años * 12 + meses)
        meses_totales = delta.years * 12 + delta.months
        return pd.Series([0, meses_totales])

# Aplicar la función y crear las columnas
df_sin_duplicados_columnas[['Edad años', 'Edad en meses']] = df_sin_duplicados_columnas.apply(calcular_edad, axis=1)

# %%
df_sin_duplicados_columnas["Fecha de nacimiento"]=pd.to_datetime(df_sin_duplicados_columnas['Fecha de nacimiento']).dt.strftime('%d/%m/%Y')
df_sin_duplicados_columnas['Fecha consulta'] = pd.to_datetime(df_sin_duplicados_columnas['Fecha consulta']).dt.strftime('%d/%m/%Y')

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... DX_EGRESO Unidad centinela Localidad unidad centinela  MES  \
# 0    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 1    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 2    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 3    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 4    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# ..   ...       ...              ...                        ...  ...
# 218  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 219  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 220  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 221  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 222  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
#
#     Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 0       13/04/2025                    16          11/10/1975
# 1       13/04/2025                    16          21/08/2021
# 2       13/04/2025                    16          02/11/2022
# 3       13/04/2025                    16          14/07/1949
# 4       13/04/2025                    16          21/09/2017
# ..             ...                   ...                 ...
# 218     19/04/2025                    16          16/12/2011
# 219     19/04/2025                    16          25/05/2022
# 220     19/04/2025                    16          12/11/1948
# 221     19/04/2025                    16          05/06/1948
# 222     19/04/2025                    16          09/04/2020
#
#     Tipo de documento Edad años Edad en meses
# 0                  CC      49.0           NaN
# 1                  RC       3.0           NaN
# 2                  RC       2.0           NaN
# 3                  CC      75.0           NaN
# 4                  PT       7.0           NaN
# ..                ...       ...           ...
# 218                TI      13.0           NaN
# 219                RC       2.0           NaN
# 220                CC      76.0           NaN
# 221                CC      76.0           NaN
# 222                RC       5.0           NaN
#
# [223 rows x 52 columns]

# %%
df_sin_duplicados_columnas["Edad en meses"].unique()
# Out:
# array([nan,  6.,  8., 10.,  9.,  2.,  7., 11.])

# %%
df_sin_duplicados_columnas[df_sin_duplicados_columnas["Edad en meses"]==0]
# Out:
# Empty DataFrame
# Columns: [CODIGO_USS, NOMBRE_USS, TIPO_HC, NOMBRE_TIPOHC, INGRESO, FECHA_INGRESO, TIPO_INGRESO, INGRESO_POR, FECHA_ATENCION, AREA, NOMBRE_AREA, TIPO_AREA_SERVICIO, AREA_URGENCIAS, FOLIO, TIPO_ID, DOCUMENTO, PRIMER_NOMBRE, SEGUNDO_NOMBRE, PRIMER_APELLIDO, SEGUNDO_APELLIDO, FECHA_NACIMIENTO, EDAD, GENERO, CODIGO_BARRIO, NOMBRE_BARRIO, DIRECCION, TELEFONO, LOCALIDAD, NOMBRE_LOCALIDAD, TIPO_PACIENTE, TIPO_AFILIADO, TERCERO_ENTIDAD, NOMBRE_TERCERO, PLAN_BENEFICIOS, ID_MEDICO, NOMBRE_MEDICO, ESPECIALIDAD, DIAGNOSTICO, NOMBRE_DIAGNOSTICO, TIPO_DX, REGISTRO_EGRESO, DIASGNOSTICO_EGRESO, DX_EGRESO, Unidad centinela, Localidad unidad centinela, MES, Fecha consulta, Semana epidemiologica, Fecha de nacimiento, Tipo de documento, Edad años, Edad en meses]
# Index: []
#
# [0 rows x 52 columns]

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... DX_EGRESO Unidad centinela Localidad unidad centinela  MES  \
# 0    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 1    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 2    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 3    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 4    ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# ..   ...       ...              ...                        ...  ...
# 218  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 219  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 220  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 221  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
# 222  ...       NaN      USS MEISSEN         19. CIUDAD BOLIVAR    4
#
#     Fecha consulta Semana epidemiologica Fecha de nacimiento  \
# 0       13/04/2025                    16          11/10/1975
# 1       13/04/2025                    16          21/08/2021
# 2       13/04/2025                    16          02/11/2022
# 3       13/04/2025                    16          14/07/1949
# 4       13/04/2025                    16          21/09/2017
# ..             ...                   ...                 ...
# 218     19/04/2025                    16          16/12/2011
# 219     19/04/2025                    16          25/05/2022
# 220     19/04/2025                    16          12/11/1948
# 221     19/04/2025                    16          05/06/1948
# 222     19/04/2025                    16          09/04/2020
#
#     Tipo de documento Edad años Edad en meses
# 0                  CC      49.0           NaN
# 1                  RC       3.0           NaN
# 2                  RC       2.0           NaN
# 3                  CC      75.0           NaN
# 4                  PT       7.0           NaN
# ..                ...       ...           ...
# 218                TI      13.0           NaN
# 219                RC       2.0           NaN
# 220                CC      76.0           NaN
# 221                CC      76.0           NaN
# 222                RC       5.0           NaN
#
# [223 rows x 52 columns]

# %% [markdown]
# ### GRUPO DE EDAD: De acuerdo al intervalo
# - 0 a 5 años: 1. INFANCIA
# - 6 a 11 años: 2. INFANCIA
# - 12 a 17 años: 3. ADOLESCENCIA
# - 18 a 28 años: 4. JUVENTUD
# - 29 a 59 años: 5. ADULTEZ
# - <60 años: 6. VEJEZ

# %%
# Función para asignar el grupo de edad
def clasificar_grupo_edad(edad):
    if 0 <= edad <= 5:
        return "1. INFANCIA"
    elif 6 <= edad <= 11:
        return "2. INFANCIA"
    elif 12 <= edad <= 17:
        return "3. ADOLESCENCIA"
    elif 18 <= edad <= 28:
        return "4. JUVENTUD"
    elif 29 <= edad <= 59:
        return "5. ADULTEZ"
    else:
        return "6. VEJEZ"

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses'],
#       dtype='object')

# %%
# Aplicar la clasificación de grupo de edad
df_sin_duplicados_columnas['GRUPO DE EDAD'] = df_sin_duplicados_columnas["Edad años"].apply(clasificar_grupo_edad)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... Unidad centinela Localidad unidad centinela MES  Fecha consulta  \
# 0    ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      13/04/2025
# 1    ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      13/04/2025
# 2    ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      13/04/2025
# 3    ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      13/04/2025
# 4    ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      13/04/2025
# ..   ...              ...                        ...  ..             ...
# 218  ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      19/04/2025
# 219  ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      19/04/2025
# 220  ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      19/04/2025
# 221  ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      19/04/2025
# 222  ...      USS MEISSEN         19. CIUDAD BOLIVAR   4      19/04/2025
#
#     Semana epidemiologica Fecha de nacimiento Tipo de documento Edad años  \
# 0                      16          11/10/1975                CC      49.0
# 1                      16          21/08/2021                RC       3.0
# 2                      16          02/11/2022                RC       2.0
# 3                      16          14/07/1949                CC      75.0
# 4                      16          21/09/2017                PT       7.0
# ..                    ...                 ...               ...       ...
# 218                    16          16/12/2011                TI      13.0
# 219                    16          25/05/2022                RC       2.0
# 220                    16          12/11/1948                CC      76.0
# 221                    16          05/06/1948                CC      76.0
# 222                    16          09/04/2020                RC       5.0
#
#     Edad en meses    GRUPO DE EDAD
# 0             NaN       5. ADULTEZ
# 1             NaN      1. INFANCIA
# 2             NaN      1. INFANCIA
# 3             NaN         6. VEJEZ
# 4             NaN      2. INFANCIA
# ..            ...              ...
# 218           NaN  3. ADOLESCENCIA
# 219           NaN      1. INFANCIA
# 220           NaN         6. VEJEZ
# 221           NaN         6. VEJEZ
# 222           NaN      1. INFANCIA
#
# [223 rows x 53 columns]

# %%
df_sin_duplicados_columnas['GENERO'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# ### Sexo: Generar Mujer o Hombre, ya que en las bases aparece FEMENINO/MASCULINO o F/M.

# %%
# Suponiendo que df_sin_duplicados_columnas es el DataFrame original
df_sin_duplicados_columnas["Sexo"] = df_sin_duplicados_columnas['GENERO'].replace({
    "FEMENINO": "Mujer",
    "MASCULINO": "Hombre",
    "F": "Mujer",
    "M": "Hombre"
})

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... Localidad unidad centinela MES Fecha consulta  Semana epidemiologica  \
# 0    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 1    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 2    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 3    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 4    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# ..   ...                        ...  ..            ...                    ...
# 218  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 219  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 220  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 221  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 222  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
#
#     Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 0            11/10/1975                CC      49.0           NaN
# 1            21/08/2021                RC       3.0           NaN
# 2            02/11/2022                RC       2.0           NaN
# 3            14/07/1949                CC      75.0           NaN
# 4            21/09/2017                PT       7.0           NaN
# ..                  ...               ...       ...           ...
# 218          16/12/2011                TI      13.0           NaN
# 219          25/05/2022                RC       2.0           NaN
# 220          12/11/1948                CC      76.0           NaN
# 221          05/06/1948                CC      76.0           NaN
# 222          09/04/2020                RC       5.0           NaN
#
#        GRUPO DE EDAD    Sexo
# 0         5. ADULTEZ   Mujer
# 1        1. INFANCIA  Hombre
# 2        1. INFANCIA  Hombre
# 3           6. VEJEZ  Hombre
# 4        2. INFANCIA  Hombre
# ..               ...     ...
# 218  3. ADOLESCENCIA   Mujer
# 219      1. INFANCIA   Mujer
# 220         6. VEJEZ   Mujer
# 221         6. VEJEZ  Hombre
# 222      1. INFANCIA  Hombre
#
# [223 rows x 54 columns]

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'DIRECCION', 'TELEFONO',
#        'LOCALIDAD', 'NOMBRE_LOCALIDAD', 'TIPO_PACIENTE', 'TIPO_AFILIADO',
#        'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS', 'ID_MEDICO',
#        'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO', 'NOMBRE_DIAGNOSTICO',
#        'TIPO_DX', 'REGISTRO_EGRESO', 'DIASGNOSTICO_EGRESO', 'DX_EGRESO',
#        'Unidad centinela', 'Localidad unidad centinela', 'MES',
#        'Fecha consulta', 'Semana epidemiologica', 'Fecha de nacimiento',
#        'Tipo de documento', 'Edad años', 'Edad en meses', 'GRUPO DE EDAD',
#        'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas.head()
# Out:
#   CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0         ME  HOSPITAL MEISSEN  HCW068
# 1         ME  HOSPITAL MEISSEN  HCW089
# 2         ME  HOSPITAL MEISSEN  HCW089
# 3         ME  HOSPITAL MEISSEN  HCW068
# 4         ME  HOSPITAL MEISSEN  HCW089
#
#                                NOMBRE_TIPOHC   INGRESO  \
# 0             CONSULTA  INICIAL DE URGENCIAS  16136467
# 1  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3             CONSULTA  INICIAL DE URGENCIAS  16136504
# 4  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
#
#             FECHA_INGRESO TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  ...  \
# 0 2025-04-13 01:10:36.813  AMBULATORIO   URGENCIAS     2025-04-13  B01ME  ...
# 1 2025-04-13 01:55:18.460  AMBULATORIO   URGENCIAS     2025-04-13  B01ME  ...
# 2 2025-04-13 03:08:20.957  AMBULATORIO   URGENCIAS     2025-04-13  B01ME  ...
# 3 2025-04-13 06:26:59.807  AMBULATORIO   URGENCIAS     2025-04-13  B01ME  ...
# 4 2025-04-13 08:01:10.533  AMBULATORIO   URGENCIAS     2025-04-13  B01ME  ...
#
#   Localidad unidad centinela MES Fecha consulta  Semana epidemiologica  \
# 0         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 1         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 2         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 3         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 4         19. CIUDAD BOLIVAR   4     13/04/2025                     16
#
#   Fecha de nacimiento Tipo de documento Edad años Edad en meses GRUPO DE EDAD  \
# 0          11/10/1975                CC      49.0           NaN    5. ADULTEZ
# 1          21/08/2021                RC       3.0           NaN   1. INFANCIA
# 2          02/11/2022                RC       2.0           NaN   1. INFANCIA
# 3          14/07/1949                CC      75.0           NaN      6. VEJEZ
# 4          21/09/2017                PT       7.0           NaN   2. INFANCIA
#
#      Sexo
# 0   Mujer
# 1  Hombre
# 2  Hombre
# 3  Hombre
# 4  Hombre
#
# [5 rows x 54 columns]

# %%
df_sin_duplicados_columnas["TIPO_PACIENTE"].unique()
# Out:
# array(['CONTRIBUTIVO', 'SUBSIDIADO', 'VINCULADO', 'PARTICULAR'],
#       dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={"TIPO_PACIENTE": "Regimen SGSS"}, inplace=True)

# %%
df_sin_duplicados_columnas["DIRECCION"]
# Out:
# 0                                # SABE
# 1             TRANSVERSAL 13 45 C 21 SUR
# 2            DIAGONAL 65 BIS A N 18 Q 63
# 3                      CL 81F SUR 18D 16
# 4                \tCL 58 SUR # 19 B - 22
#                      ...
# 218               CALLE 1 # 5 A -21 SUR
# 219    CARRERA 47 A N 72 - 48 SUR Urbana
# 220                   KR 19G 60 - 21 SUR
# 221                   CALLE 6B # 19 - 41
# 222                      KM 20 VIA QUIB4
# Name: DIRECCION, Length: 223, dtype: object

# %% [markdown]
# **Cuando se presenten datos vacios adicionar 999**

# %%
df_sin_duplicados_columnas.rename(columns={'DIRECCION': "Dirección"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... Localidad unidad centinela MES Fecha consulta  Semana epidemiologica  \
# 0    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 1    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 2    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 3    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 4    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# ..   ...                        ...  ..            ...                    ...
# 218  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 219  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 220  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 221  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 222  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
#
#     Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 0            11/10/1975                CC      49.0           NaN
# 1            21/08/2021                RC       3.0           NaN
# 2            02/11/2022                RC       2.0           NaN
# 3            14/07/1949                CC      75.0           NaN
# 4            21/09/2017                PT       7.0           NaN
# ..                  ...               ...       ...           ...
# 218          16/12/2011                TI      13.0           NaN
# 219          25/05/2022                RC       2.0           NaN
# 220          12/11/1948                CC      76.0           NaN
# 221          05/06/1948                CC      76.0           NaN
# 222          09/04/2020                RC       5.0           NaN
#
#        GRUPO DE EDAD    Sexo
# 0         5. ADULTEZ   Mujer
# 1        1. INFANCIA  Hombre
# 2        1. INFANCIA  Hombre
# 3           6. VEJEZ  Hombre
# 4        2. INFANCIA  Hombre
# ..               ...     ...
# 218  3. ADOLESCENCIA   Mujer
# 219      1. INFANCIA   Mujer
# 220         6. VEJEZ   Mujer
# 221         6. VEJEZ  Hombre
# 222      1. INFANCIA  Hombre
#
# [223 rows x 54 columns]

# %%
df_sin_duplicados_columnas["NOMBRE_LOCALIDAD"].unique()
# Out:
# array(['TUNJUELITO', 'CIUDAD BOLIVAR', 'USME', 'ENGATIVA',
#        'RAFAEL URIBE URIBE', 'KENNEDY', 'ANTONIO NARIÑO',
#        'LOCALIDADES OTRAS CIUDADES', 'USAQUEN', 'BOSA', 'SANTA FE',
#        'FONTIBON', 'SAN CRISTOBAL', 'LA CANDELARIA', 'SUMAPAZ',
#        'PUENTE ARANDA', 'SUBA', 'LOS MARTIRES'], dtype=object)

# %%
df_sin_duplicados_columnas["NOMBRE_LOCALIDAD"].replace({'LOCALIDADES OTRAS CIUDADES': "999", 'LOCALIDADES OTRAS CIUDADES ': "999" }, inplace=True)
# Out:
# <ipython-input-85-7f02a7f790ba>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["NOMBRE_LOCALIDAD"].replace({'LOCALIDADES OTRAS CIUDADES': "999", 'LOCALIDADES OTRAS CIUDADES ': "999" }, inplace=True)

# %%
df_sin_duplicados_columnas["LOCALIDAD"].unique()
# Out:
# array([ 6, 19,  5, 10, 18,  8, 15, 99,  1,  7,  3,  9,  4, 17, 20, 16, 11,
#        14])

# %%
df_sin_duplicados_columnas.rename(columns={'NOMBRE_LOCALIDAD': "Localidad de residencia base"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'DOCUMENTO', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'Dirección', 'TELEFONO',
#        'LOCALIDAD', 'Localidad de residencia base', 'Regimen SGSS',
#        'TIPO_AFILIADO', 'TERCERO_ENTIDAD', 'NOMBRE_TERCERO', 'PLAN_BENEFICIOS',
#        'ID_MEDICO', 'NOMBRE_MEDICO', 'ESPECIALIDAD', 'DIAGNOSTICO',
#        'NOMBRE_DIAGNOSTICO', 'TIPO_DX', 'REGISTRO_EGRESO',
#        'DIASGNOSTICO_EGRESO', 'DX_EGRESO', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].replace('LOCALIDADES OTRAS CIUDADES', "999", inplace=True)
# Out:
# <ipython-input-89-8947d2676a5d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Localidad de residencia base"].replace('LOCALIDADES OTRAS CIUDADES', "999", inplace=True)

# %%
df_sin_duplicados_columnas["Localidad de residencia base"].unique()
# Out:
# array(['TUNJUELITO', 'CIUDAD BOLIVAR', 'USME', 'ENGATIVA',
#        'RAFAEL URIBE URIBE', 'KENNEDY', 'ANTONIO NARIÑO', '999',
#        'USAQUEN', 'BOSA', 'SANTA FE', 'FONTIBON', 'SAN CRISTOBAL',
#        'LA CANDELARIA', 'SUMAPAZ', 'PUENTE ARANDA', 'SUBA',
#        'LOS MARTIRES'], dtype=object)

# %%
df_sin_duplicados_columnas['DIAGNOSTICO']
# Out:
# 0      J989
# 1      J050
# 2      J219
# 3      J441
# 4      J459
#        ...
# 218    J00X
# 219    J00X
# 220    J399
# 221    J441
# 222    J459
# Name: DIAGNOSTICO, Length: 223, dtype: object

# %%
df_sin_duplicados_columnas.rename(columns={'DIAGNOSTICO': "Diagnóstico de ingreso"}, inplace=True)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW068
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW068
# 4           ME  HOSPITAL MEISSEN  HCW089
# ..         ...               ...     ...
# 218         ME  HOSPITAL MEISSEN  HCW089
# 219         ME  HOSPITAL MEISSEN  HCW089
# 220         ME  HOSPITAL MEISSEN  HCW068
# 221         ME  HOSPITAL MEISSEN  HCW068
# 222         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0               CONSULTA  INICIAL DE URGENCIAS  16136467
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136476
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136483
# 3               CONSULTA  INICIAL DE URGENCIAS  16136504
# 4    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16136545
# ..                                         ...       ...
# 218  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152595
# 219  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152727
# 220             CONSULTA  INICIAL DE URGENCIAS  16152759
# 221             CONSULTA  INICIAL DE URGENCIAS  16152797
# 222  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16152851
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-04-13 01:10:36.813   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 1   2025-04-13 01:55:18.460   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 2   2025-04-13 03:08:20.957   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 3   2025-04-13 06:26:59.807   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# 4   2025-04-13 08:01:10.533   AMBULATORIO   URGENCIAS     2025-04-13  B01ME
# ..                      ...           ...         ...            ...    ...
# 218 2025-04-19 21:10:16.987   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 219 2025-04-19 22:19:19.900   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 220 2025-04-19 22:41:59.183   AMBULATORIO   URGENCIAS     2025-04-19  B01ME
# 221 2025-04-19 22:51:34.403   AMBULATORIO   URGENCIAS     2025-04-20  B01ME
# 222 2025-04-19 23:28:06.063  HOSPITALARIO   URGENCIAS     2025-04-20  B01ME
#
#      ... Localidad unidad centinela MES Fecha consulta  Semana epidemiologica  \
# 0    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 1    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 2    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 3    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# 4    ...         19. CIUDAD BOLIVAR   4     13/04/2025                     16
# ..   ...                        ...  ..            ...                    ...
# 218  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 219  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 220  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 221  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
# 222  ...         19. CIUDAD BOLIVAR   4     19/04/2025                     16
#
#     Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 0            11/10/1975                CC      49.0           NaN
# 1            21/08/2021                RC       3.0           NaN
# 2            02/11/2022                RC       2.0           NaN
# 3            14/07/1949                CC      75.0           NaN
# 4            21/09/2017                PT       7.0           NaN
# ..                  ...               ...       ...           ...
# 218          16/12/2011                TI      13.0           NaN
# 219          25/05/2022                RC       2.0           NaN
# 220          12/11/1948                CC      76.0           NaN
# 221          05/06/1948                CC      76.0           NaN
# 222          09/04/2020                RC       5.0           NaN
#
#        GRUPO DE EDAD    Sexo
# 0         5. ADULTEZ   Mujer
# 1        1. INFANCIA  Hombre
# 2        1. INFANCIA  Hombre
# 3           6. VEJEZ  Hombre
# 4        2. INFANCIA  Hombre
# ..               ...     ...
# 218  3. ADOLESCENCIA   Mujer
# 219      1. INFANCIA   Mujer
# 220         6. VEJEZ   Mujer
# 221         6. VEJEZ  Hombre
# 222      1. INFANCIA  Hombre
#
# [223 rows x 54 columns]

# %%
df_sin_duplicados_columnas["NOMBRE_DIAGNOSTICO"].unique()
# Out:
# array(['TRASTORNO RESPIRATORIO, NO ESPECIFICADO                                                             ',
#        'LARINGITIS OBSTRUCTIVA, AGUDA [CRUP]                                                                ',
#        'BRONQUIOLITIS AGUDA, NO ESPECIFICADA                                                                ',
#        'ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA CON EXACERBACION AGUDA, NO ESPECIFICADA                     ',
#        'ASMA, NO ESPECIFICADA                                                                               ',
#        'RINOFARINGITIS AGUDA (RESFRIADO COMUN)                                                              ',
#        'HIPERTENSION ESENCIAL (PRIMARIA)                                                                    ',
#        'BRONQUITIS AGUDA, NO ESPECIFICADA                                                                   ',
#        'AMIGDALITIS AGUDA, NO ESPECIFICADA                                                                  ',
#        'Neumonia bacteriana, no especificada',
#        'ENFERMEDAD PULMONAR OBSTRUCTIVA CRONICA, NO ESPECIFICADA                                            ',
#        'SINDROME DE DIFICULTAD RESPIRATORIA DEL ADULTO                                                      ',
#        'ESTADO ASMATICO                                                                                     ',
#        'Bronquitis aguda, no especificada',
#        'ASMA NO ALERGICA                                                                                    ',
#        'ENFERMEDADES DE LA TRAQUEA Y DE LOS BRONQUIOS, NO CLASIFICADAS EN OTRA PARTE                        ',
#        'INFECCION AGUDA NO ESPECIFICADA DE LAS VIAS RESPIRATORIAS INFERIORES                                ',
#        'BRONQUIOLITIS AGUDA DEBIDA A OTROS MICROORGANISMOS ESPECIFICADOS                                    ',
#        'INFARTO AGUDO DEL MIOCARDIO, SIN OTRA ESPECIFICACION                                                ',
#        'Amigdalitis aguda, no especificada',
#        'VENAS VARICOSAS DE LOS MIEMBROS INFERIORES CON ULCERA E INFLAMACION                                 ',
#        'Asma, no especificado',
#        'ASMA PREDOMINANTEMENTE ALERGICA                                                                     ',
#        'Enfermedades de la traquea y de los bronquios, no clasificadas en otra parte',
#        'OTRAS ENFERMEDADES PULMONARES OBSTRUCTIVAS CRONICAS ESPECIFICADAS                                   ',
#        'INSUFICIENCIA CARDIACA CONGESTIVA                                                                   ',
#        'OTROS TRASTORNOS DEL PULMON                                                                         ',
#        'ENFERMEDAD DE LAS VIAS RESPIRATORIAS SUPERIORES, NO ESPECIFICADA                                    ',
#        'INSUFICIENCIA CARDIACA, NO ESPECIFICADA                                                             ',
#        'BRONQUITIS CRONICA SIMPLE                                                                           ',
#        'INFECCION AGUDA DE LAS VIAS RESPIRATORIAS SUPERIORES, NO ESPECIFICADA                               ',
#        'BRONQUITIS, NO ESPECIFICADA COMO AGUDA O CRONICA                                                    ',
#        'VENAS VARICOSAS DE LOS MIEMBROS INFERIORES SIN ULCERA NI INFLAMACION                                '],
#       dtype=object)

# %%
df_sin_duplicados_columnas.rename(columns={'NOMBRE_DIAGNOSTICO': "Nombre del diagnóstico de ingreso"}, inplace=True)

# %%
def asignar_tipo_dx(diagnostico):
    """
    Si el diagnóstco empieza con 'I', devolvemos 'CARDIO'.
    Si empieza con 'J', devolvemos 'RESPIRATORIO'.
    En otros casos, devolvemos vacío o lo que prefieras.
    """
    if str(diagnostico).startswith('I'):
        return 'CARDIO'
    elif str(diagnostico).startswith('J'):
        return 'RESPIRATORIO'
    else:
        return ''  # puedes poner OTRO si deseas

# %%
# Creamos la nueva columna TIPO_DX
df_sin_duplicados_columnas['TIPO_DX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(asignar_tipo_dx)

# %%
df_sin_duplicados_columnas
# Out:
#     CODIGO_USS        NOMBRE_USS TIPO_HC  \
# 0           ME  HOSPITAL MEISSEN  HCW089
# 1           ME  HOSPITAL MEISSEN  HCW089
# 2           ME  HOSPITAL MEISSEN  HCW089
# 3           ME  HOSPITAL MEISSEN  HCW089
# 4           ME  HOSPITAL MEISSEN  HCW068
# ..         ...               ...     ...
# 250         ME  HOSPITAL MEISSEN  HCW089
# 251         ME  HOSPITAL MEISSEN  HCW068
# 252         ME  HOSPITAL MEISSEN  HCW068
# 253         ME  HOSPITAL MEISSEN  HCW089
# 254         ME  HOSPITAL MEISSEN  HCW089
#
#                                  NOMBRE_TIPOHC   INGRESO  \
# 0    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16250948
# 1    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16251013
# 2    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16251419
# 3    CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16251503
# 4               CONSULTA  INICIAL DE URGENCIAS  16251562
# ..                                         ...       ...
# 250  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16288133
# 251             CONSULTA  INICIAL DE URGENCIAS  16288190
# 252             CONSULTA  INICIAL DE URGENCIAS  16288192
# 253  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16288207
# 254  CONSULTA INICIAL DE URGENCIAS  PEDIATRICA  16288226
#
#               FECHA_INGRESO  TIPO_INGRESO INGRESO_POR FECHA_ATENCION   AREA  \
# 0   2025-05-11 01:42:11.917   AMBULATORIO   URGENCIAS     2025-05-11  B05ME
# 1   2025-05-11 02:30:29.813   AMBULATORIO   URGENCIAS     2025-05-11  B01ME
# 2   2025-05-11 10:27:18.040  HOSPITALARIO   URGENCIAS     2025-05-11  B01ME
# 3   2025-05-11 11:02:40.167   AMBULATORIO   URGENCIAS     2025-05-11  B05ME
# 4   2025-05-11 11:24:32.487   AMBULATORIO   URGENCIAS     2025-05-11  B01ME
# ..                      ...           ...         ...            ...    ...
# 250 2025-05-17 19:53:26.103   AMBULATORIO   URGENCIAS     2025-05-17  B01ME
# 251 2025-05-17 21:11:11.187   AMBULATORIO   URGENCIAS     2025-05-17  B01ME
# 252 2025-05-17 21:12:27.153   AMBULATORIO   URGENCIAS     2025-05-17  B01ME
# 253 2025-05-17 21:52:11.023   AMBULATORIO   URGENCIAS     2025-05-17  B05ME
# 254 2025-05-17 23:57:27.277   AMBULATORIO   URGENCIAS     2025-05-18  B01ME
#
#      ... Localidad unidad centinela MES Fecha consulta  Semana epidemiologica  \
# 0    ...         19. CIUDAD BOLIVAR   5     11/05/2025                     20
# 1    ...         19. CIUDAD BOLIVAR   5     11/05/2025                     20
# 2    ...         19. CIUDAD BOLIVAR   5     11/05/2025                     20
# 3    ...         19. CIUDAD BOLIVAR   5     11/05/2025                     20
# 4    ...         19. CIUDAD BOLIVAR   5     11/05/2025                     20
# ..   ...                        ...  ..            ...                    ...
# 250  ...         19. CIUDAD BOLIVAR   5     17/05/2025                     20
# 251  ...         19. CIUDAD BOLIVAR   5     17/05/2025                     20
# 252  ...         19. CIUDAD BOLIVAR   5     17/05/2025                     20
# 253  ...         19. CIUDAD BOLIVAR   5     17/05/2025                     20
# 254  ...         19. CIUDAD BOLIVAR   5     17/05/2025                     20
#
#     Fecha de nacimiento Tipo de documento Edad años Edad en meses  \
# 0            01/11/2014                TI      10.0           NaN
# 1            09/11/2023                RC       1.0           NaN
# 2            27/04/2022                RC       3.0           NaN
# 3            31/07/2023                RC       1.0           NaN
# 4            14/05/1945                CC      79.0           NaN
# ..                  ...               ...       ...           ...
# 250          21/08/2020                RC       4.0           NaN
# 251          13/02/1980                CC      45.0           NaN
# 252          16/10/1944                CC      80.0           NaN
# 253          15/11/2011                TI      13.0           NaN
# 254          06/10/2021                RC       3.0           NaN
#
#        GRUPO DE EDAD    Sexo
# 0        2. INFANCIA  Hombre
# 1        1. INFANCIA  Hombre
# 2        1. INFANCIA   Mujer
# 3        1. INFANCIA   Mujer
# 4           6. VEJEZ  Hombre
# ..               ...     ...
# 250      1. INFANCIA   Mujer
# 251       5. ADULTEZ   Mujer
# 252         6. VEJEZ   Mujer
# 253  3. ADOLESCENCIA  Hombre
# 254      1. INFANCIA  Hombre
#
# [254 rows x 54 columns]

# %%
import pandas as pd

# Códigos por grupo
EIC = {'I200', 'I201', 'I208', 'I209', 'I210', 'I211', 'I212', 'I213', 'I214', 'I219',
       'I220', 'I221', 'I228', 'I229', 'I230', 'I231', 'I232', 'I233', 'I234', 'I235',
       'I236', 'I237', 'I238', 'I240', 'I241', 'I248', 'I249', 'I250', 'I251', 'I252',
       'I253', 'I254', 'I255', 'I256', 'I257', 'I258', 'I259'}

ECV = {'I600', 'I601', 'I602', 'I603', 'I604', 'I605', 'I606', 'I607', 'I608', 'I609',
       'I610', 'I611', 'I612', 'I613', 'I614', 'I615', 'I616', 'I617', 'I618', 'I619',
       'I620', 'I621', 'I629', 'I630', 'I631', 'I632', 'I633', 'I634', 'I635', 'I636',
       'I637', 'I638', 'I639', 'I64X', 'I650', 'I651', 'I652', 'I653', 'I658', 'I659',
       'I660', 'I661', 'I662', 'I663', 'I664', 'I668', 'I669', 'I670', 'I671', 'I672',
       'I673', 'I674', 'I675', 'I676', 'I677', 'I678', 'I679', 'I680', 'I681', 'I682', 'I688',
       'I690', 'I691', 'I692', 'I693', 'I694', 'I698'}

IRA = {'J00X', 'J09X', 'J13X', 'J14X', 'J22X',
       'J010', 'J011', 'J012', 'J013', 'J014', 'J015', 'J016', 'J017', 'J018', 'J019',
       'J020', 'J028', 'J029', 'J030', 'J038', 'J039', 'J040', 'J041', 'J042', 'J050', 'J051',
       'J060', 'J068', 'J069', 'J100', 'J101', 'J108', 'J110', 'J111', 'J118', 'J120', 'J121',
       'J122', 'J123', 'J128', 'J129', 'J150', 'J151', 'J152', 'J153', 'J154', 'J155', 'J156',
       'J157', 'J158', 'J159', 'J160', 'J168', 'J170', 'J171', 'J172', 'J173', 'J178',
       'J180', 'J181', 'J182', 'J188', 'J189', 'J200', 'J201', 'J202', 'J203', 'J204', 'J205',
       'J206', 'J207', 'J208', 'J209', 'J210', 'J211', 'J218', 'J219'}

EPOC = {'J40X', 'J410', 'J411', 'J418', 'J42X', 'J430',
        'J431', 'J432', 'J438', 'J439', 'J440', 'J441', 'J448', 'J449', 'J47X'}

ASMA = {'J450', 'J451', 'J458', 'J459', 'J46X'}

# %%
# Función de clasificación
def clasificar_diagnostico(codigo):
    if pd.isna(codigo):
        return None
    codigo = str(codigo).strip().upper()
    if codigo in EIC:
        return "EIC"
    elif codigo in ECV:
        return "ECV"
    elif codigo.startswith('I'):
        return "OTRAS CARDIO"
    elif codigo in IRA:
        return "INFECCIONES RESPIRATORIAS AGUDAS"
    elif codigo in EPOC:
        return "EPOC"
    elif codigo in ASMA:
        return "ASMA"
    elif codigo.startswith('J'):
        return "OTRAS RESPIRATORIAS"
    else:
        return None


df_sin_duplicados_columnas['SUBDX'] = df_sin_duplicados_columnas["Diagnóstico de ingreso"].apply(clasificar_diagnostico)

# %%
df_sin_duplicados_columnas.rename(columns={'DOCUMENTO': "No de documento"}, inplace=True)

# %%
df_sin_duplicados_columnas.rename(columns={'NOMBRE_TERCERO': "EAPB"}, inplace=True)

# %%
df_sin_duplicados_columnas.columns
# Out:
# Index(['CODIGO_USS', 'NOMBRE_USS', 'TIPO_HC', 'NOMBRE_TIPOHC', 'INGRESO',
#        'FECHA_INGRESO', 'TIPO_INGRESO', 'INGRESO_POR', 'FECHA_ATENCION',
#        'AREA', 'NOMBRE_AREA', 'TIPO_AREA_SERVICIO', 'AREA_URGENCIAS', 'FOLIO',
#        'TIPO_ID', 'No de documento', 'PRIMER_NOMBRE', 'SEGUNDO_NOMBRE',
#        'PRIMER_APELLIDO', 'SEGUNDO_APELLIDO', 'FECHA_NACIMIENTO', 'EDAD',
#        'GENERO', 'CODIGO_BARRIO', 'NOMBRE_BARRIO', 'Dirección', 'TELEFONO',
#        'LOCALIDAD', 'Localidad de residencia base', 'Regimen SGSS',
#        'TIPO_AFILIADO', 'TERCERO_ENTIDAD', 'EAPB', 'PLAN_BENEFICIOS',
#        'ID_MEDICO', 'NOMBRE_MEDICO', 'ESPECIALIDAD', 'Diagnóstico de ingreso',
#        'Nombre del diagnóstico de ingreso', 'TIPO_DX', 'REGISTRO_EGRESO',
#        'DIASGNOSTICO_EGRESO', 'DX_EGRESO', 'Unidad centinela',
#        'Localidad unidad centinela', 'MES', 'Fecha consulta',
#        'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento',
#        'Edad años', 'Edad en meses', 'GRUPO DE EDAD', 'Sexo', 'SUBDX'],
#       dtype='object')

# %%
df_sin_duplicados_columnas["Diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico secundario"]="999"

# %%
df_sin_duplicados_columnas.rename(columns={'DIASGNOSTICO_EGRESO': "Diagnóstico de egreso",  'DX_EGRESO': "Nombre del diagnóstico de egreso"}, inplace=True)

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)
# Out:
# <ipython-input-107-8f51a3f2211d>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)
# Out:
# <ipython-input-108-aa0c04562abd>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Nombre del diagnóstico de egreso"].fillna("999", inplace=True)

# %%
df_sin_duplicados_columnas["Fecha egreso"]="999"

# %%
df_sin_duplicados_columnas["Diagnóstico de egreso"].replace('',"999", inplace=True)
# Out:
# <ipython-input-110-0b76f42dcf32>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_sin_duplicados_columnas["Diagnóstico de egreso"].replace('',"999", inplace=True)

# %%
variables_def=['Unidad centinela',  'Localidad unidad centinela', 'MES', 'Fecha consulta',
       'Semana epidemiologica', 'Fecha de nacimiento', 'Tipo de documento', 'No de documento', 'Edad en meses',
 'Edad años','GRUPO DE EDAD', 'Sexo', 'EAPB', 'Regimen SGSS', 'Dirección',
       'Localidad de residencia base', 'Diagnóstico de ingreso',
       'Nombre del diagnóstico de ingreso', 'TIPO_DX', 'SUBDX', "Diagnóstico secundario", "Nombre del diagnóstico secundario", "Diagnóstico secundario", "Nombre del diagnóstico secundario",
        "Diagnóstico de egreso",   "Nombre del diagnóstico de egreso"  , "Fecha egreso"  ]

# %%
df_sin_duplicados_columnas_filtrada=df_sin_duplicados_columnas[variables_def]

# %%
df_sin_duplicados_columnas_filtrada.to_excel("Base_Meissen_2.xlsx",index=False)
